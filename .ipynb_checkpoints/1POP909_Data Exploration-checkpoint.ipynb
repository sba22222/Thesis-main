# %% [markdown]
# # Data Exploration
#
# The below delves into the exploration and analysis of MIDI data sourced from the POP909 dataset, a collection of music tracks. The script is structured into distinct sections, each fulfilling a crucial role in understanding and processing the musical information contained within the MIDI files. Initially, the code demonstrates how to play MIDI files using the mido library, enabling auditory examination of the music. Following this, it employs the pretty_midi library to analyze MIDI data, extracting essential details such as tempo, time signature changes, and characteristics of pitched instruments. Visualizations, including histograms and scatter plots, are generated to visualize note distributions and assess pitch consistency over time. Furthermore, the code performs key signature analysis across multiple MIDI files, revealing common patterns in time signatures and expected music keys within the dataset. Overall, this code provides a comprehensive framework for exploring MIDI music data, offering valuable insights.

# %% [markdown]
# ## Play One of the Songs

# %%
just comment out while reloading code because it plays everytime

import mido
from mido import MidiFile

midi_file = MidiFile('POP909/909/909.mid')

# Open output port with default backend
with mido.open_output() as port:
    for message in midi_file.play():
        port.send(message)

# %% [markdown]
# ## Analyzing & Processing the MIDI Data

# %% [markdown]
# Use one midi file as a tester to see what information is in the files

# %% [markdown]
# Lets see if our midi has any information on Tempo, Pitch, Duration, and/or Velocity

# %%
import pretty_midi

# Load MIDI file
midi_data = pretty_midi.PrettyMIDI('POP909/909/909.mid')

# Check if tempo information is available
if midi_data.get_tempo_changes():
    print("Tempo information exists.")
else:
    print("Tempo information does not exist.")

# Check if time signature changes are available
if midi_data.time_signature_changes:
    print("Time signature changes exist.")
else:
    print("Time signature changes do not exist.")

# Check if there are any pitched instruments (containing pitch, duration, velocity)
pitched_instruments = [i for i in midi_data.instruments if i.is_drum is False and len(i.notes) > 0]
if pitched_instruments:
    print("Pitched instruments exist.")
    
    # Check if there's pitch, duration, and velocity in the first pitched instrument
    first_pitched_instrument = pitched_instruments[0]
    if any(note.pitch is not None and note.start is not None and note.end is not None and note.velocity is not None
           for note in first_pitched_instrument.notes):
        print("Pitch, duration, and velocity information exist in the first pitched instrument.")
    else:
        print("Pitch, duration, or velocity information is missing in the first pitched instrument.")
else:
    print("No pitched instruments found.")
# Out:
# Tempo information exists.
# Time signature changes exist.
# Pitched instruments exist.
# Pitch, duration, and velocity information exist in the first pitched instrument.

# %%
import pretty_midi

# Load MIDI file
midi_data = pretty_midi.PrettyMIDI('POP909/909/909.mid')

# Print time signature changes
print("Time Signatures:")
for ts in midi_data.time_signature_changes:
    print(ts)

# Print tempo changes
print("\nTempo Changes:")
for tempo_change in midi_data.get_tempo_changes()[1]:
    print(tempo_change)

# Print instrument information
print("\nInstruments:")
for instrument in midi_data.instruments:
    print(f'Name: {instrument.name}, Program: {instrument.program}, Is drum: {instrument.is_drum}')

    # Print pitch, duration, and velocity for each note in the instrument
    if not instrument.is_drum and len(instrument.notes) > 0:
        print(f"\nNotes for {instrument.name}:")
        for note in instrument.notes:
            print(f'Pitch: {note.pitch}, Duration: {note.end - note.start:.4f}, Velocity: {note.velocity}')
# Out:
# Time Signatures:
# 1/4 at 0.00 seconds
#
# Tempo Changes:
# 104.00001386666852
# 103.75022479215373
# 104.00001386666852
# 103.75022479215373
# 104.00001386666852
# Pitch: 64, Duration: 1.1490, Velocity: 73
# Pitch: 60, Duration: 1.2524, Velocity: 69

# %%
# Print some notes for the first instrument, if it has any
if midi_data.instruments:
    print("\nNotes for MELODY:")
    for note in midi_data.instruments[0].notes[:5]:  # Just the first 10 notes
        print(note)
        print(f"Duration: {note.end - note.start}")  # Adding duration
        
# Print some notes for the first instrument, if it has any
if midi_data.instruments:
    print("\nNotes for BRIDGE:")
    for note in midi_data.instruments[1].notes[:5]:  # Just the first 10 notes
        print(note)
        print(f"Duration: {note.end - note.start}")  # Adding duration
        
# Print some notes for the first instrument, if it has any
if midi_data.instruments:
    print("\nNotes for PIANO:")
    for note in midi_data.instruments[2].notes[:5]:  # Just the first 10 notes
        print(note)
        print(f"Duration: {note.end - note.start}")  # Adding duration

# %%
midi_data.plot('histogram', 'pitchClass', 'count');
# Out:
# <music21.graph.plot.HistogramPitchClass for <music21.stream.Score 0x1e582d7fbe0>>

# %% [markdown]
# The scatter plot below shows that the use of notes look consistent through time, so there are no key changes in this piece.

# %%
midi_data.plot('scatter', 'offset', 'pitchClass')
# Out:
# <music21.graph.plot.ScatterPitchClassOffset for <music21.stream.Score 0x1e582d7fbe0>>

# %%
timeSignature = midi_data.getTimeSignatures()[0]
music_analysis = midi_data.analyze('key')
print("Music time signature: {0}/{1}".format(timeSignature.beatCount, timeSignature.denominator))
print("Expected music key: {0}".format(music_analysis))
print("Music key confidence: {0}".format(music_analysis.correlationCoefficient))
print("Other music key alternatives:")
for analysis in music_analysis.alternateInterpretations:
    if (analysis.correlationCoefficient > 0.5):
        print(analysis)
# Out:
# Music time signature: 2/4
# Expected music key: g minor
# Music key confidence: 0.8737642347051872
# Other music key alternatives:
# B- major
# c minor
# E- major
# F major
# d minor

# %%
from music21 import converter, key

def analyze_midi_file(file_path):
    try:
        # Load MIDI file
        midi_data = converter.parse(file_path)

        # Extract key and time signature
        key_signature = midi_data.analyze('key')
        time_signature = midi_data.getTimeSignatures()[0]

        # Print results
        print(f"Music time signature: {time_signature.numerator}/{time_signature.denominator}")
        print(f"Expected music key: {key_signature}")
        print(f"Music key confidence: {key_signature.correlationCoefficient}")

#         # Print other music key alternatives
#         print("Other music key alternatives:")
#         for analysis in key_signature.alternateInterpretations:
#             if analysis.correlationCoefficient > 0.5:
#                 print(analysis)

    except Exception as e:
        print(f"Error analyzing {file_path}: {e}")

def analyze_midi_folder(root_folder):
    for root, dirs, files in os.walk(root_folder):
        for file in files:
            if file.lower().endswith(".mid") or file.lower().endswith(".midi"):
                file_path = os.path.join(root, file)
                print(f"\nAnalyzing MIDI file: {file_path}")
                analyze_midi_file(file_path)

# Replace 'your_root_folder' with the path to the folder containing subfolders with MIDI files
analyze_midi_folder('POP909')
# Out:
# Analyzing MIDI file: POP909\001\001.mid
# Music time signature: 2/4
# Expected music key: F# major
# Music key confidence: 0.9101015401601796
# Other music key alternatives:
# e- minor
# B major
# C# major
# g# minor
# f# minor
# c# minor
#
# Analyzing MIDI file: POP909\002\002.mid
# Music time signature: 2/4
# Expected music key: B major
# Music key confidence: 0.968839431521989
# Other music key alternatives:
# c# minor
# g# minor
# E major
# F# major
# f# minor
#
# Analyzing MIDI file: POP909\003\003.mid
# Music time signature: 2/4
# Expected music key: g minor
# Music key confidence: 0.8737642347051872
# Other music key alternatives:
# B- major
# c minor
# E- major
# F major
# d minor
#
# Analyzing MIDI file: POP909\004\004.mid
# Music time signature: 2/4
# Expected music key: e- minor
# Music key confidence: 0.9300412284200911
# Other music key alternatives:
# F# major
# g# minor
# b- minor
# C# major
# A- major
# E- major
#
# Analyzing MIDI file: POP909\005\005.mid
# Music time signature: 2/4
# Expected music key: G major
# Music key confidence: 0.909827685378034
# Other music key alternatives:
# D major
# a minor
# e minor
# C major
# d minor
#
# Analyzing MIDI file: POP909\006\006.mid
# Music time signature: 2/4
# Expected music key: c minor
# Music key confidence: 0.9053645568514631
# Other music key alternatives:
# E- major
# g minor
# f minor
# B- major
#
# Analyzing MIDI file: POP909\007\007.mid
# Music time signature: 2/4
# Expected music key: b minor
# Music key confidence: 0.8747173985337658
# Other music key alternatives:
# e minor
# E major
# D major
# f# minor
# A major
# B major
#
# Analyzing MIDI file: POP909\008\008.mid
# Music time signature: 2/4
# Expected music key: E- major
# Music key confidence: 0.9326573581935764
# Other music key alternatives:
# c minor
# B- major
# f minor
# A- major
# b- minor
#
# Analyzing MIDI file: POP909\009\009.mid
# Music time signature: 2/4
# Expected music key: e- minor
# Music key confidence: 0.8875488007696773
# Other music key alternatives:
# g# minor
# C# major
# F# major
# A- major
# b- minor
#
# Analyzing MIDI file: POP909\010\010.mid
# Music time signature: 2/4
# Expected music key: G major
# Music key confidence: 0.9242183794442137
# Other music key alternatives:
# a minor
# e minor
# C major
#
# Analyzing MIDI file: POP909\011\011.mid
# Music time signature: 2/4
# Expected music key: E- major
# Music key confidence: 0.9120267995765541
# Other music key alternatives:
# c minor
# A- major
# B- major
# f minor
# b- minor
#
# Analyzing MIDI file: POP909\012\012.mid
# Music time signature: 2/4
# Expected music key: E- major
# Music key confidence: 0.8975415283502682
# Other music key alternatives:
# A- major
# f minor
# c minor
# e- minor
# b- minor
#
# Analyzing MIDI file: POP909\013\013.mid
# Music time signature: 2/4
# Expected music key: a minor
# Music key confidence: 0.9333756187312863
# Other music key alternatives:
# d minor
# G major
# C major
# e minor
# D major
# A major
#
# Analyzing MIDI file: POP909\014\014.mid
# Music time signature: 1/4
# Expected music key: E- major
# Music key confidence: 0.8733065719085802
# Other music key alternatives:
# c minor
# f minor
# A- major
# B- major
#
# Analyzing MIDI file: POP909\015\015.mid
# Music time signature: 2/4
# Expected music key: E- major
# Music key confidence: 0.8664344773339784
# Other music key alternatives:
# c minor
# A- major
# B- major
# f minor
#
# Analyzing MIDI file: POP909\016\016.mid
# Music time signature: 2/4
# Expected music key: g minor
# Music key confidence: 0.8800692565214907
# Other music key alternatives:
# B- major
# E- major
# c minor
# d minor
# F major
#
# Analyzing MIDI file: POP909\017\017.mid
# Music time signature: 2/4
# Expected music key: f# minor
# Music key confidence: 0.8812170124081747
# Other music key alternatives:
# A major
# c# minor
# b minor
# B major
# E major
#
# Analyzing MIDI file: POP909\018\018.mid
# Music time signature: 2/4
# Expected music key: f# minor
# Music key confidence: 0.8839948503681354
# Other music key alternatives:
# A major
# c# minor
# b minor
# B major
# E major
#
# Analyzing MIDI file: POP909\019\019.mid
# Music time signature: 2/4
# Expected music key: A major
# Music key confidence: 0.8778108796244725
# Other music key alternatives:
# D major
# b minor
# e minor
# a minor
# G major
# f# minor
#
# Analyzing MIDI file: POP909\020\020.mid
# Music time signature: 2/4
# Expected music key: a minor
# Music key confidence: 0.8919210088106966
# Other music key alternatives:
# C major
# G major
# d minor
# F major
# e minor
# g minor
#
# Analyzing MIDI file: POP909\021\021.mid
# Music time signature: 2/4
# Expected music key: E- major
# Music key confidence: 0.8851964483999586
# Other music key alternatives:
# A- major
# f minor
# c minor
# e- minor
#
# Analyzing MIDI file: POP909\022\022.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.8737179489119431
# Other music key alternatives:
# g minor
# E- major
#
# Analyzing MIDI file: POP909\023\023.mid
# Music time signature: 1/4
# Expected music key: e- minor
# Music key confidence: 0.8406820880097607
# Other music key alternatives:
# g# minor
# b- minor
# A- major
# E- major
# F# major
#
# Analyzing MIDI file: POP909\024\024.mid
# Music time signature: 2/4
# Expected music key: F# major
# Music key confidence: 0.8624709041326689
# Other music key alternatives:
# e- minor
# C# major
# g# minor
# b- minor
# B major
#
# Analyzing MIDI file: POP909\025\025.mid
# Music time signature: 1/4
# Expected music key: A major
# Music key confidence: 0.9073512635396545
# Other music key alternatives:
# e minor
# E major
# f# minor
# D major
# a minor
# b minor
#
# Analyzing MIDI file: POP909\026\026.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.8546903223177007
# Other music key alternatives:
# D major
# d minor
# g minor
# C major
# e minor
# a minor
#
# Analyzing MIDI file: POP909\027\027.mid
# Music time signature: 1/4
# Expected music key: d minor
# Music key confidence: 0.8573700086238192
# Other music key alternatives:
# g minor
# B- major
# F major
# C major
# G major
# a minor
#
# Analyzing MIDI file: POP909\028\028.mid
# Music time signature: 1/4
# Expected music key: g# minor
# Music key confidence: 0.8927809095468986
# Other music key alternatives:
# B major
# c# minor
# F# major
# E major
# e- minor
# f# minor
#
# Analyzing MIDI file: POP909\029\029.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.8942141726694417
# Other music key alternatives:
# E- major
# g minor
# c minor
# F major
# f minor
# b- minor
#
# Analyzing MIDI file: POP909\030\030.mid
# Music time signature: 1/4
# Expected music key: E- major
# Music key confidence: 0.958173249437321
# Other music key alternatives:
# c minor
# f minor
# B- major
# A- major
# g minor
#
# Analyzing MIDI file: POP909\031\031.mid
# Music time signature: 1/4
# Expected music key: A major
# Music key confidence: 0.808780273923291
# Other music key alternatives:
# c# minor
# E major
# f# minor
# B major
#
# Analyzing MIDI file: POP909\032\032.mid
# Music time signature: 4/4
# Expected music key: b minor
# Music key confidence: 0.8954225519633017
# Other music key alternatives:
# e minor
# D major
# A major
# E major
# f# minor
# G major
#
# Analyzing MIDI file: POP909\033\033.mid
# Music time signature: 1/4
# Expected music key: e minor
# Music key confidence: 0.8619923505329644
# Other music key alternatives:
# a minor
# C major
# G major
# D major
# A major
#
# Analyzing MIDI file: POP909\034\034.mid
# Music time signature: 1/4
# Expected music key: e minor
# Music key confidence: 0.8830652287159939
# Other music key alternatives:
# a minor
# G major
# C major
#
# Analyzing MIDI file: POP909\035\035.mid
# Music time signature: 1/4
# Expected music key: E major
# Music key confidence: 0.8988798953517771
# Other music key alternatives:
# c# minor
# A major
# B major
# f# minor
# b minor
#
# Analyzing MIDI file: POP909\036\036.mid
# Music time signature: 1/4
# Expected music key: g minor
# Music key confidence: 0.8767032755815238
# Other music key alternatives:
# c minor
# B- major
# E- major
# F major
# C major
# d minor
#
# Analyzing MIDI file: POP909\037\037.mid
# Music time signature: 1/4
# Expected music key: b minor
# Music key confidence: 0.8389686668002394
# Other music key alternatives:
# D major
# G major
# e minor
#
# Analyzing MIDI file: POP909\038\038.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.9590061789699711
# Other music key alternatives:
# a minor
# F major
# d minor
# G major
#
# Analyzing MIDI file: POP909\039\039.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.9239810842565184
# Other music key alternatives:
# e minor
# a minor
# D major
# C major
# b minor
#
# Analyzing MIDI file: POP909\040\040.mid
# Music time signature: 1/4
# Expected music key: d minor
# Music key confidence: 0.844987825898766
# Other music key alternatives:
# g minor
# B- major
# F major
# C major
#
# Analyzing MIDI file: POP909\041\041.mid
# Music time signature: 4/4
# Expected music key: B- major
# Music key confidence: 0.8772042278429701
# Other music key alternatives:
# g minor
# c minor
# F major
# E- major
# f minor
#
# Analyzing MIDI file: POP909\042\042.mid
# Music time signature: 4/4
# Expected music key: b- minor
# Music key confidence: 0.9184898399089197
# Other music key alternatives:
# e- minor
# C# major
# A- major
# E- major
# f minor
# F# major
#
# Analyzing MIDI file: POP909\043\043.mid
# Music time signature: 4/4
# Expected music key: g minor
# Music key confidence: 0.9378330786651268
# Other music key alternatives:
# c minor
# B- major
# F major
# E- major
# d minor
#
# Analyzing MIDI file: POP909\044\044.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.912292440520578
# Other music key alternatives:
# g minor
# c minor
# F major
# E- major
# d minor
# f minor
#
# Analyzing MIDI file: POP909\045\045.mid
# Music time signature: 1/4
# Expected music key: E major
# Music key confidence: 0.9128149894504196
# Other music key alternatives:
# A major
# c# minor
# f# minor
# b minor
# B major
#
# Analyzing MIDI file: POP909\046\046.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.8546619660913259
# Other music key alternatives:
# g minor
# E- major
# c minor
#
# Analyzing MIDI file: POP909\047\047.mid
# Music time signature: 1/4
# Expected music key: E major
# Music key confidence: 0.9162925310738893
# Other music key alternatives:
# c# minor
# A major
# f# minor
# B major
#
# Analyzing MIDI file: POP909\048\048.mid
# Error analyzing POP909\048\048.mid: 2085412730192
#
# Analyzing MIDI file: POP909\049\049.mid
# Music time signature: 1/4
# Expected music key: c# minor
# Music key confidence: 0.9305548201067356
# Other music key alternatives:
# E major
# f# minor
# B major
# A major
#
# Analyzing MIDI file: POP909\050\050.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.9567762924917508
# Other music key alternatives:
# D major
# e minor
# a minor
# C major
# d minor
# b minor
#
# Analyzing MIDI file: POP909\051\051.mid
# Music time signature: 1/4
# Expected music key: B major
# Music key confidence: 0.9300275940490782
# Other music key alternatives:
# F# major
# g# minor
# c# minor
# e- minor
# E major
# f# minor
#
# Analyzing MIDI file: POP909\052\052.mid
# Music time signature: 1/4
# Expected music key: b minor
# Music key confidence: 0.9172370179342635
# Other music key alternatives:
# D major
# f# minor
# e minor
# A major
# G major
#
# Analyzing MIDI file: POP909\053\053.mid
# Music time signature: 1/4
# Expected music key: f minor
# Music key confidence: 0.9242907843706395
# Other music key alternatives:
# b- minor
# A- major
# E- major
# c minor
# B- major
# C# major
#
# Analyzing MIDI file: POP909\054\054.mid
# Music time signature: 1/4
# Expected music key: E major
# Music key confidence: 0.8932628577946546
# Other music key alternatives:
# A major
# c# minor
# f# minor
# e minor
# b minor
#
# Analyzing MIDI file: POP909\055\055.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.9356199138088611
# Other music key alternatives:
# a minor
# G major
# d minor
# F major
# g minor
#
# Analyzing MIDI file: POP909\056\056.mid
# Music time signature: 1/4
# Expected music key: a minor
# Music key confidence: 0.7983623880921737
# Other music key alternatives:
# G major
# D major
# e minor
# d minor
# C major
# A major
#
# Analyzing MIDI file: POP909\057\057.mid
# Music time signature: 1/4
# Expected music key: F major
# Music key confidence: 0.9404786546398926
# Other music key alternatives:
# d minor
# C major
# g minor
# B- major
#
# Analyzing MIDI file: POP909\058\058.mid
# Music time signature: 1/4
# Expected music key: A major
# Music key confidence: 0.9305233402306183
# Other music key alternatives:
# f# minor
# E major
# b minor
# c# minor
# D major
#
# Analyzing MIDI file: POP909\059\059.mid
# Music time signature: 1/4
# Expected music key: b minor
# Music key confidence: 0.9053196521495855
# Other music key alternatives:
# D major
# e minor
# G major
# A major
#
# Analyzing MIDI file: POP909\060\060.mid
# Music time signature: 1/4
# Expected music key: B major
# Music key confidence: 0.8434090617702538
# Other music key alternatives:
# E major
# f# minor
# b minor
# c# minor
# g# minor
# F# major
#
# Analyzing MIDI file: POP909\061\061.mid
# Music time signature: 1/4
# Expected music key: g# minor
# Music key confidence: 0.948234875863983
# Other music key alternatives:
# B major
# c# minor
# F# major
# E major
#
# Analyzing MIDI file: POP909\062\062.mid
# Music time signature: 1/4
# Expected music key: c minor
# Music key confidence: 0.9073196310696003
# Other music key alternatives:
# E- major
# f minor
# B- major
# g minor
# A- major
# F major
#
# Analyzing MIDI file: POP909\063\063.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.8686196388628462
# Other music key alternatives:
# C major
# e minor
# a minor
# D major
# d minor
# g minor
#
# Analyzing MIDI file: POP909\064\064.mid
# Music time signature: 1/4
# Expected music key: f minor
# Music key confidence: 0.8438413283222405
# Other music key alternatives:
# B- major
# E- major
# b- minor
# A- major
# c minor
#
# Analyzing MIDI file: POP909\065\065.mid
# Music time signature: 1/4
# Expected music key: a minor
# Music key confidence: 0.8607468752924017
# Other music key alternatives:
# d minor
# D major
# C major
# F major
# e minor
#
# Analyzing MIDI file: POP909\066\066.mid
# Music time signature: 1/4
# Expected music key: C# major
# Music key confidence: 0.9314558905575326
# Other music key alternatives:
# b- minor
# F# major
# A- major
# e- minor
# g# minor
#
# Analyzing MIDI file: POP909\067\067.mid
# Music time signature: 1/4
# Expected music key: B major
# Music key confidence: 0.9023136136672355
# Other music key alternatives:
# g# minor
# c# minor
# F# major
# E major
# f# minor
#
# Analyzing MIDI file: POP909\068\068.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.9365353986197942
# Other music key alternatives:
# a minor
# d minor
# F major
# G major
# g minor
#
# Analyzing MIDI file: POP909\069\069.mid
# Music time signature: 1/4
# Expected music key: g# minor
# Music key confidence: 0.7162533021977179
# Other music key alternatives:
# C# major
# c# minor
# F# major
# E major
#
# Analyzing MIDI file: POP909\070\070.mid
# Music time signature: 1/4
# Expected music key: b- minor
# Music key confidence: 0.82895438133922
# Other music key alternatives:
# C# major
# e- minor
# F# major
#
# Analyzing MIDI file: POP909\071\071.mid
# Error analyzing POP909\071\071.mid: 2085396965072
#
# Analyzing MIDI file: POP909\072\072.mid
# Error analyzing POP909\072\072.mid: 2085260651152
#
# Analyzing MIDI file: POP909\073\073.mid
# Music time signature: 1/4
# Expected music key: d minor
# Music key confidence: 0.9008868708201518
# Other music key alternatives:
# g minor
# F major
# C major
# B- major
# a minor
# G major
#
# Analyzing MIDI file: POP909\074\074.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.8626744423714268
# Other music key alternatives:
# C major
# d minor
# a minor
# g minor
#
# Analyzing MIDI file: POP909\075\075.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.944647642216069
# Other music key alternatives:
# F major
# g minor
# c minor
# E- major
# f minor
# d minor
#
# Analyzing MIDI file: POP909\076\076.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.8876925612758858
# Other music key alternatives:
# e minor
# D major
# a minor
# C major
# d minor
# b minor
#
# Analyzing MIDI file: POP909\077\077.mid
# Error analyzing POP909\077\077.mid: 2085418753904
#
# Analyzing MIDI file: POP909\078\078.mid
# Music time signature: 1/4
# Expected music key: e minor
# Music key confidence: 0.8175091811856241
# Other music key alternatives:
# a minor
# b minor
# A major
# G major
# D major
# C major
#
# Analyzing MIDI file: POP909\079\079.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.9647114531758092
# Other music key alternatives:
# a minor
# G major
# d minor
# e minor
# F major
#
# Analyzing MIDI file: POP909\080\080.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.8625382498855102
# Other music key alternatives:
# D major
# a minor
# e minor
# d minor
# C major
# A major
# b minor
#
# Analyzing MIDI file: POP909\081\081.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.9048487487373209
# Other music key alternatives:
# D major
# e minor
# C major
# d minor
# a minor
# g minor
#
# Analyzing MIDI file: POP909\082\082.mid
# Music time signature: 1/4
# Expected music key: g minor
# Music key confidence: 0.8550244189905559
# Other music key alternatives:
# c minor
# B- major
# C major
# d minor
# G major
#
# Analyzing MIDI file: POP909\083\083.mid
# Music time signature: 1/4
# Expected music key: f minor
# Music key confidence: 0.8434675048109442
# Other music key alternatives:
# b- minor
# B- major
# E- major
# A- major
# c minor
# F major
#
# Analyzing MIDI file: POP909\084\084.mid
# Music time signature: 1/4
# Expected music key: g minor
# Music key confidence: 0.9286769631405072
# Other music key alternatives:
# B- major
# c minor
# d minor
# F major
# E- major
#
# Analyzing MIDI file: POP909\085\085.mid
# Music time signature: 1/4
# Expected music key: A- major
# Music key confidence: 0.8940660436929724
# Other music key alternatives:
# b- minor
# E- major
# e- minor
# f minor
# C# major
# g# minor
#
# Analyzing MIDI file: POP909\086\086.mid
# Music time signature: 1/4
# Expected music key: A major
# Music key confidence: 0.8689648935524795
# Other music key alternatives:
# D major
# E major
# b minor
# e minor
# f# minor
#
# Analyzing MIDI file: POP909\087\087.mid
# Music time signature: 1/4
# Expected music key: b minor
# Music key confidence: 0.8906612179077008
# Other music key alternatives:
# D major
# e minor
# G major
# A major
# f# minor
#
# Analyzing MIDI file: POP909\088\088.mid
# Music time signature: 4/4
# Expected music key: c minor
# Music key confidence: 0.870880777656748
# Other music key alternatives:
# f minor
# g minor
# F major
# B- major
# E- major
#
# Analyzing MIDI file: POP909\089\089.mid
# Music time signature: 1/4
# Expected music key: D major
# Music key confidence: 0.7849002703201443
# Other music key alternatives:
# b minor
# f# minor
# A major
# E major
# e minor
#
# Analyzing MIDI file: POP909\090\090.mid
# Music time signature: 1/4
# Expected music key: c minor
# Music key confidence: 0.8504311099135301
# Other music key alternatives:
# g minor
# B- major
# C major
# F major
# E- major
# d minor
#
# Analyzing MIDI file: POP909\091\091.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.8887622358794439
# Other music key alternatives:
# f minor
# E- major
# c minor
# b- minor
# A- major
# g minor
# F major
#
# Analyzing MIDI file: POP909\092\092.mid
# Music time signature: 1/4
# Expected music key: F# major
# Music key confidence: 0.9091114236532484
# Other music key alternatives:
# e- minor
# C# major
# b- minor
# g# minor
# B major
#
# Analyzing MIDI file: POP909\093\093.mid
# Music time signature: 1/4
# Expected music key: B major
# Music key confidence: 0.9536106601025073
# Other music key alternatives:
# F# major
# c# minor
# g# minor
# E major
# f# minor
# e- minor
#
# Analyzing MIDI file: POP909\094\094.mid
# Music time signature: 1/4
# Expected music key: f minor
# Music key confidence: 0.9749732701200848
# Other music key alternatives:
# A- major
# E- major
# b- minor
# C# major
# c minor
#
# Analyzing MIDI file: POP909\095\095.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.9558100248850333
# Other music key alternatives:
# c minor
# E- major
# g minor
# F major
#
# Analyzing MIDI file: POP909\096\096.mid
# Music time signature: 1/4
# Expected music key: b- minor
# Music key confidence: 0.9033527349576929
# Other music key alternatives:
# e- minor
# A- major
# C# major
# E- major
# f minor
# F# major
#
# Analyzing MIDI file: POP909\097\097.mid
# Music time signature: 1/4
# Expected music key: b minor
# Music key confidence: 0.8898245541909386
# Other music key alternatives:
# e minor
# D major
# E major
# f# minor
# A major
# B major
#
# Analyzing MIDI file: POP909\098\098.mid
# Music time signature: 1/4
# Expected music key: C# major
# Music key confidence: 0.8522134712712288
# Other music key alternatives:
# b- minor
# A- major
# f minor
# e- minor
#
# Analyzing MIDI file: POP909\099\099.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.7351111628648158
# Other music key alternatives:
# d minor
# a minor
# G major
# e minor
# g minor
# D major
#
# Analyzing MIDI file: POP909\100\100.mid
# Music time signature: 1/4
# Expected music key: b minor
# Music key confidence: 0.8182619625045724
# Other music key alternatives:
# f# minor
# e minor
# D major
# E major
# B major
# A major
#
# Analyzing MIDI file: POP909\101\101.mid
# Music time signature: 1/4
# Expected music key: g minor
# Music key confidence: 0.8874365493190945
# Other music key alternatives:
# c minor
# B- major
# d minor
# E- major
#
# Analyzing MIDI file: POP909\102\102.mid
# Error analyzing POP909\102\102.mid: 2085449642624
#
# Analyzing MIDI file: POP909\103\103.mid
# Music time signature: 1/4
# Expected music key: d minor
# Music key confidence: 0.8575085154015739
# Other music key alternatives:
# g minor
# B- major
# F major
# G major
# a minor
# C major
#
# Analyzing MIDI file: POP909\104\104.mid
# Music time signature: 1/4
# Expected music key: C# major
# Music key confidence: 0.9221170903385536
# Other music key alternatives:
# b- minor
# A- major
# e- minor
# F# major
# g# minor
#
# Analyzing MIDI file: POP909\105\105.mid
# Music time signature: 1/4
# Expected music key: C# major
# Music key confidence: 0.8758259573108202
# Other music key alternatives:
# b- minor
# e- minor
# F# major
# A- major
# g# minor
#
# Analyzing MIDI file: POP909\106\106.mid
# Music time signature: 1/4
# Expected music key: D major
# Music key confidence: 0.8779162929745208
# Other music key alternatives:
# b minor
# e minor
# A major
# a minor
# G major
#
# Analyzing MIDI file: POP909\107\107.mid
# Music time signature: 3/4
# Expected music key: c# minor
# Music key confidence: 0.923671423699493
# Other music key alternatives:
# f# minor
# E major
# g# minor
# B major
# F# major
# C# major
#
# Analyzing MIDI file: POP909\108\108.mid
# Music time signature: 1/4
# Expected music key: A major
# Music key confidence: 0.8313655525970164
# Other music key alternatives:
# D major
# b minor
# f# minor
#
# Analyzing MIDI file: POP909\109\109.mid
# Music time signature: 1/4
# Expected music key: f# minor
# Music key confidence: 0.9051423388696118
# Other music key alternatives:
# b minor
# E major
# A major
# c# minor
# D major
#
# Analyzing MIDI file: POP909\110\110.mid
# Music time signature: 1/4
# Expected music key: E- major
# Music key confidence: 0.879940628657568
# Other music key alternatives:
# c minor
# A- major
# B- major
# f minor
# b- minor
# g minor
#
# Analyzing MIDI file: POP909\111\111.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.940996698523319
# Other music key alternatives:
# D major
# a minor
# e minor
# C major
# d minor
# b minor
#
# Analyzing MIDI file: POP909\112\112.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.9255393358034014
# Other music key alternatives:
# C major
# e minor
# a minor
# g minor
# d minor
# D major
#
# Analyzing MIDI file: POP909\113\113.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.9591621832486042
# Other music key alternatives:
# e minor
# C major
# a minor
# D major
#
# Analyzing MIDI file: POP909\114\114.mid
# Music time signature: 1/4
# Expected music key: B major
# Music key confidence: 0.894561640877467
# Other music key alternatives:
# E major
# f# minor
# b minor
# c# minor
# g# minor
# F# major
#
# Analyzing MIDI file: POP909\115\115.mid
# Music time signature: 1/4
# Expected music key: g minor
# Music key confidence: 0.8870668423264912
# Other music key alternatives:
# d minor
# C major
# G major
# F major
# c minor
# B- major
# a minor
#
# Analyzing MIDI file: POP909\116\116.mid
# Music time signature: 1/4
# Expected music key: e minor
# Music key confidence: 0.8918735425245767
# Other music key alternatives:
# a minor
# G major
# D major
# b minor
# C major
# A major
#
# Analyzing MIDI file: POP909\117\117.mid
# Music time signature: 1/4
# Expected music key: a minor
# Music key confidence: 0.8920923160649291
# Other music key alternatives:
# d minor
# G major
# C major
# D major
# F major
# e minor
# g minor
#
# Analyzing MIDI file: POP909\118\118.mid
# Music time signature: 1/4
# Expected music key: e- minor
# Music key confidence: 0.8564476832773324
# Other music key alternatives:
# F# major
# g# minor
# B major
# C# major
# b- minor
#
# Analyzing MIDI file: POP909\119\119.mid
# Music time signature: 1/4
# Expected music key: c minor
# Music key confidence: 0.9010643063821243
# Other music key alternatives:
# f minor
# E- major
# g minor
# A- major
# F major
# B- major
#
# Analyzing MIDI file: POP909\120\120.mid
# Music time signature: 1/4
# Expected music key: e- minor
# Music key confidence: 0.896198558787779
# Other music key alternatives:
# C# major
# b- minor
# F# major
# g# minor
# B major
# A- major
#
# Analyzing MIDI file: POP909\121\121.mid
# Music time signature: 1/4
# Expected music key: c minor
# Music key confidence: 0.8903957472221652
# Other music key alternatives:
# g minor
# f minor
# E- major
# B- major
# F major
# C major
#
# Analyzing MIDI file: POP909\122\122.mid
# Music time signature: 1/4
# Expected music key: b- minor
# Music key confidence: 0.922855948347712
# Other music key alternatives:
# e- minor
# C# major
# A- major
# F# major
# f minor
# E- major
#
# Analyzing MIDI file: POP909\123\123.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.9721248431793064
# Other music key alternatives:
# c minor
# g minor
# E- major
# F major
# f minor
# b- minor
#
# Analyzing MIDI file: POP909\124\124.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.8961979009799298
# Other music key alternatives:
# C major
# e minor
# D major
# d minor
# a minor
# g minor
#
# Analyzing MIDI file: POP909\125\125.mid
# Music time signature: 1/4
# Expected music key: d minor
# Music key confidence: 0.9011134428064328
# Other music key alternatives:
# g minor
# F major
# G major
# C major
# a minor
# B- major
#
# Analyzing MIDI file: POP909\126\126.mid
# Music time signature: 1/4
# Expected music key: e minor
# Music key confidence: 0.9143793884709192
# Other music key alternatives:
# G major
# D major
# a minor
# b minor
# A major
# C major
#
# Analyzing MIDI file: POP909\127\127.mid
# Music time signature: 1/4
# Expected music key: C# major
# Music key confidence: 0.9079222759088692
# Other music key alternatives:
# F# major
# e- minor
# b- minor
# c# minor
# g# minor
# A- major
#
# Analyzing MIDI file: POP909\128\128.mid
# Music time signature: 1/4
# Expected music key: E- major
# Music key confidence: 0.8583032621793053
# Other music key alternatives:
# c minor
# A- major
# B- major
# f minor
# b- minor
#
# Analyzing MIDI file: POP909\129\129.mid
# Music time signature: 1/4
# Expected music key: A major
# Music key confidence: 0.8826944102730108
# Other music key alternatives:
# E major
# f# minor
# b minor
# e minor
# D major
# c# minor
#
# Analyzing MIDI file: POP909\130\130.mid
# Music time signature: 1/4
# Expected music key: e minor
# Music key confidence: 0.8687542533220523
# Other music key alternatives:
# a minor
# G major
# C major
# D major
# A major
# b minor
#
# Analyzing MIDI file: POP909\131\131.mid
# Music time signature: 1/4
# Expected music key: a minor
# Music key confidence: 0.8095090210117518
# Other music key alternatives:
# F major
# C major
# d minor
# G major
# g minor
#
# Analyzing MIDI file: POP909\132\132.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.9548099554400077
# Other music key alternatives:
# G major
# d minor
# a minor
# F major
# g minor
# e minor
#
# Analyzing MIDI file: POP909\133\133.mid
# Music time signature: 1/4
# Expected music key: a minor
# Music key confidence: 0.9252513451244649
# Other music key alternatives:
# d minor
# C major
# G major
# e minor
# F major
# D major
#
# Analyzing MIDI file: POP909\134\134.mid
# Music time signature: 1/4
# Expected music key: c minor
# Music key confidence: 0.9097534643680689
# Other music key alternatives:
# f minor
# E- major
#
# Analyzing MIDI file: POP909\135\135.mid
# Music time signature: 1/4
# Expected music key: e minor
# Music key confidence: 0.8503359934770627
# Other music key alternatives:
# b minor
# E major
# D major
# G major
# A major
#
# Analyzing MIDI file: POP909\136\136.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.869638405340427
# Other music key alternatives:
# F major
# G major
# g minor
# a minor
# d minor
# c minor
#
# Analyzing MIDI file: POP909\137\137.mid
# Music time signature: 1/4
# Expected music key: F major
# Music key confidence: 0.9314544720478636
# Other music key alternatives:
# B- major
# d minor
# g minor
# C major
# c minor
#
# Analyzing MIDI file: POP909\138\138.mid
# Music time signature: 1/4
# Expected music key: g# minor
# Music key confidence: 0.8419047151114559
# Other music key alternatives:
# c# minor
# E major
# B major
# C# major
#
# Analyzing MIDI file: POP909\139\139.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.7099754345807445
# Other music key alternatives:
# a minor
#
# Analyzing MIDI file: POP909\140\140.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.8673397554485497
# Other music key alternatives:
# C major
# a minor
# d minor
# D major
# e minor
# g minor
#
# Analyzing MIDI file: POP909\141\141.mid
# Music time signature: 1/4
# Expected music key: d minor
# Music key confidence: 0.8252662531023477
# Other music key alternatives:
# g minor
# C major
# G major
# B- major
# F major
#
# Analyzing MIDI file: POP909\142\142.mid
# Music time signature: 1/4
# Expected music key: E- major
# Music key confidence: 0.8440663800075753
# Other music key alternatives:
# B- major
# b- minor
# c minor
# A- major
# f minor
# e- minor
#
# Analyzing MIDI file: POP909\143\143.mid
# Music time signature: 1/4
# Expected music key: g# minor
# Music key confidence: 0.8448014901326253
# Other music key alternatives:
# e- minor
# c# minor
# B major
# F# major
# C# major
# A- major
#
# Analyzing MIDI file: POP909\144\144.mid
# Music time signature: 1/4
# Expected music key: f minor
# Music key confidence: 0.9187834421996348
# Other music key alternatives:
# A- major
# b- minor
# C# major
# E- major
# c minor
# B- major
#
# Analyzing MIDI file: POP909\145\145.mid
# Music time signature: 1/4
# Expected music key: E- major
# Music key confidence: 0.9411555447114354
# Other music key alternatives:
# c minor
# f minor
# B- major
# A- major
# b- minor
#
# Analyzing MIDI file: POP909\146\146.mid
# Music time signature: 1/4
# Expected music key: C# major
# Music key confidence: 0.8688204041515097
# Other music key alternatives:
# F# major
# b- minor
# e- minor
# A- major
# g# minor
#
# Analyzing MIDI file: POP909\147\147.mid
# Music time signature: 1/4
# Expected music key: A major
# Music key confidence: 0.8995032998510708
# Other music key alternatives:
# f# minor
# E major
# b minor
# c# minor
# B major
# D major
# e minor
#
# Analyzing MIDI file: POP909\148\148.mid
# Music time signature: 1/4
# Expected music key: D major
# Music key confidence: 0.9579342458445628
# Other music key alternatives:
# b minor
# A major
# e minor
# G major
# f# minor
# a minor
#
# Analyzing MIDI file: POP909\149\149.mid
# Music time signature: 1/4
# Expected music key: E- major
# Music key confidence: 0.8453932124534901
# Other music key alternatives:
# A- major
# c minor
# f minor
# e- minor
# B- major
#
# Analyzing MIDI file: POP909\150\150.mid
# Music time signature: 1/4
# Expected music key: F major
# Music key confidence: 0.8406771621217276
# Other music key alternatives:
# d minor
# C major
# a minor
#
# Analyzing MIDI file: POP909\151\151.mid
# Music time signature: 1/4
# Expected music key: d minor
# Music key confidence: 0.8849266996637405
# Other music key alternatives:
# F major
# a minor
# g minor
#
# Analyzing MIDI file: POP909\152\152.mid
# Music time signature: 1/4
# Expected music key: d minor
# Music key confidence: 0.8890025806230561
# Other music key alternatives:
# a minor
# C major
# G major
# D major
# F major
# e minor
# g minor
#
# Analyzing MIDI file: POP909\153\153.mid
# Music time signature: 1/4
# Expected music key: c minor
# Music key confidence: 0.9087475661579764
# Other music key alternatives:
# E- major
# f minor
# B- major
# A- major
# g minor
# F major
#
# Analyzing MIDI file: POP909\154\154.mid
# Music time signature: 1/4
# Expected music key: D major
# Music key confidence: 0.9374331939837938
# Other music key alternatives:
# b minor
# A major
# e minor
# G major
# a minor
# f# minor
#
# Analyzing MIDI file: POP909\155\155.mid
# Music time signature: 1/4
# Expected music key: A major
# Music key confidence: 0.9055871753810978
# Other music key alternatives:
# b minor
# f# minor
# E major
# D major
# e minor
#
# Analyzing MIDI file: POP909\156\156.mid
# Music time signature: 1/4
# Expected music key: f minor
# Music key confidence: 0.8794556495336178
# Other music key alternatives:
# b- minor
# A- major
# c minor
# C# major
# B- major
#
# Analyzing MIDI file: POP909\157\157.mid
# Music time signature: 1/4
# Expected music key: g# minor
# Music key confidence: 0.8670753600864648
# Other music key alternatives:
# c# minor
# C# major
# B major
# F# major
# e- minor
# E major
#
# Analyzing MIDI file: POP909\158\158.mid
# Music time signature: 1/4
# Expected music key: d minor
# Music key confidence: 0.8830253021807696
# Other music key alternatives:
# g minor
# D major
# F major
# a minor
#
# Analyzing MIDI file: POP909\159\159.mid
# Music time signature: 1/4
# Expected music key: F major
# Music key confidence: 0.8905266587389381
# Other music key alternatives:
# g minor
# d minor
# B- major
# C major
# c minor
#
# Analyzing MIDI file: POP909\160\160.mid
# Music time signature: 1/4
# Expected music key: B major
# Music key confidence: 0.8917704156710222
# Other music key alternatives:
# E major
# g# minor
# c# minor
#
# Analyzing MIDI file: POP909\161\161.mid
# Music time signature: 1/4
# Expected music key: b- minor
# Music key confidence: 0.8716495484671579
# Other music key alternatives:
# C# major
# A- major
# f minor
# F# major
#
# Analyzing MIDI file: POP909\162\162.mid
# Music time signature: 1/4
# Expected music key: E major
# Music key confidence: 0.8661910994463435
# Other music key alternatives:
# c# minor
# A major
# b minor
# B major
# f# minor
# e minor
#
# Analyzing MIDI file: POP909\163\163.mid
# Music time signature: 1/4
# Expected music key: E major
# Music key confidence: 0.8080017974247838
# Other music key alternatives:
# A major
# c# minor
# f# minor
# b minor
# B major
# e minor
#
# Analyzing MIDI file: POP909\164\164.mid
# Music time signature: 1/4
# Expected music key: C# major
# Music key confidence: 0.8688668229465193
# Other music key alternatives:
# F# major
# c# minor
# b- minor
# e- minor
#
# Analyzing MIDI file: POP909\165\165.mid
# Music time signature: 1/4
# Expected music key: e- minor
# Music key confidence: 0.8253198184632264
# Other music key alternatives:
# g# minor
# b- minor
# A- major
# F# major
# B major
#
# Analyzing MIDI file: POP909\166\166.mid
# Music time signature: 1/4
# Expected music key: c# minor
# Music key confidence: 0.9094897586608153
# Other music key alternatives:
# E major
# f# minor
# g# minor
# B major
# A major
#
# Analyzing MIDI file: POP909\167\167.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.9527119651913332
# Other music key alternatives:
# g minor
# c minor
# E- major
# F major
# f minor
#
# Analyzing MIDI file: POP909\168\168.mid
# Music time signature: 1/4
# Expected music key: b minor
# Music key confidence: 0.9218726628195778
# Other music key alternatives:
# D major
# e minor
# G major
# A major
# f# minor
#
# Analyzing MIDI file: POP909\169\169.mid
# Music time signature: 1/4
# Expected music key: D major
# Music key confidence: 0.8417807553341319
# Other music key alternatives:
# b minor
# G major
# e minor
#
# Analyzing MIDI file: POP909\170\170.mid
# Music time signature: 1/4
# Expected music key: c# minor
# Music key confidence: 0.8667452210481491
# Other music key alternatives:
# E major
# A major
# f# minor
# B major
#
# Analyzing MIDI file: POP909\171\171.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.8270369090242622
# Other music key alternatives:
# F major
# a minor
# c minor
# g minor
# G major
# d minor
#
# Analyzing MIDI file: POP909\172\172.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.9132704684119288
# Other music key alternatives:
# F major
# a minor
# g minor
# c minor
# d minor
# G major
#
# Analyzing MIDI file: POP909\173\173.mid
# Music time signature: 1/4
# Expected music key: e minor
# Music key confidence: 0.7819765680298943
# Other music key alternatives:
# b minor
# G major
# D major
# A major
#
# Analyzing MIDI file: POP909\174\174.mid
# Music time signature: 1/4
# Expected music key: A major
# Music key confidence: 0.8831024862816548
# Other music key alternatives:
# f# minor
# D major
#
# Analyzing MIDI file: POP909\175\175.mid
# Music time signature: 1/4
# Expected music key: F# major
# Music key confidence: 0.8313341795610307
# Other music key alternatives:
# c# minor
# B major
# g# minor
# C# major
# f# minor
# E major
# e- minor
#
# Analyzing MIDI file: POP909\176\176.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.8659327940127777
# Other music key alternatives:
# E- major
# g minor
# c minor
# f minor
# b- minor
# F major
#
# Analyzing MIDI file: POP909\177\177.mid
# Music time signature: 4/4
# Expected music key: G major
# Music key confidence: 0.9291287740915896
# Other music key alternatives:
# e minor
# D major
# C major
# a minor
# d minor
#
# Analyzing MIDI file: POP909\178\178.mid
# Music time signature: 4/4
# Expected music key: G major
# Music key confidence: 0.7615738334703099
# Other music key alternatives:
# C major
# e minor
# d minor
#
# Analyzing MIDI file: POP909\179\179.mid
# Music time signature: 4/4
# Expected music key: F# major
# Music key confidence: 0.8956873439286405
# Other music key alternatives:
# B major
# e- minor
# g# minor
# c# minor
# C# major
#
# Analyzing MIDI file: POP909\180\180.mid
# Music time signature: 4/4
# Expected music key: g# minor
# Music key confidence: 0.8500082053666795
# Other music key alternatives:
# A- major
# C# major
# e- minor
# c# minor
#
# Analyzing MIDI file: POP909\181\181.mid
# Music time signature: 4/4
# Expected music key: F major
# Music key confidence: 0.8626729697152271
# Other music key alternatives:
# B- major
# d minor
# g minor
# f minor
#
# Analyzing MIDI file: POP909\182\182.mid
# Music time signature: 2/4
# Expected music key: A- major
# Music key confidence: 0.9381245662337679
# Other music key alternatives:
# f minor
# b- minor
# E- major
# C# major
# e- minor
# c minor
#
# Analyzing MIDI file: POP909\183\183.mid
# Music time signature: 4/4
# Expected music key: A major
# Music key confidence: 0.8438329748024572
# Other music key alternatives:
# f# minor
# D major
# E major
#
# Analyzing MIDI file: POP909\184\184.mid
# Music time signature: 2/4
# Expected music key: c minor
# Music key confidence: 0.8634412053131252
# Other music key alternatives:
# B- major
# f minor
# F major
# g minor
# E- major
#
# Analyzing MIDI file: POP909\185\185.mid
# Music time signature: 4/4
# Expected music key: C major
# Music key confidence: 0.9435804558441306
# Other music key alternatives:
# F major
# d minor
# a minor
# g minor
# G major
# c minor
#
# Analyzing MIDI file: POP909\186\186.mid
# Music time signature: 4/4
# Expected music key: G major
# Music key confidence: 0.9307071969958388
# Other music key alternatives:
# a minor
# C major
# e minor
# d minor
# g minor
# D major
#
# Analyzing MIDI file: POP909\187\187.mid
# Music time signature: 4/4
# Expected music key: A major
# Music key confidence: 0.9516590312150944
# Other music key alternatives:
# f# minor
# E major
# b minor
# D major
# e minor
# c# minor
#
# Analyzing MIDI file: POP909\188\188.mid
# Music time signature: 4/4
# Expected music key: B- major
# Music key confidence: 0.9655586232849905
# Other music key alternatives:
# g minor
# F major
# c minor
# E- major
# f minor
# b- minor
#
# Analyzing MIDI file: POP909\189\189.mid
# Music time signature: 4/4
# Expected music key: C# major
# Music key confidence: 0.9343243305386849
# Other music key alternatives:
# b- minor
# A- major
# F# major
# e- minor
#
# Analyzing MIDI file: POP909\190\190.mid
# Music time signature: 4/4
# Expected music key: d minor
# Music key confidence: 0.8039738295671327
# Other music key alternatives:
# G major
# a minor
# C major
# F major
# g minor
# D major
# e minor
#
# Analyzing MIDI file: POP909\191\191.mid
# Music time signature: 4/4
# Expected music key: g minor
# Music key confidence: 0.9024267221663885
# Other music key alternatives:
# c minor
# B- major
# E- major
# F major
# C major
# d minor
#
# Analyzing MIDI file: POP909\192\192.mid
# Music time signature: 4/4
# Expected music key: F major
# Music key confidence: 0.9062039459931988
# Other music key alternatives:
# B- major
# d minor
# g minor
# C major
# c minor
#
# Analyzing MIDI file: POP909\193\193.mid
# Music time signature: 4/4
# Expected music key: F# major
# Music key confidence: 0.9626310931252039
# Other music key alternatives:
# e- minor
# g# minor
# B major
# C# major
# c# minor
# f# minor
#
# Analyzing MIDI file: POP909\194\194.mid
# Music time signature: 4/4
# Expected music key: E major
# Music key confidence: 0.8858178027595026
# Other music key alternatives:
# A major
# c# minor
# f# minor
# b minor
# e minor
#
# Analyzing MIDI file: POP909\195\195.mid
# Music time signature: 4/4
# Expected music key: g minor
# Music key confidence: 0.8582002732662355
# Other music key alternatives:
# d minor
# c minor
# C major
# F major
# G major
#
# Analyzing MIDI file: POP909\196\196.mid
# Music time signature: 4/4
# Expected music key: e- minor
# Music key confidence: 0.8942467527840057
# Other music key alternatives:
# g# minor
# F# major
# B major
# A- major
# C# major
#
# Analyzing MIDI file: POP909\197\197.mid
# Music time signature: 4/4
# Expected music key: C major
# Music key confidence: 0.9320619270431335
# Other music key alternatives:
# F major
# g minor
# a minor
# c minor
# d minor
# G major
#
# Analyzing MIDI file: POP909\198\198.mid
# Music time signature: 2/4
# Expected music key: d minor
# Music key confidence: 0.8836648121264153
# Other music key alternatives:
# F major
# C major
# g minor
# a minor
# B- major
# G major
#
# Analyzing MIDI file: POP909\199\199.mid
# Music time signature: 4/4
# Expected music key: A- major
# Music key confidence: 0.9234898857306685
# Other music key alternatives:
# f minor
# E- major
# b- minor
# c minor
# C# major
#
# Analyzing MIDI file: POP909\200\200.mid
# Music time signature: 4/4
# Expected music key: g# minor
# Music key confidence: 0.8612250283553716
# Other music key alternatives:
# c# minor
# E major
# B major
# F# major
# C# major
# e- minor
#
# Analyzing MIDI file: POP909\201\201.mid
# Music time signature: 4/4
# Expected music key: b minor
# Music key confidence: 0.8648540975087752
# Other music key alternatives:
# A major
# D major
# f# minor
# e minor
# G major
# E major
#
# Analyzing MIDI file: POP909\202\202.mid
# Music time signature: 2/4
# Expected music key: C# major
# Music key confidence: 0.7516569689327388
# Other music key alternatives:
# F# major
# b- minor
#
# Analyzing MIDI file: POP909\203\203.mid
# Music time signature: 6/8
# Expected music key: C major
# Music key confidence: 0.9266302723089264
# Other music key alternatives:
# a minor
# F major
# G major
# d minor
# g minor
# e minor
#
# Analyzing MIDI file: POP909\204\204.mid
# Music time signature: 4/4
# Expected music key: b- minor
# Music key confidence: 0.9313118172866913
# Other music key alternatives:
# C# major
# e- minor
# A- major
# F# major
# f minor
#
# Analyzing MIDI file: POP909\205\205.mid
# Music time signature: 4/4
# Expected music key: F# major
# Music key confidence: 0.9041329325360868
# Other music key alternatives:
# B major
# e- minor
# g# minor
# f# minor
# c# minor
#
# Analyzing MIDI file: POP909\206\206.mid
# Music time signature: 4/4
# Expected music key: g# minor
# Music key confidence: 0.8751921911605113
# Other music key alternatives:
# c# minor
# B major
# F# major
# C# major
#
# Analyzing MIDI file: POP909\207\207.mid
# Music time signature: 4/4
# Expected music key: B major
# Music key confidence: 0.9607590451026345
# Other music key alternatives:
# g# minor
# E major
# c# minor
# F# major
# f# minor
#
# Analyzing MIDI file: POP909\208\208.mid
# Music time signature: 4/4
# Expected music key: A major
# Music key confidence: 0.8754916327913542
# Other music key alternatives:
# D major
# f# minor
# E major
# e minor
# b minor
#
# Analyzing MIDI file: POP909\209\209.mid
# Music time signature: 4/4
# Expected music key: F major
# Music key confidence: 0.9143906617729878
# Other music key alternatives:
# B- major
# d minor
# g minor
# c minor
# C major
# f minor
#
# Analyzing MIDI file: POP909\210\210.mid
# Music time signature: 4/4
# Expected music key: F major
# Music key confidence: 0.9491166656445504
# Other music key alternatives:
# B- major
# d minor
# g minor
# C major
# f minor
# c minor
#
# Analyzing MIDI file: POP909\211\211.mid
# Music time signature: 4/4
# Expected music key: C major
# Music key confidence: 0.9572016520338168
# Other music key alternatives:
# a minor
# G major
# d minor
# F major
# g minor
#
# Analyzing MIDI file: POP909\212\212.mid
# Music time signature: 2/4
# Expected music key: C# major
# Music key confidence: 0.902312240143439
# Other music key alternatives:
# b- minor
# e- minor
# A- major
# F# major
# g# minor
#
# Analyzing MIDI file: POP909\213\213.mid
# Music time signature: 4/4
# Expected music key: A- major
# Music key confidence: 0.9343490025749803
# Other music key alternatives:
# f minor
# b- minor
# C# major
# E- major
# c minor
# e- minor
#
# Analyzing MIDI file: POP909\214\214.mid
# Music time signature: 4/4
# Expected music key: f# minor
# Music key confidence: 0.936002992720464
# Other music key alternatives:
# A major
# b minor
# E major
# c# minor
# D major
#
# Analyzing MIDI file: POP909\215\215.mid
# Music time signature: 6/8
# Expected music key: b- minor
# Music key confidence: 0.949528753582758
# Other music key alternatives:
# C# major
# e- minor
# A- major
# f minor
# F# major
#
# Analyzing MIDI file: POP909\216\216.mid
# Music time signature: 4/4
# Expected music key: C major
# Music key confidence: 0.9425035656206865
# Other music key alternatives:
# F major
# G major
# d minor
# a minor
# g minor
# c minor
#
# Analyzing MIDI file: POP909\217\217.mid
# Music time signature: 4/4
# Expected music key: a minor
# Music key confidence: 0.9036159071990434
# Other music key alternatives:
# G major
# C major
# e minor
# F major
# d minor
#
# Analyzing MIDI file: POP909\218\218.mid
# Music time signature: 4/4
# Expected music key: F# major
# Music key confidence: 0.9102661636012168
# Other music key alternatives:
# B major
# e- minor
# g# minor
# c# minor
# C# major
# f# minor
#
# Analyzing MIDI file: POP909\219\219.mid
# Music time signature: 4/4
# Expected music key: F major
# Music key confidence: 0.8732776600534369
# Other music key alternatives:
# C major
# g minor
# d minor
# c minor
# B- major
# a minor
#
# Analyzing MIDI file: POP909\220\220.mid
# Music time signature: 4/4
# Expected music key: A- major
# Music key confidence: 0.9124250521466557
# Other music key alternatives:
# f minor
# b- minor
# E- major
# C# major
# c minor
#
# Analyzing MIDI file: POP909\221\221.mid
# Music time signature: 4/4
# Expected music key: f minor
# Music key confidence: 0.8258594878552945
# Other music key alternatives:
# A- major
# b- minor
# C# major
# E- major
# c minor
# e- minor
#
# Analyzing MIDI file: POP909\222\222.mid
# Music time signature: 4/4
# Expected music key: F# major
# Music key confidence: 0.9422211242643173
# Other music key alternatives:
# e- minor
# C# major
# B major
# g# minor
# c# minor
#
# Analyzing MIDI file: POP909\223\223.mid
# Music time signature: 4/4
# Expected music key: f minor
# Music key confidence: 0.917106608595557
# Other music key alternatives:
# A- major
# b- minor
# E- major
# C# major
# c minor
#
# Analyzing MIDI file: POP909\224\224.mid
# Music time signature: 4/4
# Expected music key: C# major
# Music key confidence: 0.7898957709252367
# Other music key alternatives:
# e- minor
# g# minor
# c# minor
# A- major
# B major
# F# major
#
# Analyzing MIDI file: POP909\225\225.mid
# Music time signature: 4/4
# Expected music key: B- major
# Music key confidence: 0.9296317294281896
# Other music key alternatives:
# g minor
# E- major
# F major
# c minor
# f minor
#
# Analyzing MIDI file: POP909\226\226.mid
# Music time signature: 4/4
# Expected music key: d minor
# Music key confidence: 0.896839440153675
# Other music key alternatives:
# g minor
# F major
# a minor
# B- major
# C major
# G major
#
# Analyzing MIDI file: POP909\227\227.mid
# Music time signature: 4/4
# Expected music key: A- major
# Music key confidence: 0.9005480665252795
# Other music key alternatives:
# f minor
# C# major
# b- minor
# E- major
#
# Analyzing MIDI file: POP909\228\228.mid
# Music time signature: 4/4
# Expected music key: E major
# Music key confidence: 0.9353728638840537
# Other music key alternatives:
# c# minor
# B major
# A major
# f# minor
# b minor
#
# Analyzing MIDI file: POP909\229\229.mid
# Music time signature: 4/4
# Expected music key: a minor
# Music key confidence: 0.766123805648386
# Other music key alternatives:
# D major
# d minor
# G major
# e minor
# F major
#
# Analyzing MIDI file: POP909\230\230.mid
# Music time signature: 4/4
# Expected music key: B- major
# Music key confidence: 0.8940467858332257
# Other music key alternatives:
# E- major
# g minor
# f minor
# F major
# c minor
# b- minor
#
# Analyzing MIDI file: POP909\231\231.mid
# Music time signature: 6/8
# Expected music key: A major
# Music key confidence: 0.918986611626348
# Other music key alternatives:
# f# minor
# E major
# b minor
# D major
# c# minor
# e minor
#
# Analyzing MIDI file: POP909\232\232.mid
# Music time signature: 4/4
# Expected music key: B- major
# Music key confidence: 0.9006867642845909
# Other music key alternatives:
# g minor
# E- major
# ...
# Expected music key: c minor
# Music key confidence: 0.8240299581537878
# Other music key alternatives:
# E- major
# A- major
# f minor
#
# Analyzing MIDI file: POP909\587\587.mid
# Music time signature: 1/4
# Expected music key: d minor
# Music key confidence: 0.8417816619877301
# Other music key alternatives:
# g minor
# G major
# B- major
# F major
# C major
#
# Analyzing MIDI file: POP909\588\588.mid
# Music time signature: 1/4
# Expected music key: g minor
# Music key confidence: 0.8925442468020464
# Other music key alternatives:
# C major
# G major
# c minor
# d minor
# F major
#
# Analyzing MIDI file: POP909\589\589.mid
# Music time signature: 1/4
# Expected music key: a minor
# Music key confidence: 0.8729764344418376
# Other music key alternatives:
# d minor
# C major
# F major
# G major
# D major
#
# Analyzing MIDI file: POP909\590\590.mid
# Music time signature: 1/4
# Expected music key: G major
# Music key confidence: 0.8744169571737758
# Other music key alternatives:
# C major
# e minor
# a minor
# d minor
# g minor
#
# Analyzing MIDI file: POP909\591\591.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.9641595130681812
# Other music key alternatives:
# a minor
# G major
# d minor
# F major
# e minor
#
# Analyzing MIDI file: POP909\592\592.mid
# Music time signature: 1/4
# Expected music key: A- major
# Music key confidence: 0.8294701947412955
# Other music key alternatives:
# g# minor
# C# major
# e- minor
# E- major
# b- minor
#
# Analyzing MIDI file: POP909\593\593.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.9079743359337702
# Other music key alternatives:
# E- major
# g minor
# c minor
# b- minor
# F major
#
# Analyzing MIDI file: POP909\594\594.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.9101885490140541
# Other music key alternatives:
# g minor
# c minor
# F major
# d minor
# E- major
# C major
# f minor
#
# Analyzing MIDI file: POP909\595\595.mid
# Music time signature: 1/4
# Expected music key: D major
# Music key confidence: 0.9530524558285629
# Other music key alternatives:
# b minor
# A major
# e minor
# G major
# a minor
#
# Analyzing MIDI file: POP909\596\596.mid
# Music time signature: 1/4
# Expected music key: D major
# Music key confidence: 0.948568401399808
# Other music key alternatives:
# b minor
# e minor
# G major
# A major
#
# Analyzing MIDI file: POP909\597\597.mid
# Music time signature: 1/4
# Expected music key: E- major
# Music key confidence: 0.9507260328334638
# Other music key alternatives:
# c minor
# B- major
# f minor
# A- major
# b- minor
#
# Analyzing MIDI file: POP909\598\598.mid
# Music time signature: 1/4
# Expected music key: c minor
# Music key confidence: 0.9205907711984601
# Other music key alternatives:
# f minor
# E- major
# B- major
# A- major
# F major
#
# Analyzing MIDI file: POP909\599\599.mid
# Music time signature: 1/4
# Expected music key: g minor
# Music key confidence: 0.9065302575445184
# Other music key alternatives:
# c minor
# B- major
# d minor
# F major
# C major
# E- major
#
# Analyzing MIDI file: POP909\600\600.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.9470950914529053
# Other music key alternatives:
# g minor
# c minor
# E- major
# F major
#
# Analyzing MIDI file: POP909\601\601.mid
# Music time signature: 1/4
# Expected music key: g# minor
# Music key confidence: 0.9372551223196814
# Other music key alternatives:
# c# minor
# B major
# F# major
# e- minor
# C# major
# E major
#
# Analyzing MIDI file: POP909\602\602.mid
# Music time signature: 1/4
# Expected music key: g minor
# Music key confidence: 0.9035090317991094
# Other music key alternatives:
# B- major
# c minor
# d minor
# F major
# C major
# E- major
#
# Analyzing MIDI file: POP909\603\603.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.8997161190870583
# Other music key alternatives:
# a minor
# d minor
# G major
# e minor
# F major
# g minor
#
# Analyzing MIDI file: POP909\604\604.mid
# Music time signature: 1/4
# Expected music key: d minor
# Music key confidence: 0.9686475084086149
# Other music key alternatives:
# F major
# g minor
# C major
# a minor
# B- major
#
# Analyzing MIDI file: POP909\605\605.mid
# Music time signature: 1/4
# Expected music key: A- major
# Music key confidence: 0.7964211906019922
# Other music key alternatives:
# E- major
# f minor
# c minor
#
# Analyzing MIDI file: POP909\606\606.mid
# Music time signature: 1/4
# Expected music key: E major
# Music key confidence: 0.9417241883773336
# Other music key alternatives:
# c# minor
# B major
# f# minor
# A major
#
# Analyzing MIDI file: POP909\607\607.mid
# Music time signature: 1/4
# Expected music key: E major
# Music key confidence: 0.9473746903850742
# Other music key alternatives:
# f# minor
# B major
# c# minor
# A major
# b minor
# e minor
#
# Analyzing MIDI file: POP909\608\608.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.9353231379291951
# Other music key alternatives:
# F major
# d minor
# a minor
# G major
# c minor
# g minor
#
# Analyzing MIDI file: POP909\609\609.mid
# Music time signature: 1/4
# Expected music key: F major
# Music key confidence: 0.8673323304952971
# Other music key alternatives:
# d minor
# B- major
# C major
# g minor
# a minor
# c minor
#
# Analyzing MIDI file: POP909\610\610.mid
# Music time signature: 1/4
# Expected music key: F major
# Music key confidence: 0.8074076503165047
# Other music key alternatives:
# C major
# d minor
# g minor
# a minor
# B- major
# c minor
# G major
#
# Analyzing MIDI file: POP909\611\611.mid
# Music time signature: 1/4
# Expected music key: f# minor
# Music key confidence: 0.8592621800647107
# Other music key alternatives:
# b minor
# D major
# A major
# B major
# E major
#
# Analyzing MIDI file: POP909\612\612.mid
# Music time signature: 1/4
# Expected music key: a minor
# Music key confidence: 0.9433975308826379
# Other music key alternatives:
# C major
# G major
# d minor
# F major
# e minor
#
# Analyzing MIDI file: POP909\613\613.mid
# Music time signature: 1/4
# Expected music key: B major
# Music key confidence: 0.8769893663927651
# Other music key alternatives:
# g# minor
# E major
# c# minor
#
# Analyzing MIDI file: POP909\614\614.mid
# Music time signature: 1/4
# Expected music key: c# minor
# Music key confidence: 0.8099802482381775
# Other music key alternatives:
# f# minor
# F# major
# g# minor
# C# major
# E major
#
# Analyzing MIDI file: POP909\615\615.mid
# Music time signature: 1/4
# Expected music key: A major
# Music key confidence: 0.958058703445471
# Other music key alternatives:
# f# minor
# D major
# b minor
# E major
#
# Analyzing MIDI file: POP909\616\616.mid
# Music time signature: 1/4
# Expected music key: c# minor
# Music key confidence: 0.9386667944062632
# Other music key alternatives:
# f# minor
# E major
# B major
# A major
# g# minor
#
# Analyzing MIDI file: POP909\617\617.mid
# Music time signature: 1/4
# Expected music key: B- major
# Music key confidence: 0.9584352201024725
# Other music key alternatives:
# g minor
# c minor
# E- major
# F major
#
# Analyzing MIDI file: POP909\618\618.mid
# Music time signature: 1/4
# Expected music key: F# major
# Music key confidence: 0.9164614095109798
# Other music key alternatives:
# B major
# e- minor
# g# minor
# C# major
# c# minor
#
# Analyzing MIDI file: POP909\619\619.mid
# Music time signature: 1/4
# Expected music key: D major
# Music key confidence: 0.7942953029534122
# Other music key alternatives:
# G major
# b minor
# e minor
#
# Analyzing MIDI file: POP909\620\620.mid
# Music time signature: 1/4
# Expected music key: C# major
# Music key confidence: 0.9109161815306276
# Other music key alternatives:
# A- major
# b- minor
# F# major
# f minor
# e- minor
# g# minor
#
# Analyzing MIDI file: POP909\621\621.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.8655782298084344
# Other music key alternatives:
# a minor
# G major
# F major
# d minor
# g minor
# c minor
#
# Analyzing MIDI file: POP909\622\622.mid
# Music time signature: 1/4
# Expected music key: c# minor
# Music key confidence: 0.8837486091383498
# Other music key alternatives:
# E major
# B major
# g# minor
# f# minor
# F# major
#
# Analyzing MIDI file: POP909\623\623.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.8047080599832829
# Other music key alternatives:
# d minor
# a minor
# G major
# F major
# e minor
# D major
#
# Analyzing MIDI file: POP909\624\624.mid
# Music time signature: 1/4
# Expected music key: b minor
# Music key confidence: 0.8552889759332813
# Other music key alternatives:
# e minor
# E major
# B major
#
# Analyzing MIDI file: POP909\625\625.mid
# Music time signature: 1/4
# Expected music key: e minor
# Music key confidence: 0.8329547762118124
# Other music key alternatives:
# a minor
# b minor
# G major
# C major
# D major
# A major
#
# Analyzing MIDI file: POP909\626\626.mid
# Music time signature: 1/4
# Expected music key: C major
# Music key confidence: 0.9052994884268615
# Other music key alternatives:
# G major
# a minor
# g minor
# d minor
# F major
#
# Analyzing MIDI file: POP909\627\627.mid
# Music time signature: 1/4
# Expected music key: d minor
# Music key confidence: 0.9012208878574404
# Other music key alternatives:
# g minor
# F major
# C major
# G major
# a minor
# B- major
#
# Analyzing MIDI file: POP909\628\628.mid
# Music time signature: 1/4
# Expected music key: E major
# Music key confidence: 0.8475775747637072
# Other music key alternatives:
# A major
# c# minor
# f# minor
# e minor
# b minor
#
# Analyzing MIDI file: POP909\629\629.mid
# Music time signature: 1/4
# Expected music key: g minor
# Music key confidence: 0.8519034550642709
# Other music key alternatives:
# d minor
# F major
# B- major
# C major
# c minor
# a minor
#
# Analyzing MIDI file: POP909\630\630.mid
# Music time signature: 1/4
# Expected music key: f minor
# Music key confidence: 0.9012004417038169
# Other music key alternatives:
# A- major
# b- minor
# c minor
# E- major
# C# major
#
# Analyzing MIDI file: POP909\631\631.mid
# Music time signature: 1/4
# Expected music key: C# major
# Music key confidence: 0.848593502736669
# Other music key alternatives:
# e- minor
# F# major
# g# minor
# b- minor
# A- major
#
# Analyzing MIDI file: POP909\632\632.mid
# Music time signature: 1/4
# Expected music key: g# minor
# Music key confidence: 0.8821016099492653
# Other music key alternatives:
# B major
# c# minor
# E major
#
# Analyzing MIDI file: POP909\633\633.mid
# Music time signature: 1/4
# Expected music key: E major
# Music key confidence: 0.9038904754936627
# Other music key alternatives:
# c# minor
# A major
#
# Analyzing MIDI file: POP909\634\634.mid
# Music time signature: 1/4
# Expected music key: b- minor
# Music key confidence: 0.8379428842286999
# Other music key alternatives:
# f minor
# E- major
# e- minor
# B- major
#
# Analyzing MIDI file: POP909\635\635.mid
# Music time signature: 1/4
# Expected music key: f# minor
# Music key confidence: 0.858614707467838
# Other music key alternatives:
# b minor
# D major
# A major
# E major
# B major
#
# Analyzing MIDI file: POP909\636\636.mid
# Music time signature: 1/4
# Expected music key: f# minor
# Music key confidence: 0.9568689107315599
# Other music key alternatives:
# A major
# b minor
# E major
# D major
# c# minor
#
# Analyzing MIDI file: POP909\637\637.mid
# Music time signature: 1/4
# Expected music key: B major
# Music key confidence: 0.8984296643454326
# Other music key alternatives:
# F# major
# g# minor
# E major
# f# minor
# c# minor
#
# Analyzing MIDI file: POP909\638\638.mid
# Music time signature: 1/4
# Expected music key: F major
# Music key confidence: 0.9119860493887185
# Other music key alternatives:
# d minor
# C major
# g minor
# c minor
# B- major
#
# Analyzing MIDI file: POP909\639\639.mid
# Music time signature: 1/4
# Expected music key: E major
# Music key confidence: 0.9334499422659222
# Other music key alternatives:
# A major
# c# minor
# f# minor
# B major
# b minor
#
# Analyzing MIDI file: POP909\640\640.mid
# Music time signature: 1/4
# Expected music key: D major
# Music key confidence: 0.8949972846861461
# Other music key alternatives:
# b minor
# A major
# G major
# a minor
# e minor
#
# Analyzing MIDI file: POP909\641\641.mid
# Music time signature: 1/4
# Expected music key: A major
# Music key confidence: 0.9168693725364501
# Other music key alternatives:
# b minor
# D major
# e minor
# f# minor
# E major
# a minor
#
# Analyzing MIDI file: POP909\642\642.mid
# Music time signature: 1/4
# Expected music key: b- minor
# Music key confidence: 0.8386187333840583
# Other music key alternatives:
# A- major
# C# major
# e- minor
# F# major
# g# minor
# f minor
# E- major
#
# Analyzing MIDI file: POP909\643\643.mid
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 35
#      32                 analyze_midi_file(file_path)
#      34 # Replace 'your_root_folder' with the path to the folder containing subfolders with MIDI files
# ---> 35 analyze_midi_folder('POP909')
#
# Cell In[26], line 32, in analyze_midi_folder(root_folder)
#      30 file_path = os.path.join(root, file)
#      31 print(f"\nAnalyzing MIDI file: {file_path}")
# ---> 32 analyze_midi_file(file_path)
#
# Cell In[26], line 9, in analyze_midi_file(file_path)
#       6 midi_data = converter.parse(file_path)
#       8 # Extract key and time signature
# ----> 9 key_signature = midi_data.analyze('key')
#      10 time_signature = midi_data.getTimeSignatures()[0]
#      12 # Print results
#
# File ~\anaconda3\lib\site-packages\music21\stream\base.py:3424, in Stream.analyze(self, method, **keywords)
#    3422 from music21.analysis import discrete
#    3423 # pass this stream to the analysis procedure
# -> 3424 return discrete.analyzeStream(self, method, **keywords)
#
# File ~\anaconda3\lib\site-packages\music21\analysis\discrete.py:1336, in analyzeStream(streamObj, method, **keywords)
#    1334     obj = analysisClassName()
#    1335     # environLocal.printDebug(['analysis method used:', obj])
# -> 1336     return obj.getSolution(streamObj)
#    1338 # if no match raise error
#    1339 raise DiscreteAnalysisException(f'no such analysis method: {method}')
#
# File ~\anaconda3\lib\site-packages\music21\analysis\discrete.py:703, in KeyWeightKeyAnalysis.getSolution(self, sStream)
#     684 '''
#     685 Return a music21 Key object defining the results of the analysis.
#     686 Do not call process before calling this method, as this method calls process.
#    (...)
#     700 <music21.key.Key of B- major>
#     701 '''
#     702 # always take a flat version here, otherwise likely to get nothing
# --> 703 solution, unused_color = self.process(sStream.flatten(), storeAlternatives=True)
#     704 # assign best solution
#     705 k = self._solutionToObject(solution)
#
# File ~\anaconda3\lib\site-packages\music21\analysis\discrete.py:618, in KeyWeightKeyAnalysis.process(self, sStream, storeAlternatives)
#     605 def process(self, sStream, storeAlternatives=False):
#     606     '''
#     607     Takes in a Stream or sub-Stream and performs analysis
#     608     on all contents of the Stream. The
#    (...)
#     616     (as a string), and a correlation value (degree of certainty)
#     617     '''
# --> 618     sStream = sStream.flatten().notesAndRests
#     619     # this is the sample distribution used in the paper, for some testing purposes
#     620     # pcDistribution = [7, 0, 5, 0, 7, 16, 0, 16, 0, 15, 6, 0]
#     621
#     622     # this is the distribution for the melody of "happy birthday"
#     623     # pcDistribution = [9, 0, 3, 0, 2, 5, 0, 2, 0, 2, 2, 0]
#     625     likelyKeysMajor, likelyKeysMinor = self._likelyKeys(sStream)
#
# File ~\anaconda3\lib\site-packages\music21\stream\base.py:7772, in Stream.flatten(self, retainContainers)
#    7770     if e.isStream and not retainContainers:
#    7771         continue
# -> 7772     sNew.coreInsert(ri.currentHierarchyOffset(),
#    7773                      e,
#    7774                      setActiveSite=False)
#    7775 if not retainContainers:
#    7776     sNew.isFlat = True
#
# File ~\anaconda3\lib\site-packages\music21\stream\iterator.py:2004, in RecursiveIterator.currentHierarchyOffset(self)
#    2002     return common.opFrac(lastStartOffset)
#    2003 else:
# -> 2004     return common.opFrac(lastStartOffset + lastStream.elementOffset(lastYield))
#
# File ~\anaconda3\lib\site-packages\music21\common\numberTools.py:308, in opFrac(num)
#     305 ir = num.as_integer_ratio()
#     306 if ir[1] > DENOM_LIMIT:  # slightly faster[SIC!] than hard coding 65535!
#     307     # _preFracLimitDenominator uses a cache
# --> 308     return Fraction(*_preFracLimitDenominator(*ir))  # way faster!
#     309     # return Fraction(*ir).limit_denominator(DENOM_LIMIT) # *ir instead of float--can happen
#     310     # internally in Fraction constructor, but is twice as fast...
#     311 else:
#     312     return num
#
# KeyboardInterrupt:

# %% [markdown]
# # Following on from the above code. make a graph of the output and find the mode expected key signature

# %% [markdown]
# The below block takes a long time to run.

# %%
#MODE
from music21 import converter, key, meter
import os
import statistics
import matplotlib.pyplot as plt

def analyze_midi_file(file_path):
    try:
        # Load MIDI file
        midi_data = converter.parse(file_path)

        # Extract key and time signature
        key_signature = midi_data.analyze('key')
        time_signatures = [event.numerator / event.denominator for event in midi_data.flat.getElementsByClass(meter.TimeSignature)]
        
        return time_signatures, key_signature

    except Exception as e:
        print(f"Error analyzing {file_path}: {e}")
        return None, None

def analyze_midi_folder(root_folder):
    results = {'TimeSignatures': [], 'ExpectedKey': []}

    for root, dirs, files in os.walk(root_folder):
        for file in files:
            if file.lower().endswith(".mid") or file.lower().endswith(".midi"):
                file_path = os.path.join(root, file)
                print(f"\nAnalyzing MIDI file: {file_path}")
                time_signatures, key_signature = analyze_midi_file(file_path)

                if time_signatures is not None and key_signature is not None:
                    results['TimeSignatures'].extend(time_signatures)
                    results['ExpectedKey'].append(str(key_signature))

    return results

def plot_results(results):
    # Plot time signatures
    plt.figure(figsize=(10, 6))
    plt.hist(results['TimeSignatures'], bins=20, edgecolor='black')
    plt.xlabel('Time Signature')
    plt.ylabel('Frequency')
    plt.title('Distribution of Time Signatures')
    plt.show()

    # Find mode time signature and expected music key
    mode_time_signature = statistics.mode(results['TimeSignatures'])
    expected_music_key = statistics.mode(results['ExpectedKey'])
    print(f"\nMode Time Signature: {mode_time_signature}")
    print(f"Expected Music Key: {expected_music_key}")

# Replace 'your_root_folder' with the path to the folder containing subfolders with MIDI files
analysis_results = analyze_midi_folder('POP909')
plot_results(analysis_results)
# Out:
# Analyzing MIDI file: POP909\001\001.mid
#
# Analyzing MIDI file: POP909\002\002.mid
#
# Analyzing MIDI file: POP909\003\003.mid
#
# Analyzing MIDI file: POP909\004\004.mid
#
# Analyzing MIDI file: POP909\005\005.mid
#
# Analyzing MIDI file: POP909\006\006.mid
#
# Analyzing MIDI file: POP909\007\007.mid
#
# Analyzing MIDI file: POP909\008\008.mid
#
# Analyzing MIDI file: POP909\009\009.mid
#
# Analyzing MIDI file: POP909\010\010.mid
#
# Analyzing MIDI file: POP909\011\011.mid
#
# Analyzing MIDI file: POP909\012\012.mid
#
# Analyzing MIDI file: POP909\013\013.mid
#
# Analyzing MIDI file: POP909\014\014.mid
#
# Analyzing MIDI file: POP909\015\015.mid
#
# Analyzing MIDI file: POP909\016\016.mid
#
# Analyzing MIDI file: POP909\017\017.mid
#
# Analyzing MIDI file: POP909\018\018.mid
#
# Analyzing MIDI file: POP909\019\019.mid
#
# Analyzing MIDI file: POP909\020\020.mid
#
# Analyzing MIDI file: POP909\021\021.mid
#
# Analyzing MIDI file: POP909\022\022.mid
#
# Analyzing MIDI file: POP909\023\023.mid
#
# Analyzing MIDI file: POP909\024\024.mid
#
# Analyzing MIDI file: POP909\025\025.mid
#
# Analyzing MIDI file: POP909\026\026.mid
#
# Analyzing MIDI file: POP909\027\027.mid
#
# Analyzing MIDI file: POP909\028\028.mid
#
# Analyzing MIDI file: POP909\029\029.mid
#
# Analyzing MIDI file: POP909\030\030.mid
#
# Analyzing MIDI file: POP909\031\031.mid
#
# Analyzing MIDI file: POP909\032\032.mid
#
# Analyzing MIDI file: POP909\033\033.mid
#
# Analyzing MIDI file: POP909\034\034.mid
#
# Analyzing MIDI file: POP909\035\035.mid
#
# Analyzing MIDI file: POP909\036\036.mid
#
# Analyzing MIDI file: POP909\037\037.mid
#
# Analyzing MIDI file: POP909\038\038.mid
#
# Analyzing MIDI file: POP909\039\039.mid
#
# Analyzing MIDI file: POP909\040\040.mid
#
# Analyzing MIDI file: POP909\041\041.mid
#
# Analyzing MIDI file: POP909\042\042.mid
#
# Analyzing MIDI file: POP909\043\043.mid
#
# Analyzing MIDI file: POP909\044\044.mid
#
# Analyzing MIDI file: POP909\045\045.mid
#
# Analyzing MIDI file: POP909\046\046.mid
#
# Analyzing MIDI file: POP909\047\047.mid
#
# Analyzing MIDI file: POP909\048\048.mid
# Error analyzing POP909\048\048.mid: 2469568004832
#
# Analyzing MIDI file: POP909\049\049.mid
#
# Analyzing MIDI file: POP909\050\050.mid
#
# Analyzing MIDI file: POP909\051\051.mid
#
# Analyzing MIDI file: POP909\052\052.mid
#
# Analyzing MIDI file: POP909\053\053.mid
#
# Analyzing MIDI file: POP909\054\054.mid
#
# Analyzing MIDI file: POP909\055\055.mid
#
# Analyzing MIDI file: POP909\056\056.mid
#
# Analyzing MIDI file: POP909\057\057.mid
#
# Analyzing MIDI file: POP909\058\058.mid
#
# Analyzing MIDI file: POP909\059\059.mid
#
# Analyzing MIDI file: POP909\060\060.mid
#
# Analyzing MIDI file: POP909\061\061.mid
#
# Analyzing MIDI file: POP909\062\062.mid
#
# Analyzing MIDI file: POP909\063\063.mid
#
# Analyzing MIDI file: POP909\064\064.mid
#
# Analyzing MIDI file: POP909\065\065.mid
#
# Analyzing MIDI file: POP909\066\066.mid
#
# Analyzing MIDI file: POP909\067\067.mid
#
# Analyzing MIDI file: POP909\068\068.mid
#
# Analyzing MIDI file: POP909\069\069.mid
#
# Analyzing MIDI file: POP909\070\070.mid
#
# Analyzing MIDI file: POP909\071\071.mid
# Error analyzing POP909\071\071.mid: 2469551821680
#
# Analyzing MIDI file: POP909\072\072.mid
# Error analyzing POP909\072\072.mid: 2469568150640
#
# Analyzing MIDI file: POP909\073\073.mid
#
# Analyzing MIDI file: POP909\074\074.mid
#
# Analyzing MIDI file: POP909\075\075.mid
#
# Analyzing MIDI file: POP909\076\076.mid
#
# Analyzing MIDI file: POP909\077\077.mid
# Error analyzing POP909\077\077.mid: 2469533107488
#
# Analyzing MIDI file: POP909\078\078.mid
#
# Analyzing MIDI file: POP909\079\079.mid
#
# Analyzing MIDI file: POP909\080\080.mid
#
# Analyzing MIDI file: POP909\081\081.mid
#
# Analyzing MIDI file: POP909\082\082.mid
#
# Analyzing MIDI file: POP909\083\083.mid
#
# Analyzing MIDI file: POP909\084\084.mid
#
# Analyzing MIDI file: POP909\085\085.mid
#
# Analyzing MIDI file: POP909\086\086.mid
#
# Analyzing MIDI file: POP909\087\087.mid
#
# Analyzing MIDI file: POP909\088\088.mid
#
# Analyzing MIDI file: POP909\089\089.mid
#
# Analyzing MIDI file: POP909\090\090.mid
#
# Analyzing MIDI file: POP909\091\091.mid
#
# Analyzing MIDI file: POP909\092\092.mid
#
# Analyzing MIDI file: POP909\093\093.mid
#
# Analyzing MIDI file: POP909\094\094.mid
#
# Analyzing MIDI file: POP909\095\095.mid
#
# Analyzing MIDI file: POP909\096\096.mid
#
# Analyzing MIDI file: POP909\097\097.mid
#
# Analyzing MIDI file: POP909\098\098.mid
#
# Analyzing MIDI file: POP909\099\099.mid
#
# Analyzing MIDI file: POP909\100\100.mid
#
# Analyzing MIDI file: POP909\101\101.mid
#
# Analyzing MIDI file: POP909\102\102.mid
# Error analyzing POP909\102\102.mid: 2469557565856
#
# Analyzing MIDI file: POP909\103\103.mid
#
# Analyzing MIDI file: POP909\104\104.mid
#
# Analyzing MIDI file: POP909\105\105.mid
#
# Analyzing MIDI file: POP909\106\106.mid
#
# Analyzing MIDI file: POP909\107\107.mid
#
# Analyzing MIDI file: POP909\108\108.mid
#
# Analyzing MIDI file: POP909\109\109.mid
#
# Analyzing MIDI file: POP909\110\110.mid
#
# Analyzing MIDI file: POP909\111\111.mid
#
# Analyzing MIDI file: POP909\112\112.mid
#
# Analyzing MIDI file: POP909\113\113.mid
#
# Analyzing MIDI file: POP909\114\114.mid
#
# Analyzing MIDI file: POP909\115\115.mid
#
# Analyzing MIDI file: POP909\116\116.mid
#
# Analyzing MIDI file: POP909\117\117.mid
#
# Analyzing MIDI file: POP909\118\118.mid
#
# Analyzing MIDI file: POP909\119\119.mid
#
# Analyzing MIDI file: POP909\120\120.mid
#
# Analyzing MIDI file: POP909\121\121.mid
#
# Analyzing MIDI file: POP909\122\122.mid
#
# Analyzing MIDI file: POP909\123\123.mid
#
# Analyzing MIDI file: POP909\124\124.mid
#
# Analyzing MIDI file: POP909\125\125.mid
#
# Analyzing MIDI file: POP909\126\126.mid
#
# Analyzing MIDI file: POP909\127\127.mid
#
# Analyzing MIDI file: POP909\128\128.mid
#
# Analyzing MIDI file: POP909\129\129.mid
#
# Analyzing MIDI file: POP909\130\130.mid
#
# Analyzing MIDI file: POP909\131\131.mid
#
# Analyzing MIDI file: POP909\132\132.mid
#
# Analyzing MIDI file: POP909\133\133.mid
#
# Analyzing MIDI file: POP909\134\134.mid
#
# Analyzing MIDI file: POP909\135\135.mid
#
# Analyzing MIDI file: POP909\136\136.mid
#
# Analyzing MIDI file: POP909\137\137.mid
#
# Analyzing MIDI file: POP909\138\138.mid
#
# Analyzing MIDI file: POP909\139\139.mid
#
# Analyzing MIDI file: POP909\140\140.mid
#
# Analyzing MIDI file: POP909\141\141.mid
#
# Analyzing MIDI file: POP909\142\142.mid
#
# Analyzing MIDI file: POP909\143\143.mid
#
# Analyzing MIDI file: POP909\144\144.mid
#
# Analyzing MIDI file: POP909\145\145.mid
#
# Analyzing MIDI file: POP909\146\146.mid
#
# Analyzing MIDI file: POP909\147\147.mid
#
# Analyzing MIDI file: POP909\148\148.mid
#
# Analyzing MIDI file: POP909\149\149.mid
#
# Analyzing MIDI file: POP909\150\150.mid
#
# Analyzing MIDI file: POP909\151\151.mid
#
# Analyzing MIDI file: POP909\152\152.mid
#
# Analyzing MIDI file: POP909\153\153.mid
#
# Analyzing MIDI file: POP909\154\154.mid
#
# Analyzing MIDI file: POP909\155\155.mid
#
# Analyzing MIDI file: POP909\156\156.mid
#
# Analyzing MIDI file: POP909\157\157.mid
#
# Analyzing MIDI file: POP909\158\158.mid
#
# Analyzing MIDI file: POP909\159\159.mid
#
# Analyzing MIDI file: POP909\160\160.mid
#
# Analyzing MIDI file: POP909\161\161.mid
#
# Analyzing MIDI file: POP909\162\162.mid
#
# Analyzing MIDI file: POP909\163\163.mid
#
# Analyzing MIDI file: POP909\164\164.mid
#
# Analyzing MIDI file: POP909\165\165.mid
#
# Analyzing MIDI file: POP909\166\166.mid
#
# Analyzing MIDI file: POP909\167\167.mid
#
# Analyzing MIDI file: POP909\168\168.mid
#
# Analyzing MIDI file: POP909\169\169.mid
#
# Analyzing MIDI file: POP909\170\170.mid
#
# Analyzing MIDI file: POP909\171\171.mid
#
# Analyzing MIDI file: POP909\172\172.mid
#
# Analyzing MIDI file: POP909\173\173.mid
#
# Analyzing MIDI file: POP909\174\174.mid
#
# Analyzing MIDI file: POP909\175\175.mid
#
# Analyzing MIDI file: POP909\176\176.mid
#
# Analyzing MIDI file: POP909\177\177.mid
#
# Analyzing MIDI file: POP909\178\178.mid
#
# Analyzing MIDI file: POP909\179\179.mid
#
# Analyzing MIDI file: POP909\180\180.mid
#
# Analyzing MIDI file: POP909\181\181.mid
#
# Analyzing MIDI file: POP909\182\182.mid
#
# Analyzing MIDI file: POP909\183\183.mid
#
# Analyzing MIDI file: POP909\184\184.mid
#
# Analyzing MIDI file: POP909\185\185.mid
#
# Analyzing MIDI file: POP909\186\186.mid
#
# Analyzing MIDI file: POP909\187\187.mid
#
# Analyzing MIDI file: POP909\188\188.mid
#
# Analyzing MIDI file: POP909\189\189.mid
#
# Analyzing MIDI file: POP909\190\190.mid
#
# Analyzing MIDI file: POP909\191\191.mid
#
# Analyzing MIDI file: POP909\192\192.mid
#
# Analyzing MIDI file: POP909\193\193.mid
#
# Analyzing MIDI file: POP909\194\194.mid
# Analyzing MIDI file: POP909\195\195.mid
#
# Analyzing MIDI file: POP909\196\196.mid
#
# Analyzing MIDI file: POP909\197\197.mid
#
# Analyzing MIDI file: POP909\198\198.mid
#
# Analyzing MIDI file: POP909\199\199.mid
#
# Analyzing MIDI file: POP909\200\200.mid
#
# Analyzing MIDI file: POP909\201\201.mid
#
# Analyzing MIDI file: POP909\202\202.mid
#
# Analyzing MIDI file: POP909\203\203.mid
#
# Analyzing MIDI file: POP909\204\204.mid
#
# Analyzing MIDI file: POP909\205\205.mid
#
# Analyzing MIDI file: POP909\206\206.mid
#
# Analyzing MIDI file: POP909\207\207.mid
#
# Analyzing MIDI file: POP909\208\208.mid
#
# Analyzing MIDI file: POP909\209\209.mid
#
# Analyzing MIDI file: POP909\210\210.mid
#
# Analyzing MIDI file: POP909\211\211.mid
#
# Analyzing MIDI file: POP909\212\212.mid
#
# Analyzing MIDI file: POP909\213\213.mid
#
# Analyzing MIDI file: POP909\214\214.mid
#
# Analyzing MIDI file: POP909\215\215.mid
#
# Analyzing MIDI file: POP909\216\216.mid
#
# Analyzing MIDI file: POP909\217\217.mid
#
# Analyzing MIDI file: POP909\218\218.mid
#
# Analyzing MIDI file: POP909\219\219.mid
#
# Analyzing MIDI file: POP909\220\220.mid
#
# Analyzing MIDI file: POP909\221\221.mid
#
# Analyzing MIDI file: POP909\222\222.mid
#
# Analyzing MIDI file: POP909\223\223.mid
#
# Analyzing MIDI file: POP909\224\224.mid
#
# Analyzing MIDI file: POP909\225\225.mid
#
# Analyzing MIDI file: POP909\226\226.mid
#
# Analyzing MIDI file: POP909\227\227.mid
#
# Analyzing MIDI file: POP909\228\228.mid
#
# Analyzing MIDI file: POP909\229\229.mid
#
# Analyzing MIDI file: POP909\230\230.mid
#
# Analyzing MIDI file: POP909\231\231.mid
#
# Analyzing MIDI file: POP909\232\232.mid
#
# Analyzing MIDI file: POP909\233\233.mid
#
# Analyzing MIDI file: POP909\234\234.mid
#
# Analyzing MIDI file: POP909\235\235.mid
#
# Analyzing MIDI file: POP909\236\236.mid
#
# Analyzing MIDI file: POP909\237\237.mid
#
# Analyzing MIDI file: POP909\238\238.mid
#
# Analyzing MIDI file: POP909\239\239.mid
#
# Analyzing MIDI file: POP909\240\240.mid
#
# Analyzing MIDI file: POP909\241\241.mid
#
# Analyzing MIDI file: POP909\242\242.mid
#
# Analyzing MIDI file: POP909\243\243.mid
#
# Analyzing MIDI file: POP909\244\244.mid
#
# Analyzing MIDI file: POP909\245\245.mid
#
# Analyzing MIDI file: POP909\246\246.mid
#
# Analyzing MIDI file: POP909\247\247.mid
#
# Analyzing MIDI file: POP909\248\248.mid
#
# Analyzing MIDI file: POP909\249\249.mid
#
# Analyzing MIDI file: POP909\250\250.mid
#
# Analyzing MIDI file: POP909\251\251.mid
#
# Analyzing MIDI file: POP909\252\252.mid
#
# Analyzing MIDI file: POP909\253\253.mid
#
# Analyzing MIDI file: POP909\254\254.mid
#
# Analyzing MIDI file: POP909\255\255.mid
#
# Analyzing MIDI file: POP909\256\256.mid
#
# Analyzing MIDI file: POP909\257\257.mid
#
# Analyzing MIDI file: POP909\258\258.mid
#
# Analyzing MIDI file: POP909\259\259.mid
#
# Analyzing MIDI file: POP909\260\260.mid
#
# Analyzing MIDI file: POP909\261\261.mid
#
# Analyzing MIDI file: POP909\262\262.mid
#
# Analyzing MIDI file: POP909\263\263.mid
#
# Analyzing MIDI file: POP909\264\264.mid
#
# Analyzing MIDI file: POP909\265\265.mid
#
# Analyzing MIDI file: POP909\266\266.mid
#
# Analyzing MIDI file: POP909\267\267.mid
#
# Analyzing MIDI file: POP909\268\268.mid
#
# Analyzing MIDI file: POP909\269\269.mid
#
# Analyzing MIDI file: POP909\270\270.mid
#
# Analyzing MIDI file: POP909\271\271.mid
#
# Analyzing MIDI file: POP909\272\272.mid
#
# Analyzing MIDI file: POP909\273\273.mid
#
# Analyzing MIDI file: POP909\274\274.mid
#
# Analyzing MIDI file: POP909\275\275.mid
#
# Analyzing MIDI file: POP909\276\276.mid
#
# Analyzing MIDI file: POP909\277\277.mid
#
# Analyzing MIDI file: POP909\278\278.mid
#
# Analyzing MIDI file: POP909\279\279.mid
#
# Analyzing MIDI file: POP909\280\280.mid
#
# Analyzing MIDI file: POP909\281\281.mid
#
# Analyzing MIDI file: POP909\282\282.mid
#
# Analyzing MIDI file: POP909\283\283.mid
#
# Analyzing MIDI file: POP909\284\284.mid
#
# Analyzing MIDI file: POP909\285\285.mid
#
# Analyzing MIDI file: POP909\286\286.mid
#
# Analyzing MIDI file: POP909\287\287.mid
#
# Analyzing MIDI file: POP909\288\288.mid
#
# Analyzing MIDI file: POP909\289\289.mid
#
# Analyzing MIDI file: POP909\290\290.mid
#
# Analyzing MIDI file: POP909\291\291.mid
#
# Analyzing MIDI file: POP909\292\292.mid
#
# Analyzing MIDI file: POP909\293\293.mid
#
# Analyzing MIDI file: POP909\294\294.mid
#
# Analyzing MIDI file: POP909\295\295.mid
#
# Analyzing MIDI file: POP909\296\296.mid
#
# Analyzing MIDI file: POP909\297\297.mid
#
# Analyzing MIDI file: POP909\298\298.mid
#
# Analyzing MIDI file: POP909\299\299.mid
#
# Analyzing MIDI file: POP909\300\300.mid
#
# Analyzing MIDI file: POP909\301\301.mid
#
# Analyzing MIDI file: POP909\302\302.mid
#
# Analyzing MIDI file: POP909\303\303.mid
#
# Analyzing MIDI file: POP909\304\304.mid
#
# Analyzing MIDI file: POP909\305\305.mid
#
# Analyzing MIDI file: POP909\306\306.mid
#
# Analyzing MIDI file: POP909\307\307.mid
#
# Analyzing MIDI file: POP909\308\308.mid
#
# Analyzing MIDI file: POP909\309\309.mid
#
# Analyzing MIDI file: POP909\310\310.mid
#
# Analyzing MIDI file: POP909\311\311.mid
#
# Analyzing MIDI file: POP909\312\312.mid
#
# Analyzing MIDI file: POP909\313\313.mid
#
# Analyzing MIDI file: POP909\314\314.mid
#
# Analyzing MIDI file: POP909\315\315.mid
#
# Analyzing MIDI file: POP909\316\316.mid
#
# Analyzing MIDI file: POP909\317\317.mid
#
# Analyzing MIDI file: POP909\318\318.mid
#
# Analyzing MIDI file: POP909\319\319.mid
#
# Analyzing MIDI file: POP909\320\320.mid
# Error analyzing POP909\320\320.mid: 2469528336944
#
# Analyzing MIDI file: POP909\321\321.mid
#
# Analyzing MIDI file: POP909\322\322.mid
#
# Analyzing MIDI file: POP909\323\323.mid
#
# Analyzing MIDI file: POP909\324\324.mid
#
# Analyzing MIDI file: POP909\325\325.mid
#
# Analyzing MIDI file: POP909\326\326.mid
#
# Analyzing MIDI file: POP909\327\327.mid
#
# Analyzing MIDI file: POP909\328\328.mid
#
# Analyzing MIDI file: POP909\329\329.mid
#
# Analyzing MIDI file: POP909\330\330.mid
#
# Analyzing MIDI file: POP909\331\331.mid
#
# Analyzing MIDI file: POP909\332\332.mid
#
# Analyzing MIDI file: POP909\333\333.mid
#
# Analyzing MIDI file: POP909\334\334.mid
#
# Analyzing MIDI file: POP909\335\335.mid
#
# Analyzing MIDI file: POP909\336\336.mid
#
# Analyzing MIDI file: POP909\337\337.mid
#
# Analyzing MIDI file: POP909\338\338.mid
#
# Analyzing MIDI file: POP909\339\339.mid
#
# Analyzing MIDI file: POP909\340\340.mid
#
# Analyzing MIDI file: POP909\341\341.mid
#
# Analyzing MIDI file: POP909\342\342.mid
#
# Analyzing MIDI file: POP909\343\343.mid
#
# Analyzing MIDI file: POP909\344\344.mid
#
# Analyzing MIDI file: POP909\345\345.mid
#
# Analyzing MIDI file: POP909\346\346.mid
#
# Analyzing MIDI file: POP909\347\347.mid
#
# Analyzing MIDI file: POP909\348\348.mid
#
# Analyzing MIDI file: POP909\349\349.mid
#
# Analyzing MIDI file: POP909\350\350.mid
#
# Analyzing MIDI file: POP909\351\351.mid
#
# Analyzing MIDI file: POP909\352\352.mid
#
# Analyzing MIDI file: POP909\353\353.mid
#
# Analyzing MIDI file: POP909\354\354.mid
#
# Analyzing MIDI file: POP909\355\355.mid
#
# Analyzing MIDI file: POP909\356\356.mid
#
# Analyzing MIDI file: POP909\357\357.mid
#
# Analyzing MIDI file: POP909\358\358.mid
#
# Analyzing MIDI file: POP909\359\359.mid
#
# Analyzing MIDI file: POP909\360\360.mid
#
# Analyzing MIDI file: POP909\361\361.mid
#
# Analyzing MIDI file: POP909\362\362.mid
#
# Analyzing MIDI file: POP909\363\363.mid
#
# Analyzing MIDI file: POP909\364\364.mid
#
# Analyzing MIDI file: POP909\365\365.mid
#
# Analyzing MIDI file: POP909\366\366.mid
#
# Analyzing MIDI file: POP909\367\367.mid
#
# Analyzing MIDI file: POP909\368\368.mid
#
# Analyzing MIDI file: POP909\369\369.mid
#
# Analyzing MIDI file: POP909\370\370.mid
#
# Analyzing MIDI file: POP909\371\371.mid
#
# Analyzing MIDI file: POP909\372\372.mid
# Error analyzing POP909\372\372.mid: 2469527579040
#
# Analyzing MIDI file: POP909\373\373.mid
#
# Analyzing MIDI file: POP909\374\374.mid
#
# Analyzing MIDI file: POP909\375\375.mid
#
# Analyzing MIDI file: POP909\376\376.mid
#
# Analyzing MIDI file: POP909\377\377.mid
#
# Analyzing MIDI file: POP909\378\378.mid
#
# Analyzing MIDI file: POP909\379\379.mid
#
# Analyzing MIDI file: POP909\380\380.mid
#
# Analyzing MIDI file: POP909\381\381.mid
#
# Analyzing MIDI file: POP909\382\382.mid
#
# Analyzing MIDI file: POP909\383\383.mid
#
# Analyzing MIDI file: POP909\384\384.mid
#
# Analyzing MIDI file: POP909\385\385.mid
#
# Analyzing MIDI file: POP909\386\386.mid
#
# Analyzing MIDI file: POP909\387\387.mid
#
# Analyzing MIDI file: POP909\388\388.mid
#
# Analyzing MIDI file: POP909\389\389.mid
#
# Analyzing MIDI file: POP909\390\390.mid
#
# Analyzing MIDI file: POP909\391\391.mid
#
# Analyzing MIDI file: POP909\392\392.mid
# Analyzing MIDI file: POP909\393\393.mid
#
# Analyzing MIDI file: POP909\394\394.mid
#
# Analyzing MIDI file: POP909\395\395.mid
#
# Analyzing MIDI file: POP909\396\396.mid
#
# Analyzing MIDI file: POP909\397\397.mid
#
# Analyzing MIDI file: POP909\398\398.mid
#
# Analyzing MIDI file: POP909\399\399.mid
#
# Analyzing MIDI file: POP909\400\400.mid
#
# Analyzing MIDI file: POP909\401\401.mid
#
# Analyzing MIDI file: POP909\402\402.mid
#
# Analyzing MIDI file: POP909\403\403.mid
#
# Analyzing MIDI file: POP909\404\404.mid
#
# Analyzing MIDI file: POP909\405\405.mid
#
# Analyzing MIDI file: POP909\406\406.mid
#
# Analyzing MIDI file: POP909\407\407.mid
#
# Analyzing MIDI file: POP909\408\408.mid
# Error analyzing POP909\408\408.mid: 2469531091440
#
# Analyzing MIDI file: POP909\409\409.mid
#
# Analyzing MIDI file: POP909\410\410.mid
#
# Analyzing MIDI file: POP909\411\411.mid
#
# Analyzing MIDI file: POP909\412\412.mid
#
# Analyzing MIDI file: POP909\413\413.mid
#
# Analyzing MIDI file: POP909\414\414.mid
#
# Analyzing MIDI file: POP909\415\415.mid
#
# Analyzing MIDI file: POP909\416\416.mid
#
# Analyzing MIDI file: POP909\417\417.mid
#
# Analyzing MIDI file: POP909\418\418.mid
#
# Analyzing MIDI file: POP909\419\419.mid
#
# Analyzing MIDI file: POP909\420\420.mid
#
# Analyzing MIDI file: POP909\421\421.mid
#
# Analyzing MIDI file: POP909\422\422.mid
#
# Analyzing MIDI file: POP909\423\423.mid
#
# Analyzing MIDI file: POP909\424\424.mid
#
# Analyzing MIDI file: POP909\425\425.mid
#
# Analyzing MIDI file: POP909\426\426.mid
#
# Analyzing MIDI file: POP909\427\427.mid
#
# Analyzing MIDI file: POP909\428\428.mid
#
# Analyzing MIDI file: POP909\429\429.mid
#
# Analyzing MIDI file: POP909\430\430.mid
#
# Analyzing MIDI file: POP909\431\431.mid
#
# Analyzing MIDI file: POP909\432\432.mid
#
# Analyzing MIDI file: POP909\433\433.mid
#
# Analyzing MIDI file: POP909\434\434.mid
#
# Analyzing MIDI file: POP909\435\435.mid
#
# Analyzing MIDI file: POP909\436\436.mid
#
# Analyzing MIDI file: POP909\437\437.mid
# Error analyzing POP909\437\437.mid: 2469557489968
#
# Analyzing MIDI file: POP909\438\438.mid
#
# Analyzing MIDI file: POP909\439\439.mid
#
# Analyzing MIDI file: POP909\440\440.mid
#
# Analyzing MIDI file: POP909\441\441.mid
#
# Analyzing MIDI file: POP909\442\442.mid
#
# Analyzing MIDI file: POP909\443\443.mid
#
# Analyzing MIDI file: POP909\444\444.mid
#
# Analyzing MIDI file: POP909\445\445.mid
#
# Analyzing MIDI file: POP909\446\446.mid
#
# Analyzing MIDI file: POP909\447\447.mid
#
# Analyzing MIDI file: POP909\448\448.mid
#
# Analyzing MIDI file: POP909\449\449.mid
#
# Analyzing MIDI file: POP909\450\450.mid
#
# Analyzing MIDI file: POP909\451\451.mid
#
# Analyzing MIDI file: POP909\452\452.mid
#
# Analyzing MIDI file: POP909\453\453.mid
#
# Analyzing MIDI file: POP909\454\454.mid
#
# Analyzing MIDI file: POP909\455\455.mid
#
# Analyzing MIDI file: POP909\456\456.mid
#
# Analyzing MIDI file: POP909\457\457.mid
#
# Analyzing MIDI file: POP909\458\458.mid
#
# Analyzing MIDI file: POP909\459\459.mid
#
# Analyzing MIDI file: POP909\460\460.mid
#
# Analyzing MIDI file: POP909\461\461.mid
#
# Analyzing MIDI file: POP909\462\462.mid
#
# Analyzing MIDI file: POP909\463\463.mid
#
# Analyzing MIDI file: POP909\464\464.mid
#
# Analyzing MIDI file: POP909\465\465.mid
#
# Analyzing MIDI file: POP909\466\466.mid
#
# Analyzing MIDI file: POP909\467\467.mid
#
# Analyzing MIDI file: POP909\468\468.mid
#
# Analyzing MIDI file: POP909\469\469.mid
#
# Analyzing MIDI file: POP909\470\470.mid
#
# Analyzing MIDI file: POP909\471\471.mid
#
# Analyzing MIDI file: POP909\472\472.mid
#
# Analyzing MIDI file: POP909\473\473.mid
#
# Analyzing MIDI file: POP909\474\474.mid
#
# Analyzing MIDI file: POP909\475\475.mid
#
# Analyzing MIDI file: POP909\476\476.mid
#
# Analyzing MIDI file: POP909\477\477.mid
#
# Analyzing MIDI file: POP909\478\478.mid
#
# Analyzing MIDI file: POP909\479\479.mid
#
# Analyzing MIDI file: POP909\480\480.mid
#
# Analyzing MIDI file: POP909\481\481.mid
#
# Analyzing MIDI file: POP909\482\482.mid
#
# Analyzing MIDI file: POP909\483\483.mid
#
# Analyzing MIDI file: POP909\484\484.mid
#
# Analyzing MIDI file: POP909\485\485.mid
#
# Analyzing MIDI file: POP909\486\486.mid
#
# Analyzing MIDI file: POP909\487\487.mid
#
# Analyzing MIDI file: POP909\488\488.mid
#
# Analyzing MIDI file: POP909\489\489.mid
#
# Analyzing MIDI file: POP909\490\490.mid
#
# Analyzing MIDI file: POP909\491\491.mid
#
# Analyzing MIDI file: POP909\492\492.mid
#
# Analyzing MIDI file: POP909\493\493.mid
#
# Analyzing MIDI file: POP909\494\494.mid
#
# Analyzing MIDI file: POP909\495\495.mid
#
# Analyzing MIDI file: POP909\496\496.mid
#
# Analyzing MIDI file: POP909\497\497.mid
#
# Analyzing MIDI file: POP909\498\498.mid
#
# Analyzing MIDI file: POP909\499\499.mid
#
# Analyzing MIDI file: POP909\500\500.mid
# Error analyzing POP909\500\500.mid: 2469531679808
#
# Analyzing MIDI file: POP909\501\501.mid
#
# Analyzing MIDI file: POP909\502\502.mid
#
# Analyzing MIDI file: POP909\503\503.mid
# Error analyzing POP909\503\503.mid: 2469522783392
#
# Analyzing MIDI file: POP909\504\504.mid
#
# Analyzing MIDI file: POP909\505\505.mid
#
# Analyzing MIDI file: POP909\506\506.mid
#
# Analyzing MIDI file: POP909\507\507.mid
#
# Analyzing MIDI file: POP909\508\508.mid
#
# Analyzing MIDI file: POP909\509\509.mid
# Error analyzing POP909\509\509.mid: 2469569575424
#
# Analyzing MIDI file: POP909\510\510.mid
#
# Analyzing MIDI file: POP909\511\511.mid
#
# Analyzing MIDI file: POP909\512\512.mid
# Error analyzing POP909\512\512.mid: 2469577690464
#
# Analyzing MIDI file: POP909\513\513.mid
# Error analyzing POP909\513\513.mid: 2469565978320
#
# Analyzing MIDI file: POP909\514\514.mid
#
# Analyzing MIDI file: POP909\515\515.mid
#
# Analyzing MIDI file: POP909\516\516.mid
#
# Analyzing MIDI file: POP909\517\517.mid
#
# Analyzing MIDI file: POP909\518\518.mid
#
# Analyzing MIDI file: POP909\519\519.mid
# Error analyzing POP909\519\519.mid: 2469577756928
#
# Analyzing MIDI file: POP909\520\520.mid
#
# Analyzing MIDI file: POP909\521\521.mid
#
# Analyzing MIDI file: POP909\522\522.mid
#
# Analyzing MIDI file: POP909\523\523.mid
#
# Analyzing MIDI file: POP909\524\524.mid
# Error analyzing POP909\524\524.mid: 2469568048240
#
# Analyzing MIDI file: POP909\525\525.mid
#
# Analyzing MIDI file: POP909\526\526.mid
#
# Analyzing MIDI file: POP909\527\527.mid
#
# Analyzing MIDI file: POP909\528\528.mid
#
# Analyzing MIDI file: POP909\529\529.mid
#
# Analyzing MIDI file: POP909\530\530.mid
#
# Analyzing MIDI file: POP909\531\531.mid
#
# Analyzing MIDI file: POP909\532\532.mid
#
# Analyzing MIDI file: POP909\533\533.mid
#
# Analyzing MIDI file: POP909\534\534.mid
#
# Analyzing MIDI file: POP909\535\535.mid
#
# Analyzing MIDI file: POP909\536\536.mid
#
# Analyzing MIDI file: POP909\537\537.mid
#
# Analyzing MIDI file: POP909\538\538.mid
#
# Analyzing MIDI file: POP909\539\539.mid
#
# Analyzing MIDI file: POP909\540\540.mid
#
# Analyzing MIDI file: POP909\541\541.mid
#
# Analyzing MIDI file: POP909\542\542.mid
#
# Analyzing MIDI file: POP909\543\543.mid
#
# Analyzing MIDI file: POP909\544\544.mid
#
# Analyzing MIDI file: POP909\545\545.mid
#
# Analyzing MIDI file: POP909\546\546.mid
#
# Analyzing MIDI file: POP909\547\547.mid
#
# Analyzing MIDI file: POP909\548\548.mid
#
# Analyzing MIDI file: POP909\549\549.mid
#
# Analyzing MIDI file: POP909\550\550.mid
#
# Analyzing MIDI file: POP909\551\551.mid
#
# Analyzing MIDI file: POP909\552\552.mid
#
# Analyzing MIDI file: POP909\553\553.mid
#
# Analyzing MIDI file: POP909\554\554.mid
#
# Analyzing MIDI file: POP909\555\555.mid
#
# Analyzing MIDI file: POP909\556\556.mid
#
# Analyzing MIDI file: POP909\557\557.mid
#
# Analyzing MIDI file: POP909\558\558.mid
#
# Analyzing MIDI file: POP909\559\559.mid
#
# Analyzing MIDI file: POP909\560\560.mid
#
# Analyzing MIDI file: POP909\561\561.mid
#
# Analyzing MIDI file: POP909\562\562.mid
#
# Analyzing MIDI file: POP909\563\563.mid
# Error analyzing POP909\563\563.mid: 2469573187904
#
# Analyzing MIDI file: POP909\564\564.mid
#
# Analyzing MIDI file: POP909\565\565.mid
#
# Analyzing MIDI file: POP909\566\566.mid
#
# Analyzing MIDI file: POP909\567\567.mid
#
# Analyzing MIDI file: POP909\568\568.mid
#
# Analyzing MIDI file: POP909\569\569.mid
#
# Analyzing MIDI file: POP909\570\570.mid
#
# Analyzing MIDI file: POP909\571\571.mid
#
# Analyzing MIDI file: POP909\572\572.mid
#
# Analyzing MIDI file: POP909\573\573.mid
#
# Analyzing MIDI file: POP909\574\574.mid
#
# Analyzing MIDI file: POP909\575\575.mid
#
# Analyzing MIDI file: POP909\576\576.mid
#
# Analyzing MIDI file: POP909\577\577.mid
#
# Analyzing MIDI file: POP909\578\578.mid
#
# Analyzing MIDI file: POP909\579\579.mid
#
# Analyzing MIDI file: POP909\580\580.mid
# Analyzing MIDI file: POP909\581\581.mid
#
# Analyzing MIDI file: POP909\582\582.mid
#
# Analyzing MIDI file: POP909\583\583.mid
#
# Analyzing MIDI file: POP909\584\584.mid
#
# Analyzing MIDI file: POP909\585\585.mid
#
# Analyzing MIDI file: POP909\586\586.mid
#
# Analyzing MIDI file: POP909\587\587.mid
#
# Analyzing MIDI file: POP909\588\588.mid
#
# Analyzing MIDI file: POP909\589\589.mid
#
# Analyzing MIDI file: POP909\590\590.mid
#
# Analyzing MIDI file: POP909\591\591.mid
#
# Analyzing MIDI file: POP909\592\592.mid
#
# Analyzing MIDI file: POP909\593\593.mid
#
# Analyzing MIDI file: POP909\594\594.mid
#
# Analyzing MIDI file: POP909\595\595.mid
#
# Analyzing MIDI file: POP909\596\596.mid
#
# Analyzing MIDI file: POP909\597\597.mid
#
# Analyzing MIDI file: POP909\598\598.mid
#
# Analyzing MIDI file: POP909\599\599.mid
#
# Analyzing MIDI file: POP909\600\600.mid
#
# Analyzing MIDI file: POP909\601\601.mid
#
# Analyzing MIDI file: POP909\602\602.mid
#
# Analyzing MIDI file: POP909\603\603.mid
#
# Analyzing MIDI file: POP909\604\604.mid
#
# Analyzing MIDI file: POP909\605\605.mid
#
# Analyzing MIDI file: POP909\606\606.mid
#
# Analyzing MIDI file: POP909\607\607.mid
#
# Analyzing MIDI file: POP909\608\608.mid
#
# Analyzing MIDI file: POP909\609\609.mid
#
# Analyzing MIDI file: POP909\610\610.mid
#
# Analyzing MIDI file: POP909\611\611.mid
#
# Analyzing MIDI file: POP909\612\612.mid
#
# Analyzing MIDI file: POP909\613\613.mid
#
# Analyzing MIDI file: POP909\614\614.mid
#
# Analyzing MIDI file: POP909\615\615.mid
#
# Analyzing MIDI file: POP909\616\616.mid
#
# Analyzing MIDI file: POP909\617\617.mid
#
# Analyzing MIDI file: POP909\618\618.mid
#
# Analyzing MIDI file: POP909\619\619.mid
#
# Analyzing MIDI file: POP909\620\620.mid
#
# Analyzing MIDI file: POP909\621\621.mid
#
# Analyzing MIDI file: POP909\622\622.mid
#
# Analyzing MIDI file: POP909\623\623.mid
#
# Analyzing MIDI file: POP909\624\624.mid
#
# Analyzing MIDI file: POP909\625\625.mid
#
# Analyzing MIDI file: POP909\626\626.mid
#
# Analyzing MIDI file: POP909\627\627.mid
#
# Analyzing MIDI file: POP909\628\628.mid
#
# Analyzing MIDI file: POP909\629\629.mid
#
# Analyzing MIDI file: POP909\630\630.mid
#
# Analyzing MIDI file: POP909\631\631.mid
#
# Analyzing MIDI file: POP909\632\632.mid
#
# Analyzing MIDI file: POP909\633\633.mid
#
# Analyzing MIDI file: POP909\634\634.mid
#
# Analyzing MIDI file: POP909\635\635.mid
#
# Analyzing MIDI file: POP909\636\636.mid
#
# Analyzing MIDI file: POP909\637\637.mid
#
# Analyzing MIDI file: POP909\638\638.mid
#
# Analyzing MIDI file: POP909\639\639.mid
#
# Analyzing MIDI file: POP909\640\640.mid
#
# Analyzing MIDI file: POP909\641\641.mid
#
# Analyzing MIDI file: POP909\642\642.mid
#
# Analyzing MIDI file: POP909\643\643.mid
#
# Analyzing MIDI file: POP909\644\644.mid
#
# Analyzing MIDI file: POP909\645\645.mid
#
# Analyzing MIDI file: POP909\646\646.mid
#
# Analyzing MIDI file: POP909\647\647.mid
# Error analyzing POP909\647\647.mid: 2469565344688
#
# Analyzing MIDI file: POP909\648\648.mid
#
# Analyzing MIDI file: POP909\649\649.mid
#
# Analyzing MIDI file: POP909\650\650.mid
#
# Analyzing MIDI file: POP909\651\651.mid
#
# Analyzing MIDI file: POP909\652\652.mid
#
# Analyzing MIDI file: POP909\653\653.mid
#
# Analyzing MIDI file: POP909\654\654.mid
#
# Analyzing MIDI file: POP909\655\655.mid
#
# Analyzing MIDI file: POP909\656\656.mid
#
# Analyzing MIDI file: POP909\657\657.mid
#
# Analyzing MIDI file: POP909\658\658.mid
#
# Analyzing MIDI file: POP909\659\659.mid
#
# Analyzing MIDI file: POP909\660\660.mid
#
# Analyzing MIDI file: POP909\661\661.mid
#
# Analyzing MIDI file: POP909\662\662.mid
#
# Analyzing MIDI file: POP909\663\663.mid
#
# Analyzing MIDI file: POP909\664\664.mid
#
# Analyzing MIDI file: POP909\665\665.mid
#
# Analyzing MIDI file: POP909\666\666.mid
#
# Analyzing MIDI file: POP909\667\667.mid
#
# Analyzing MIDI file: POP909\668\668.mid
#
# Analyzing MIDI file: POP909\669\669.mid
#
# Analyzing MIDI file: POP909\670\670.mid
#
# Analyzing MIDI file: POP909\671\671.mid
#
# Analyzing MIDI file: POP909\672\672.mid
#
# Analyzing MIDI file: POP909\673\673.mid
#
# Analyzing MIDI file: POP909\674\674.mid
#
# Analyzing MIDI file: POP909\675\675.mid
#
# Analyzing MIDI file: POP909\676\676.mid
#
# Analyzing MIDI file: POP909\677\677.mid
#
# Analyzing MIDI file: POP909\678\678.mid
#
# Analyzing MIDI file: POP909\679\679.mid
#
# Analyzing MIDI file: POP909\680\680.mid
#
# Analyzing MIDI file: POP909\681\681.mid
#
# Analyzing MIDI file: POP909\682\682.mid
#
# Analyzing MIDI file: POP909\683\683.mid
#
# Analyzing MIDI file: POP909\684\684.mid
#
# Analyzing MIDI file: POP909\685\685.mid
#
# Analyzing MIDI file: POP909\686\686.mid
#
# Analyzing MIDI file: POP909\687\687.mid
#
# Analyzing MIDI file: POP909\688\688.mid
#
# Analyzing MIDI file: POP909\689\689.mid
#
# Analyzing MIDI file: POP909\690\690.mid
#
# Analyzing MIDI file: POP909\691\691.mid
# Error analyzing POP909\691\691.mid: 2467481322256
#
# Analyzing MIDI file: POP909\692\692.mid
#
# Analyzing MIDI file: POP909\693\693.mid
#
# Analyzing MIDI file: POP909\694\694.mid
#
# Analyzing MIDI file: POP909\695\695.mid
#
# Analyzing MIDI file: POP909\696\696.mid
#
# Analyzing MIDI file: POP909\697\697.mid
#
# Analyzing MIDI file: POP909\698\698.mid
#
# Analyzing MIDI file: POP909\699\699.mid
#
# Analyzing MIDI file: POP909\700\700.mid
#
# Analyzing MIDI file: POP909\701\701.mid
# Error analyzing POP909\701\701.mid: 2469558338464
#
# Analyzing MIDI file: POP909\702\702.mid
#
# Analyzing MIDI file: POP909\703\703.mid
#
# Analyzing MIDI file: POP909\704\704.mid
#
# Analyzing MIDI file: POP909\705\705.mid
#
# Analyzing MIDI file: POP909\706\706.mid
#
# Analyzing MIDI file: POP909\707\707.mid
#
# Analyzing MIDI file: POP909\708\708.mid
#
# Analyzing MIDI file: POP909\709\709.mid
#
# Analyzing MIDI file: POP909\710\710.mid
#
# Analyzing MIDI file: POP909\711\711.mid
#
# Analyzing MIDI file: POP909\712\712.mid
#
# Analyzing MIDI file: POP909\713\713.mid
#
# Analyzing MIDI file: POP909\714\714.mid
#
# Analyzing MIDI file: POP909\715\715.mid
#
# Analyzing MIDI file: POP909\716\716.mid
#
# Analyzing MIDI file: POP909\717\717.mid
#
# Analyzing MIDI file: POP909\718\718.mid
#
# Analyzing MIDI file: POP909\719\719.mid
#
# Analyzing MIDI file: POP909\720\720.mid
#
# Analyzing MIDI file: POP909\721\721.mid
#
# Analyzing MIDI file: POP909\722\722.mid
#
# Analyzing MIDI file: POP909\723\723.mid
#
# Analyzing MIDI file: POP909\724\724.mid
#
# Analyzing MIDI file: POP909\725\725.mid
#
# Analyzing MIDI file: POP909\726\726.mid
#
# Analyzing MIDI file: POP909\727\727.mid
#
# Analyzing MIDI file: POP909\728\728.mid
#
# Analyzing MIDI file: POP909\729\729.mid
#
# Analyzing MIDI file: POP909\730\730.mid
#
# Analyzing MIDI file: POP909\731\731.mid
#
# Analyzing MIDI file: POP909\732\732.mid
#
# Analyzing MIDI file: POP909\733\733.mid
#
# Analyzing MIDI file: POP909\734\734.mid
#
# Analyzing MIDI file: POP909\735\735.mid
#
# Analyzing MIDI file: POP909\736\736.mid
#
# Analyzing MIDI file: POP909\737\737.mid
#
# Analyzing MIDI file: POP909\738\738.mid
#
# Analyzing MIDI file: POP909\739\739.mid
#
# Analyzing MIDI file: POP909\740\740.mid
# Error analyzing POP909\740\740.mid: 2469598463648
#
# Analyzing MIDI file: POP909\741\741.mid
#
# Analyzing MIDI file: POP909\742\742.mid
#
# Analyzing MIDI file: POP909\743\743.mid
#
# Analyzing MIDI file: POP909\744\744.mid
#
# Analyzing MIDI file: POP909\745\745.mid
#
# Analyzing MIDI file: POP909\746\746.mid
#
# Analyzing MIDI file: POP909\747\747.mid
#
# Analyzing MIDI file: POP909\748\748.mid
#
# Analyzing MIDI file: POP909\749\749.mid
#
# Analyzing MIDI file: POP909\750\750.mid
#
# Analyzing MIDI file: POP909\751\751.mid
#
# Analyzing MIDI file: POP909\752\752.mid
#
# Analyzing MIDI file: POP909\753\753.mid
#
# Analyzing MIDI file: POP909\754\754.mid
#
# Analyzing MIDI file: POP909\755\755.mid
#
# Analyzing MIDI file: POP909\756\756.mid
#
# Analyzing MIDI file: POP909\757\757.mid
#
# Analyzing MIDI file: POP909\758\758.mid
#
# Analyzing MIDI file: POP909\759\759.mid
#
# Analyzing MIDI file: POP909\760\760.mid
#
# Analyzing MIDI file: POP909\761\761.mid
#
# Analyzing MIDI file: POP909\762\762.mid
#
# Analyzing MIDI file: POP909\763\763.mid
#
# Analyzing MIDI file: POP909\764\764.mid
#
# Analyzing MIDI file: POP909\765\765.mid
#
# Analyzing MIDI file: POP909\766\766.mid
#
# Analyzing MIDI file: POP909\767\767.mid
#
# Analyzing MIDI file: POP909\768\768.mid
#
# Analyzing MIDI file: POP909\769\769.mid
#
# Analyzing MIDI file: POP909\770\770.mid
#
# Analyzing MIDI file: POP909\771\771.mid
#
# Analyzing MIDI file: POP909\772\772.mid
#
# Analyzing MIDI file: POP909\773\773.mid
#
# Analyzing MIDI file: POP909\774\774.mid
#
# Analyzing MIDI file: POP909\775\775.mid
# Analyzing MIDI file: POP909\776\776.mid
#
# Analyzing MIDI file: POP909\777\777.mid
#
# Analyzing MIDI file: POP909\778\778.mid
#
# Analyzing MIDI file: POP909\779\779.mid
#
# Analyzing MIDI file: POP909\780\780.mid
#
# Analyzing MIDI file: POP909\781\781.mid
#
# Analyzing MIDI file: POP909\782\782.mid
#
# Analyzing MIDI file: POP909\783\783.mid
#
# Analyzing MIDI file: POP909\784\784.mid
#
# Analyzing MIDI file: POP909\785\785.mid
#
# Analyzing MIDI file: POP909\786\786.mid
#
# Analyzing MIDI file: POP909\787\787.mid
#
# Analyzing MIDI file: POP909\788\788.mid
#
# Analyzing MIDI file: POP909\789\789.mid
#
# Analyzing MIDI file: POP909\790\790.mid
#
# Analyzing MIDI file: POP909\791\791.mid
#
# Analyzing MIDI file: POP909\792\792.mid
#
# Analyzing MIDI file: POP909\793\793.mid
#
# Analyzing MIDI file: POP909\794\794.mid
#
# Analyzing MIDI file: POP909\795\795.mid
#
# Analyzing MIDI file: POP909\796\796.mid
#
# Analyzing MIDI file: POP909\797\797.mid
#
# Analyzing MIDI file: POP909\798\798.mid
#
# Analyzing MIDI file: POP909\799\799.mid
#
# Analyzing MIDI file: POP909\800\800.mid
#
# Analyzing MIDI file: POP909\801\801.mid
#
# Analyzing MIDI file: POP909\802\802.mid
#
# Analyzing MIDI file: POP909\803\803.mid
#
# Analyzing MIDI file: POP909\804\804.mid
#
# Analyzing MIDI file: POP909\805\805.mid
#
# Analyzing MIDI file: POP909\806\806.mid
#
# Analyzing MIDI file: POP909\807\807.mid
#
# Analyzing MIDI file: POP909\808\808.mid
#
# Analyzing MIDI file: POP909\809\809.mid
#
# Analyzing MIDI file: POP909\810\810.mid
#
# Analyzing MIDI file: POP909\811\811.mid
#
# Analyzing MIDI file: POP909\812\812.mid
#
# Analyzing MIDI file: POP909\813\813.mid
#
# Analyzing MIDI file: POP909\814\814.mid
#
# Analyzing MIDI file: POP909\815\815.mid
#
# Analyzing MIDI file: POP909\816\816.mid
#
# Analyzing MIDI file: POP909\817\817.mid
#
# Analyzing MIDI file: POP909\818\818.mid
#
# Analyzing MIDI file: POP909\819\819.mid
#
# Analyzing MIDI file: POP909\820\820.mid
#
# Analyzing MIDI file: POP909\821\821.mid
#
# Analyzing MIDI file: POP909\822\822.mid
#
# Analyzing MIDI file: POP909\823\823.mid
#
# Analyzing MIDI file: POP909\824\824.mid
#
# Analyzing MIDI file: POP909\825\825.mid
#
# Analyzing MIDI file: POP909\826\826.mid
#
# Analyzing MIDI file: POP909\827\827.mid
#
# Analyzing MIDI file: POP909\828\828.mid
#
# Analyzing MIDI file: POP909\829\829.mid
#
# Analyzing MIDI file: POP909\830\830.mid
#
# Analyzing MIDI file: POP909\831\831.mid
#
# Analyzing MIDI file: POP909\832\832.mid
#
# Analyzing MIDI file: POP909\833\833.mid
#
# Analyzing MIDI file: POP909\834\834.mid
#
# Analyzing MIDI file: POP909\835\835.mid
#
# Analyzing MIDI file: POP909\836\836.mid
#
# Analyzing MIDI file: POP909\837\837.mid
#
# Analyzing MIDI file: POP909\838\838.mid
#
# Analyzing MIDI file: POP909\839\839.mid
#
# Analyzing MIDI file: POP909\840\840.mid
#
# Analyzing MIDI file: POP909\841\841.mid
#
# Analyzing MIDI file: POP909\842\842.mid
#
# Analyzing MIDI file: POP909\843\843.mid
#
# Analyzing MIDI file: POP909\844\844.mid
#
# Analyzing MIDI file: POP909\845\845.mid
#
# Analyzing MIDI file: POP909\846\846.mid
#
# Analyzing MIDI file: POP909\847\847.mid
#
# Analyzing MIDI file: POP909\848\848.mid
#
# Analyzing MIDI file: POP909\849\849.mid
#
# Analyzing MIDI file: POP909\850\850.mid
# Error analyzing POP909\850\850.mid: 2467480085312
#
# Analyzing MIDI file: POP909\851\851.mid
#
# Analyzing MIDI file: POP909\852\852.mid
#
# Analyzing MIDI file: POP909\853\853.mid
#
# Analyzing MIDI file: POP909\854\854.mid
#
# Analyzing MIDI file: POP909\855\855.mid
#
# Analyzing MIDI file: POP909\856\856.mid
#
# Analyzing MIDI file: POP909\857\857.mid
#
# Analyzing MIDI file: POP909\858\858.mid
#
# Analyzing MIDI file: POP909\859\859.mid
#
# Analyzing MIDI file: POP909\860\860.mid
#
# Analyzing MIDI file: POP909\861\861.mid
#
# Analyzing MIDI file: POP909\862\862.mid
#
# Analyzing MIDI file: POP909\863\863.mid
#
# Analyzing MIDI file: POP909\864\864.mid
#
# Analyzing MIDI file: POP909\865\865.mid
#
# Analyzing MIDI file: POP909\866\866.mid
#
# Analyzing MIDI file: POP909\867\867.mid
#
# Analyzing MIDI file: POP909\868\868.mid
#
# Analyzing MIDI file: POP909\869\869.mid
#
# Analyzing MIDI file: POP909\870\870.mid
#
# Analyzing MIDI file: POP909\871\871.mid
#
# Analyzing MIDI file: POP909\872\872.mid
#
# Analyzing MIDI file: POP909\873\873.mid
#
# Analyzing MIDI file: POP909\874\874.mid
#
# Analyzing MIDI file: POP909\875\875.mid
#
# Analyzing MIDI file: POP909\876\876.mid
#
# Analyzing MIDI file: POP909\877\877.mid
#
# Analyzing MIDI file: POP909\878\878.mid
#
# Analyzing MIDI file: POP909\879\879.mid
# Error analyzing POP909\879\879.mid: 2467494420336
#
# Analyzing MIDI file: POP909\880\880.mid
#
# Analyzing MIDI file: POP909\881\881.mid
#
# Analyzing MIDI file: POP909\882\882.mid
#
# Analyzing MIDI file: POP909\883\883.mid
#
# Analyzing MIDI file: POP909\884\884.mid
#
# Analyzing MIDI file: POP909\885\885.mid
#
# Analyzing MIDI file: POP909\886\886.mid
#
# Analyzing MIDI file: POP909\887\887.mid
#
# Analyzing MIDI file: POP909\888\888.mid
#
# Analyzing MIDI file: POP909\889\889.mid
#
# Analyzing MIDI file: POP909\890\890.mid
#
# Analyzing MIDI file: POP909\891\891.mid
#
# Analyzing MIDI file: POP909\892\892.mid
#
# Analyzing MIDI file: POP909\893\893.mid
#
# Analyzing MIDI file: POP909\894\894.mid
#
# Analyzing MIDI file: POP909\895\895.mid
# Error analyzing POP909\895\895.mid: 2467466487696
#
# Analyzing MIDI file: POP909\896\896.mid
#
# Analyzing MIDI file: POP909\897\897.mid
#
# Analyzing MIDI file: POP909\898\898.mid
#
# Analyzing MIDI file: POP909\899\899.mid
#
# Analyzing MIDI file: POP909\900\900.mid
#
# Analyzing MIDI file: POP909\901\901.mid
#
# Analyzing MIDI file: POP909\902\902.mid
#
# Analyzing MIDI file: POP909\903\903.mid
#
# Analyzing MIDI file: POP909\904\904.mid
#
# Analyzing MIDI file: POP909\905\905.mid
#
# Analyzing MIDI file: POP909\906\906.mid
#
# Analyzing MIDI file: POP909\907\907.mid
#
# Analyzing MIDI file: POP909\908\908.mid
#
# Analyzing MIDI file: POP909\909\909.mid
# Mode Time Signature: 0.25
# Expected Music Key: G major

# %% [markdown]
# Reference: https://www.kaggle.com/code/wfaria/midi-music-data-extraction-using-music21
