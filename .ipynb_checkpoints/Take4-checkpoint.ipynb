# %%
#!pip install -q jupyternotify

# %%
#%load_ext jupyternotify

# %% [markdown]
# ## Read in the music into one file

# %% [markdown]
# The given code is a Python script that uses the mido library to read MIDI files from various sub-folders (presumably each representing a composer) within a base directory called "POP909". The code populates a list, midi, with the MIDI data from each file.

# %%
import mido
import os

# Base directory where all composers' folders are located
base_filepath = "POP909"

# Initializing an empty list to hold all the MIDI files
all_midis = []

# Looping through all the composers' folders
for composer in os.listdir(base_filepath):
    # Constructing the full path to the composer's folder
    composer_filepath = os.path.join(base_filepath, composer)

    # Checking if it's a directory before proceeding
    if os.path.isdir(composer_filepath):
        # Looping through all the files in the composer's folder
        for i in os.listdir(composer_filepath):
            if i.endswith(".mid"):
                tr = os.path.join(composer_filepath, i)
                midi = mido.MidiFile(tr) # Reading the MIDI file
                all_midis.append(midi)

# %% [markdown]
# ## 1. Inspecting the MIDI File

# %% [markdown]
# Let have a look at the midi files and see what is in the new folder

# %%
print(midi)
# Out:
# MidiFile(type=1, ticks_per_beat=480, tracks=[
#   MidiTrack([
#     MetaMessage('set_tempo', tempo=576923, time=0),
#     MetaMessage('time_signature', numerator=1, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
#     MetaMessage('set_tempo', tempo=578312, time=28009),
#     MetaMessage('set_tempo', tempo=576923, time=7445),
#     MetaMessage('set_tempo', tempo=578312, time=3602),
#     MetaMessage('set_tempo', tempo=576923, time=7670),
#     MetaMessage('set_tempo', tempo=578312, time=13884),
#     MetaMessage('set_tempo', tempo=576923, time=12308),
#     MetaMessage('end_of_track', time=1)]),
#   MidiTrack([
#     MetaMessage('track_name', name='MELODY', time=0),
#     Message('program_change', channel=0, program=0, time=0),
#     Message('note_on', channel=0, note=76, velocity=85, time=10529),
#     Message('note_on', channel=0, note=76, velocity=0, time=69),
#     Message('note_on', channel=0, note=77, velocity=78, time=51),
#     Message('note_on', channel=0, note=77, velocity=0, time=76),
#     Message('note_on', channel=0, note=79, velocity=74, time=44),
#     Message('note_on', channel=0, note=79, velocity=0, time=76),
#     Message('note_on', channel=0, note=77, velocity=78, time=164),
#     Message('note_on', channel=0, note=77, velocity=0, time=74),
#     Message('note_on', channel=0, note=76, velocity=81, time=166),
#     Message('note_on', channel=0, note=76, velocity=0, time=80),
#     Message('note_on', channel=0, note=77, velocity=80, time=160),
#     Message('note_on', channel=0, note=77, velocity=0, time=72),
#     Message('note_on', channel=0, note=79, velocity=78, time=168),
#     Message('note_on', channel=0, note=79, velocity=0, time=76),
#     Message('note_on', channel=0, note=77, velocity=80, time=164),
#     Message('note_on', channel=0, note=77, velocity=0, time=80),
#     Message('note_on', channel=0, note=76, velocity=81, time=160),
#     Message('note_on', channel=0, note=76, velocity=0, time=93),
#     Message('note_on', channel=0, note=77, velocity=80, time=147),
#     Message('note_on', channel=0, note=77, velocity=0, time=93),
#     Message('note_on', channel=0, note=79, velocity=76, time=147),
#     Message('note_on', channel=0, note=79, velocity=0, time=101),
#     Message('note_on', channel=0, note=79, velocity=76, time=139),
#     Message('note_on', channel=0, note=79, velocity=0, time=62),
#     Message('note_on', channel=0, note=79, velocity=71, time=58),
#     Message('note_on', channel=0, note=79, velocity=0, time=54),
#     Message('note_on', channel=0, note=79, velocity=74, time=66),
#     Message('note_on', channel=0, note=79, velocity=0, time=118),
#     Message('note_on', channel=0, note=88, velocity=80, time=122),
#     Message('note_on', channel=0, note=88, velocity=0, time=154),
#     Message('note_on', channel=0, note=84, velocity=75, time=86),
#     Message('note_on', channel=0, note=84, velocity=0, time=480),
#     Message('note_on', channel=0, note=74, velocity=81, time=240),
#     Message('note_on', channel=0, note=74, velocity=0, time=66),
#     Message('note_on', channel=0, note=76, velocity=75, time=54),
#     Message('note_on', channel=0, note=77, velocity=77, time=120),
#     Message('note_on', channel=0, note=76, velocity=0, time=24),
#     Message('note_on', channel=0, note=77, velocity=0, time=68),
#     Message('note_on', channel=0, note=76, velocity=76, time=148),
#     Message('note_on', channel=0, note=76, velocity=0, time=109),
#     Message('note_on', channel=0, note=77, velocity=76, time=131),
#     Message('note_on', channel=0, note=77, velocity=0, time=113),
#     Message('note_on', channel=0, note=86, velocity=79, time=127),
#     Message('note_on', channel=0, note=86, velocity=0, time=96),
#     Message('note_on', channel=0, note=83, velocity=75, time=144),
#     Message('note_on', channel=0, note=83, velocity=0, time=332),
#     Message('note_on', channel=0, note=74, velocity=81, time=388),
#     Message('note_on', channel=0, note=74, velocity=0, time=77),
#     Message('note_on', channel=0, note=76, velocity=78, time=43),
#     Message('note_on', channel=0, note=76, velocity=0, time=80),
#     Message('note_on', channel=0, note=77, velocity=78, time=40),
#     Message('note_on', channel=0, note=77, velocity=0, time=101),
#     Message('note_on', channel=0, note=76, velocity=80, time=139),
#     Message('note_on', channel=0, note=76, velocity=0, time=93),
#     Message('note_on', channel=0, note=77, velocity=74, time=147),
#     Message('note_on', channel=0, note=77, velocity=0, time=120),
#     Message('note_on', channel=0, note=81, velocity=76, time=120),
#     Message('note_on', channel=0, note=81, velocity=0, time=125),
#     Message('note_on', channel=0, note=79, velocity=75, time=115),
#     Message('note_on', channel=0, note=79, velocity=0, time=271),
#     Message('note_on', channel=0, note=76, velocity=85, time=449),
#     Message('note_on', channel=0, note=76, velocity=0, time=69),
#     Message('note_on', channel=0, note=77, velocity=78, time=51),
#     Message('note_on', channel=0, note=77, velocity=0, time=76),
#     Message('note_on', channel=0, note=79, velocity=74, time=44),
#     Message('note_on', channel=0, note=79, velocity=0, time=76),
#     Message('note_on', channel=0, note=77, velocity=78, time=164),
#     Message('note_on', channel=0, note=77, velocity=0, time=74),
#     Message('note_on', channel=0, note=76, velocity=81, time=166),
#     Message('note_on', channel=0, note=76, velocity=0, time=80),
#     Message('note_on', channel=0, note=77, velocity=80, time=160),
#     Message('note_on', channel=0, note=77, velocity=0, time=72),
#     Message('note_on', channel=0, note=79, velocity=78, time=168),
#     Message('note_on', channel=0, note=79, velocity=0, time=76),
#     Message('note_on', channel=0, note=77, velocity=80, time=164),
#     Message('note_on', channel=0, note=77, velocity=0, time=80),
#     Message('note_on', channel=0, note=76, velocity=81, time=160),
#     Message('note_on', channel=0, note=76, velocity=0, time=93),
#     Message('note_on', channel=0, note=77, velocity=80, time=147),
#     Message('note_on', channel=0, note=77, velocity=0, time=93),
#     Message('note_on', channel=0, note=79, velocity=76, time=147),
#     Message('note_on', channel=0, note=79, velocity=0, time=101),
#     Message('note_on', channel=0, note=79, velocity=76, time=139),
#     Message('note_on', channel=0, note=79, velocity=0, time=62),
#     Message('note_on', channel=0, note=79, velocity=71, time=58),
#     Message('note_on', channel=0, note=79, velocity=0, time=54),
#     Message('note_on', channel=0, note=79, velocity=74, time=66),
#     Message('note_on', channel=0, note=79, velocity=0, time=118),
#     Message('note_on', channel=0, note=88, velocity=80, time=122),
#     Message('note_on', channel=0, note=88, velocity=0, time=154),
#     Message('note_on', channel=0, note=86, velocity=75, time=86),
#     Message('note_on', channel=0, note=86, velocity=0, time=480),
#     Message('note_on', channel=0, note=74, velocity=81, time=240),
#     Message('note_on', channel=0, note=74, velocity=0, time=66),
#     Message('note_on', channel=0, note=76, velocity=75, time=54),
#     Message('note_on', channel=0, note=77, velocity=77, time=120),
#     Message('note_on', channel=0, note=76, velocity=0, time=24),
#     Message('note_on', channel=0, note=77, velocity=0, time=68),
#     Message('note_on', channel=0, note=76, velocity=76, time=148),
#     Message('note_on', channel=0, note=76, velocity=0, time=109),
#     Message('note_on', channel=0, note=77, velocity=76, time=131),
#     Message('note_on', channel=0, note=77, velocity=0, time=113),
#     Message('note_on', channel=0, note=86, velocity=79, time=127),
#     Message('note_on', channel=0, note=86, velocity=0, time=96),
#     Message('note_on', channel=0, note=84, velocity=72, time=144),
#     Message('note_on', channel=0, note=84, velocity=0, time=207),
#     Message('note_on', channel=0, note=83, velocity=76, time=33),
#     Message('note_on', channel=0, note=83, velocity=0, time=101),
#     Message('note_on', channel=0, note=81, velocity=75, time=139),
#     Message('note_on', channel=0, note=81, velocity=0, time=154),
#     Message('note_on', channel=0, note=83, velocity=75, time=86),
#     Message('note_on', channel=0, note=83, velocity=0, time=134),
#     Message('note_on', channel=0, note=84, velocity=75, time=106),
#     Message('note_on', channel=0, note=84, velocity=0, time=1133),
#     Message('note_on', channel=0, note=79, velocity=76, time=307),
#     Message('note_on', channel=0, note=79, velocity=0, time=370),
#     Message('note_on', channel=0, note=79, velocity=74, time=110),
#     Message('note_on', channel=0, note=79, velocity=0, time=354),
#     Message('note_on', channel=0, note=88, velocity=74, time=126),
#     Message('note_on', channel=0, note=88, velocity=0, time=133),
#     Message('note_on', channel=0, note=88, velocity=76, time=107),
#     Message('note_on', channel=0, note=88, velocity=0, time=133),
#     Message('note_on', channel=0, note=84, velocity=78, time=107),
#     Message('note_on', channel=0, note=84, velocity=0, time=375),
#     Message('note_on', channel=0, note=79, velocity=78, time=105),
#     Message('note_on', channel=0, note=79, velocity=0, time=439),
#     Message('note_on', channel=0, note=76, velocity=79, time=41),
#     Message('note_on', channel=0, note=76, velocity=0, time=1312),
#     Message('note_on', channel=0, note=79, velocity=76, time=128),
#     Message('note_on', channel=0, note=79, velocity=0, time=309),
#     Message('note_on', channel=0, note=77, velocity=80, time=171),
#     Message('note_on', channel=0, note=77, velocity=0, time=378),
#     Message('note_on', channel=0, note=86, velocity=69, time=102),
#     Message('note_on', channel=0, note=86, velocity=0, time=124),
#     Message('note_on', channel=0, note=86, velocity=77, time=116),
#     Message('note_on', channel=0, note=86, velocity=0, time=171),
#     Message('note_on', channel=0, note=83, velocity=74, time=69),
#     Message('note_on', channel=0, note=83, velocity=0, time=350),
#     Message('note_on', channel=0, note=77, velocity=75, time=130),
#     Message('note_on', channel=0, note=77, velocity=0, time=399),
#     Message('note_on', channel=0, note=74, velocity=74, time=81),
#     Message('note_on', channel=0, note=74, velocity=0, time=1226),
#     Message('note_on', channel=0, note=76, velocity=78, time=454),
#     Message('note_on', channel=0, note=76, velocity=0, time=70),
#     Message('note_on', channel=0, note=77, velocity=75, time=50),
#     Message('note_on', channel=0, note=77, velocity=0, time=79),
#     Message('note_on', channel=0, note=79, velocity=75, time=41),
#     Message('note_on', channel=0, note=79, velocity=0, time=80),
#     Message('note_on', channel=0, note=77, velocity=74, time=160),
#     Message('note_on', channel=0, note=77, velocity=0, time=86),
#     Message('note_on', channel=0, note=76, velocity=81, time=154),
#     Message('note_on', channel=0, note=76, velocity=0, time=84),
#     Message('note_on', channel=0, note=77, velocity=75, time=156),
#     Message('note_on', channel=0, note=77, velocity=0, time=90),
#     Message('note_on', channel=0, note=79, velocity=74, time=150),
#     Message('note_on', channel=0, note=79, velocity=0, time=89),
#     Message('note_on', channel=0, note=77, velocity=76, time=151),
#     Message('note_on', channel=0, note=77, velocity=0, time=84),
#     Message('note_on', channel=0, note=76, velocity=76, time=156),
#     Message('note_on', channel=0, note=76, velocity=0, time=103),
#     Message('note_on', channel=0, note=77, velocity=75, time=137),
#     Message('note_on', channel=0, note=77, velocity=0, time=111),
#     Message('note_on', channel=0, note=79, velocity=75, time=129),
#     Message('note_on', channel=0, note=79, velocity=0, time=89),
#     Message('note_on', channel=0, note=79, velocity=74, time=151),
#     Message('note_on', channel=0, note=79, velocity=0, time=97),
#     Message('note_on', channel=0, note=79, velocity=74, time=23),
#     Message('note_on', channel=0, note=79, velocity=0, time=97),
#     Message('note_on', channel=0, note=79, velocity=75, time=23),
#     Message('note_on', channel=0, note=79, velocity=0, time=110),
#     Message('note_on', channel=0, note=84, velocity=78, time=130),
#     Message('note_on', channel=0, note=84, velocity=0, time=98),
#     Message('note_on', channel=0, note=88, velocity=78, time=142),
#     Message('note_on', channel=0, note=88, velocity=0, time=420),
#     Message('note_on', channel=0, note=74, velocity=78, time=300),
#     Message('note_on', channel=0, note=74, velocity=0, time=73),
#     Message('note_on', channel=0, note=76, velocity=78, time=47),
#     Message('note_on', channel=0, note=76, velocity=0, time=76),
#     Message('note_on', channel=0, note=77, velocity=74, time=44),
#     Message('note_on', channel=0, note=77, velocity=0, time=71),
#     Message('note_on', channel=0, note=76, velocity=83, time=169),
#     Message('note_on', channel=0, note=76, velocity=0, time=88),
#     Message('note_on', channel=0, note=77, velocity=69, time=152),
#     Message('note_on', channel=0, note=77, velocity=0, time=116),
#     Message('note_on', channel=0, note=86, velocity=78, time=124),
#     Message('note_on', channel=0, note=86, velocity=0, time=106),
#     Message('note_on', channel=0, note=84, velocity=78, time=134),
#     Message('note_on', channel=0, note=84, velocity=0, time=102),
#     Message('note_on', channel=0, note=83, velocity=75, time=138),
#     Message('note_on', channel=0, note=83, velocity=0, time=116),
#     Message('note_on', channel=0, note=81, velocity=74, time=124),
#     Message('note_on', channel=0, note=81, velocity=0, time=109),
#     Message('note_on', channel=0, note=83, velocity=74, time=131),
#     Message('note_on', channel=0, note=83, velocity=0, time=132),
#     Message('note_on', channel=0, note=84, velocity=78, time=108),
#     Message('note_on', channel=0, note=84, velocity=0, time=1472),
#     Message('note_on', channel=0, note=76, velocity=85, time=9808),
#     Message('note_on', channel=0, note=76, velocity=0, time=69),
#     Message('note_on', channel=0, note=77, velocity=78, time=51),
#     Message('note_on', channel=0, note=77, velocity=0, time=76),
#     Message('note_on', channel=0, note=79, velocity=74, time=44),
#     Message('note_on', channel=0, note=79, velocity=0, time=76),
#     Message('note_on', channel=0, note=77, velocity=78, time=164),
#     Message('note_on', channel=0, note=77, velocity=0, time=74),
#     Message('note_on', channel=0, note=76, velocity=81, time=166),
#     Message('note_on', channel=0, note=76, velocity=0, time=80),
#     Message('note_on', channel=0, note=77, velocity=80, time=160),
#     Message('note_on', channel=0, note=77, velocity=0, time=72),
#     Message('note_on', channel=0, note=79, velocity=78, time=168),
#     Message('note_on', channel=0, note=79, velocity=0, time=76),
#     Message('note_on', channel=0, note=77, velocity=80, time=164),
#     Message('note_on', channel=0, note=77, velocity=0, time=80),
#     Message('note_on', channel=0, note=76, velocity=81, time=160),
#     Message('note_on', channel=0, note=76, velocity=0, time=93),
#     Message('note_on', channel=0, note=77, velocity=80, time=147),
#     Message('note_on', channel=0, note=77, velocity=0, time=93),
#     Message('note_on', channel=0, note=79, velocity=76, time=147),
#     Message('note_on', channel=0, note=79, velocity=0, time=101),
#     Message('note_on', channel=0, note=79, velocity=76, time=139),
#     Message('note_on', channel=0, note=79, velocity=0, time=62),
#     Message('note_on', channel=0, note=79, velocity=71, time=58),
#     Message('note_on', channel=0, note=79, velocity=0, time=54),
#     Message('note_on', channel=0, note=79, velocity=74, time=66),
#     Message('note_on', channel=0, note=79, velocity=0, time=118),
#     Message('note_on', channel=0, note=88, velocity=80, time=122),
#     Message('note_on', channel=0, note=88, velocity=0, time=154),
#     Message('note_on', channel=0, note=84, velocity=75, time=86),
#     Message('note_on', channel=0, note=84, velocity=0, time=480),
#     Message('note_on', channel=0, note=74, velocity=81, time=240),
#     Message('note_on', channel=0, note=74, velocity=0, time=66),
#     Message('note_on', channel=0, note=76, velocity=75, time=54),
#     Message('note_on', channel=0, note=77, velocity=77, time=120),
#     Message('note_on', channel=0, note=76, velocity=0, time=24),
#     Message('note_on', channel=0, note=77, velocity=0, time=68),
#     Message('note_on', channel=0, note=76, velocity=76, time=148),
#     Message('note_on', channel=0, note=76, velocity=0, time=109),
#     Message('note_on', channel=0, note=77, velocity=76, time=131),
#     Message('note_on', channel=0, note=77, velocity=0, time=113),
#     Message('note_on', channel=0, note=86, velocity=79, time=127),
#     Message('note_on', channel=0, note=86, velocity=0, time=96),
#     Message('note_on', channel=0, note=83, velocity=75, time=144),
#     Message('note_on', channel=0, note=83, velocity=0, time=332),
#     Message('note_on', channel=0, note=74, velocity=81, time=388),
#     Message('note_on', channel=0, note=74, velocity=0, time=77),
#     Message('note_on', channel=0, note=76, velocity=78, time=43),
#     Message('note_on', channel=0, note=76, velocity=0, time=80),
#     Message('note_on', channel=0, note=77, velocity=78, time=40),
#     Message('note_on', channel=0, note=77, velocity=0, time=101),
#     Message('note_on', channel=0, note=76, velocity=80, time=139),
#     Message('note_on', channel=0, note=76, velocity=0, time=93),
#     Message('note_on', channel=0, note=77, velocity=74, time=147),
#     Message('note_on', channel=0, note=77, velocity=0, time=120),
#     Message('note_on', channel=0, note=81, velocity=76, time=120),
#     Message('note_on', channel=0, note=81, velocity=0, time=125),
#     Message('note_on', channel=0, note=79, velocity=75, time=115),
#     Message('note_on', channel=0, note=79, velocity=0, time=271),
#     Message('note_on', channel=0, note=76, velocity=85, time=449),
#     Message('note_on', channel=0, note=76, velocity=0, time=69),
#     Message('note_on', channel=0, note=77, velocity=78, time=51),
#     Message('note_on', channel=0, note=77, velocity=0, time=76),
#     Message('note_on', channel=0, note=79, velocity=74, time=44),
#     Message('note_on', channel=0, note=79, velocity=0, time=76),
#     Message('note_on', channel=0, note=77, velocity=78, time=164),
#     Message('note_on', channel=0, note=77, velocity=0, time=74),
#     Message('note_on', channel=0, note=76, velocity=81, time=166),
#     Message('note_on', channel=0, note=76, velocity=0, time=80),
#     Message('note_on', channel=0, note=77, velocity=80, time=160),
#     Message('note_on', channel=0, note=77, velocity=0, time=72),
#     Message('note_on', channel=0, note=79, velocity=78, time=168),
#     Message('note_on', channel=0, note=79, velocity=0, time=76),
#     Message('note_on', channel=0, note=77, velocity=80, time=164),
#     Message('note_on', channel=0, note=77, velocity=0, time=80),
#     Message('note_on', channel=0, note=76, velocity=81, time=160),
#     Message('note_on', channel=0, note=76, velocity=0, time=93),
#     Message('note_on', channel=0, note=77, velocity=80, time=147),
#     Message('note_on', channel=0, note=77, velocity=0, time=93),
#     Message('note_on', channel=0, note=79, velocity=76, time=147),
#     Message('note_on', channel=0, note=79, velocity=0, time=101),
#     Message('note_on', channel=0, note=79, velocity=76, time=139),
#     Message('note_on', channel=0, note=79, velocity=0, time=62),
#     Message('note_on', channel=0, note=79, velocity=71, time=58),
#     Message('note_on', channel=0, note=79, velocity=0, time=54),
#     Message('note_on', channel=0, note=79, velocity=74, time=66),
#     Message('note_on', channel=0, note=79, velocity=0, time=118),
#     Message('note_on', channel=0, note=88, velocity=80, time=122),
#     Message('note_on', channel=0, note=88, velocity=0, time=154),
#     Message('note_on', channel=0, note=86, velocity=75, time=86),
#     Message('note_on', channel=0, note=86, velocity=0, time=480),
#     Message('note_on', channel=0, note=74, velocity=81, time=240),
#     Message('note_on', channel=0, note=74, velocity=0, time=66),
#     Message('note_on', channel=0, note=76, velocity=75, time=54),
#     Message('note_on', channel=0, note=77, velocity=77, time=120),
#     Message('note_on', channel=0, note=76, velocity=0, time=24),
#     Message('note_on', channel=0, note=77, velocity=0, time=68),
#     Message('note_on', channel=0, note=76, velocity=76, time=148),
#     Message('note_on', channel=0, note=76, velocity=0, time=109),
#     Message('note_on', channel=0, note=77, velocity=76, time=131),
#     Message('note_on', channel=0, note=77, velocity=0, time=113),
#     Message('note_on', channel=0, note=86, velocity=79, time=127),
#     Message('note_on', channel=0, note=86, velocity=0, time=96),
#     Message('note_on', channel=0, note=84, velocity=72, time=144),
#     Message('note_on', channel=0, note=84, velocity=0, time=207),
#     Message('note_on', channel=0, note=83, velocity=76, time=33),
#     Message('note_on', channel=0, note=83, velocity=0, time=101),
#     Message('note_on', channel=0, note=81, velocity=75, time=139),
#     Message('note_on', channel=0, note=81, velocity=0, time=154),
#     Message('note_on', channel=0, note=83, velocity=75, time=86),
#     Message('note_on', channel=0, note=83, velocity=0, time=134),
#     Message('note_on', channel=0, note=84, velocity=75, time=106),
#     Message('note_on', channel=0, note=84, velocity=0, time=1133),
#     Message('note_on', channel=0, note=79, velocity=76, time=307),
#     Message('note_on', channel=0, note=79, velocity=0, time=370),
#     Message('note_on', channel=0, note=79, velocity=74, time=110),
#     Message('note_on', channel=0, note=79, velocity=0, time=354),
#     Message('note_on', channel=0, note=88, velocity=74, time=126),
#     Message('note_on', channel=0, note=88, velocity=0, time=133),
#     Message('note_on', channel=0, note=88, velocity=76, time=107),
#     Message('note_on', channel=0, note=88, velocity=0, time=133),
#     Message('note_on', channel=0, note=84, velocity=78, time=107),
#     Message('note_on', channel=0, note=84, velocity=0, time=375),
#     Message('note_on', channel=0, note=79, velocity=78, time=105),
#     Message('note_on', channel=0, note=79, velocity=0, time=439),
#     Message('note_on', channel=0, note=76, velocity=79, time=41),
#     Message('note_on', channel=0, note=76, velocity=0, time=1312),
#     Message('note_on', channel=0, note=79, velocity=76, time=128),
#     Message('note_on', channel=0, note=79, velocity=0, time=309),
#     Message('note_on', channel=0, note=77, velocity=80, time=171),
#     Message('note_on', channel=0, note=77, velocity=0, time=378),
#     Message('note_on', channel=0, note=86, velocity=69, time=102),
#     Message('note_on', channel=0, note=86, velocity=0, time=124),
#     Message('note_on', channel=0, note=86, velocity=77, time=116),
#     Message('note_on', channel=0, note=86, velocity=0, time=171),
#     Message('note_on', channel=0, note=83, velocity=74, time=69),
#     Message('note_on', channel=0, note=83, velocity=0, time=350),
#     Message('note_on', channel=0, note=77, velocity=75, time=130),
#     Message('note_on', channel=0, note=77, velocity=0, time=399),
#     Message('note_on', channel=0, note=74, velocity=74, time=81),
#     Message('note_on', channel=0, note=74, velocity=0, time=1226),
#     Message('note_on', channel=0, note=76, velocity=78, time=454),
#     Message('note_on', channel=0, note=76, velocity=0, time=70),
#     Message('note_on', channel=0, note=77, velocity=75, time=50),
#     Message('note_on', channel=0, note=77, velocity=0, time=79),
#     Message('note_on', channel=0, note=79, velocity=75, time=41),
#     Message('note_on', channel=0, note=79, velocity=0, time=80),
#     Message('note_on', channel=0, note=77, velocity=74, time=160),
#     Message('note_on', channel=0, note=77, velocity=0, time=86),
#     Message('note_on', channel=0, note=76, velocity=81, time=154),
#     Message('note_on', channel=0, note=76, velocity=0, time=84),
#     Message('note_on', channel=0, note=77, velocity=75, time=156),
#     Message('note_on', channel=0, note=77, velocity=0, time=90),
#     Message('note_on', channel=0, note=79, velocity=74, time=150),
#     Message('note_on', channel=0, note=79, velocity=0, time=89),
#     Message('note_on', channel=0, note=77, velocity=76, time=151),
#     Message('note_on', channel=0, note=77, velocity=0, time=84),
#     Message('note_on', channel=0, note=76, velocity=76, time=156),
#     Message('note_on', channel=0, note=76, velocity=0, time=103),
#     Message('note_on', channel=0, note=77, velocity=75, time=137),
#     Message('note_on', channel=0, note=77, velocity=0, time=111),
#     Message('note_on', channel=0, note=79, velocity=75, time=129),
#     Message('note_on', channel=0, note=79, velocity=0, time=89),
#     Message('note_on', channel=0, note=79, velocity=74, time=151),
#     Message('note_on', channel=0, note=79, velocity=0, time=97),
#     Message('note_on', channel=0, note=79, velocity=74, time=23),
#     Message('note_on', channel=0, note=79, velocity=0, time=97),
#     Message('note_on', channel=0, note=79, velocity=75, time=23),
#     Message('note_on', channel=0, note=79, velocity=0, time=110),
#     Message('note_on', channel=0, note=84, velocity=78, time=130),
#     Message('note_on', channel=0, note=84, velocity=0, time=98),
#     Message('note_on', channel=0, note=88, velocity=78, time=142),
#     Message('note_on', channel=0, note=88, velocity=0, time=420),
#     Message('note_on', channel=0, note=74, velocity=78, time=300),
#     Message('note_on', channel=0, note=74, velocity=0, time=73),
#     Message('note_on', channel=0, note=76, velocity=78, time=47),
#     Message('note_on', channel=0, note=76, velocity=0, time=76),
#     Message('note_on', channel=0, note=77, velocity=74, time=44),
#     Message('note_on', channel=0, note=77, velocity=0, time=71),
#     Message('note_on', channel=0, note=76, velocity=83, time=169),
#     Message('note_on', channel=0, note=76, velocity=0, time=88),
#     Message('note_on', channel=0, note=77, velocity=69, time=152),
#     Message('note_on', channel=0, note=77, velocity=0, time=116),
#     Message('note_on', channel=0, note=86, velocity=78, time=124),
#     Message('note_on', channel=0, note=86, velocity=0, time=106),
#     Message('note_on', channel=0, note=84, velocity=78, time=134),
#     Message('note_on', channel=0, note=84, velocity=0, time=102),
#     Message('note_on', channel=0, note=83, velocity=75, time=138),
#     Message('note_on', channel=0, note=83, velocity=0, time=116),
#     Message('note_on', channel=0, note=81, velocity=74, time=124),
#     Message('note_on', channel=0, note=81, velocity=0, time=109),
#     Message('note_on', channel=0, note=83, velocity=74, time=131),
#     Message('note_on', channel=0, note=83, velocity=0, time=132),
#     Message('note_on', channel=0, note=84, velocity=78, time=108),
#     Message('note_on', channel=0, note=84, velocity=0, time=1472),
#     MetaMessage('end_of_track', time=1)]),
#   MidiTrack([
#     MetaMessage('track_name', name='BRIDGE', time=0),
#     Message('program_change', channel=1, program=0, time=0),
#     Message('note_on', channel=1, note=76, velocity=80, time=929),
#     Message('note_on', channel=1, note=76, velocity=0, time=71),
#     Message('note_on', channel=1, note=77, velocity=74, time=49),
#     Message('note_on', channel=1, note=77, velocity=0, time=102),
#     Message('note_on', channel=1, note=79, velocity=81, time=18),
#     Message('note_on', channel=1, note=79, velocity=0, time=129),
#     Message('note_on', channel=1, note=88, velocity=79, time=111),
#     Message('note_on', channel=1, note=88, velocity=0, time=110),
#     Message('note_on', channel=1, note=84, velocity=83, time=130),
#     Message('note_on', channel=1, note=84, velocity=0, time=97),
#     Message('note_on', channel=1, note=79, velocity=81, time=143),
#     Message('note_on', channel=1, note=79, velocity=0, time=76),
#     Message('note_on', channel=1, note=76, velocity=85, time=169),
#     Message('note_on', channel=1, note=76, velocity=0, time=85),
#     Message('note_on', channel=1, note=77, velocity=70, time=24),
#     Message('note_on', channel=1, note=76, velocity=56, time=73),
#     Message('note_on', channel=1, note=77, velocity=0, time=47),
#     Message('note_on', channel=1, note=76, velocity=0, time=3),
#     Message('note_on', channel=1, note=77, velocity=62, time=17),
#     Message('note_on', channel=1, note=77, velocity=0, time=63),
#     Message('note_on', channel=1, note=76, velocity=78, time=11),
#     Message('note_on', channel=1, note=76, velocity=0, time=58),
#     Message('note_on', channel=1, note=77, velocity=65, time=6),
#     Message('note_on', channel=1, note=77, velocity=0, time=60),
#     Message('note_on', channel=1, note=76, velocity=75, time=5),
#     Message('note_on', channel=1, note=77, velocity=74, time=57),
#     Message('note_on', channel=1, note=76, velocity=0, time=12),
#     Message('note_on', channel=1, note=76, velocity=75, time=53),
#     Message('note_on', channel=1, note=77, velocity=0, time=20),
#     Message('note_on', channel=1, note=76, velocity=0, time=53),
#     Message('note_on', channel=1, note=74, velocity=80, time=68),
#     Message('note_on', channel=1, note=74, velocity=0, time=71),
#     Message('note_on', channel=1, note=76, velocity=76, time=49),
#     Message('note_on', channel=1, note=76, velocity=0, time=81),
#     Message('note_on', channel=1, note=77, velocity=76, time=39),
#     Message('note_on', channel=1, note=77, velocity=0, time=106),
#     Message('note_on', channel=1, note=86, velocity=85, time=134),
#     Message('note_on', channel=1, note=86, velocity=0, time=85),
#     Message('note_on', channel=1, note=83, velocity=81, time=155),
#     Message('note_on', channel=1, note=83, velocity=0, time=89),
#     Message('note_on', channel=1, note=77, velocity=75, time=151),
#     Message('note_on', channel=1, note=77, velocity=0, time=85),
#     Message('note_on', channel=1, note=74, velocity=80, time=107),
#     Message('note_on', channel=1, note=74, velocity=0, time=62),
#     Message('note_on', channel=1, note=76, velocity=72, time=1),
#     Message('note_on', channel=1, note=76, velocity=0, time=64),
#     Message('note_on', channel=1, note=74, velocity=75, time=10),
#     Message('note_on', channel=1, note=74, velocity=0, time=60),
#     Message('note_on', channel=1, note=76, velocity=74, time=7),
#     Message('note_on', channel=1, note=76, velocity=0, time=63),
#     Message('note_on', channel=1, note=74, velocity=75, time=7),
#     Message('note_on', channel=1, note=74, velocity=0, time=62),
#     Message('note_on', channel=1, note=76, velocity=71, time=6),
#     Message('note_on', channel=1, note=76, velocity=0, time=60),
#     Message('note_on', channel=1, note=74, velocity=76, time=6),
#     Message('note_on', channel=1, note=74, velocity=0, time=73),
#     Message('note_on', channel=1, note=76, velocity=72, time=0),
#     Message('note_on', channel=1, note=76, velocity=0, time=47),
#     Message('note_on', channel=1, note=74, velocity=73, time=12),
#     Message('note_on', channel=1, note=76, velocity=76, time=67),
#     Message('note_on', channel=1, note=74, velocity=0, time=2),
#     Message('note_on', channel=1, note=76, velocity=0, time=74),
#     Message('note_on', channel=1, note=74, velocity=66, time=7),
#     Message('note_on', channel=1, note=74, velocity=0, time=54),
#     Message('note_on', channel=1, note=72, velocity=85, time=24),
#     Message('note_on', channel=1, note=72, velocity=0, time=76),
#     Message('note_on', channel=1, note=74, velocity=85, time=44),
#     Message('note_on', channel=1, note=74, velocity=0, time=67),
#     Message('note_on', channel=1, note=76, velocity=85, time=53),
#     Message('note_on', channel=1, note=76, velocity=0, time=80),
#     Message('note_on', channel=1, note=74, velocity=79, time=160),
#     Message('note_on', channel=1, note=74, velocity=0, time=71),
#     Message('note_on', channel=1, note=76, velocity=74, time=49),
#     Message('note_on', channel=1, note=76, velocity=0, time=88),
#     Message('note_on', channel=1, note=77, velocity=76, time=32),
#     Message('note_on', channel=1, note=77, velocity=0, time=73),
#     Message('note_on', channel=1, note=76, velocity=76, time=167),
#     Message('note_on', channel=1, note=76, velocity=0, time=76),
#     Message('note_on', channel=1, note=77, velocity=75, time=44),
#     Message('note_on', channel=1, note=77, velocity=0, time=77),
#     Message('note_on', channel=1, note=79, velocity=77, time=43),
#     Message('note_on', channel=1, note=79, velocity=0, time=72),
#     Message('note_on', channel=1, note=77, velocity=77, time=168),
#     Message('note_on', channel=1, note=77, velocity=0, time=71),
#     Message('note_on', channel=1, note=79, velocity=76, time=49),
#     Message('note_on', channel=1, note=79, velocity=0, time=75),
#     Message('note_on', channel=1, note=81, velocity=75, time=45),
#     Message('note_on', channel=1, note=81, velocity=0, time=60),
#     Message('note_on', channel=1, note=79, velocity=79, time=180),
#     Message('note_on', channel=1, note=79, velocity=0, time=68),
#     Message('note_on', channel=1, note=81, velocity=77, time=52),
#     Message('note_on', channel=1, note=81, velocity=0, time=67),
#     Message('note_on', channel=1, note=83, velocity=75, time=53),
#     Message('note_on', channel=1, note=83, velocity=0, time=118),
#     Message('note_on', channel=1, note=84, velocity=75, time=2),
#     Message('note_on', channel=1, note=84, velocity=0, time=118),
#     Message('note_on', channel=1, note=85, velocity=75, time=2),
#     Message('note_on', channel=1, note=85, velocity=0, time=118),
#     Message('note_on', channel=1, note=86, velocity=75, time=2),
#     Message('note_on', channel=1, note=86, velocity=0, time=118),
#     Message('note_on', channel=1, note=87, velocity=75, time=2),
#     Message('note_on', channel=1, note=87, velocity=0, time=118),
#     Message('note_on', channel=1, note=88, velocity=75, time=2),
#     Message('note_on', channel=1, note=88, velocity=0, time=118),
#     Message('note_on', channel=1, note=89, velocity=75, time=2),
#     Message('note_on', channel=1, note=89, velocity=0, time=118),
#     Message('note_on', channel=1, note=90, velocity=75, time=2),
#     Message('note_on', channel=1, note=90, velocity=0, time=118),
#     Message('note_on', channel=1, note=91, velocity=75, time=2),
#     Message('note_on', channel=1, note=91, velocity=0, time=478),
#     Message('note_on', channel=1, note=79, velocity=83, time=5522),
#     Message('note_on', channel=1, note=79, velocity=0, time=81),
#     Message('note_on', channel=1, note=88, velocity=78, time=39),
#     Message('note_on', channel=1, note=88, velocity=0, time=84),
#     Message('note_on', channel=1, note=84, velocity=88, time=36),
#     Message('note_on', channel=1, note=84, velocity=0, time=249),
#     Message('note_on', channel=1, note=77, velocity=76, time=1431),
#     Message('note_on', channel=1, note=77, velocity=0, time=76),
#     Message('note_on', channel=1, note=86, velocity=74, time=44),
#     Message('note_on', channel=1, note=86, velocity=0, time=80),
#     Message('note_on', channel=1, note=83, velocity=85, time=40),
#     Message('note_on', channel=1, note=83, velocity=0, time=324),
#     Message('note_on', channel=1, note=77, velocity=75, time=1356),
#     Message('note_on', channel=1, note=77, velocity=0, time=88),
#     Message('note_on', channel=1, note=81, velocity=69, time=32),
#     Message('note_on', channel=1, note=79, velocity=74, time=120),
#     Message('note_on', channel=1, note=81, velocity=0, time=5),
#     Message('note_on', channel=1, note=79, velocity=0, time=316),
#     Message('note_on', channel=1, note=77, velocity=76, time=3279),
#     Message('note_on', channel=1, note=77, velocity=0, time=85),
#     Message('note_on', channel=1, note=81, velocity=74, time=35),
#     Message('note_on', channel=1, note=86, velocity=75, time=120),
#     Message('note_on', channel=1, note=81, velocity=0, time=16),
#     Message('note_on', channel=1, note=86, velocity=0, time=276),
#     Message('note_on', channel=1, note=83, velocity=66, time=188),
#     Message('note_on', channel=1, note=86, velocity=73, time=0),
#     Message('note_on', channel=1, note=83, velocity=0, time=763),
#     Message('note_on', channel=1, note=86, velocity=0, time=16),
#     Message('note_on', channel=1, note=81, velocity=68, time=181),
#     Message('note_on', channel=1, note=84, velocity=76, time=0),
#     Message('note_on', channel=1, note=81, velocity=0, time=383),
#     Message('note_on', channel=1, note=84, velocity=0, time=18),
#     Message('note_on', channel=1, note=79, velocity=71, time=79),
#     Message('note_on', channel=1, note=83, velocity=74, time=0),
#     Message('note_on', channel=1, note=79, velocity=0, time=333),
#     Message('note_on', channel=1, note=83, velocity=0, time=23),
#     Message('note_on', channel=1, note=79, velocity=68, time=124),
#     Message('note_on', channel=1, note=84, velocity=71, time=0),
#     Message('note_on', channel=1, note=84, velocity=0, time=1119),
#     Message('note_on', channel=1, note=79, velocity=0, time=6),
#     Message('note_on', channel=1, note=72, velocity=62, time=795),
#     Message('note_on', channel=1, note=76, velocity=70, time=0),
#     Message('note_on', channel=1, note=76, velocity=0, time=1690),
#     Message('note_on', channel=1, note=72, velocity=0, time=27),
#     Message('note_on', channel=1, note=76, velocity=83, time=443),
#     Message('note_on', channel=1, note=76, velocity=0, time=110),
#     Message('note_on', channel=1, note=79, velocity=75, time=10),
#     Message('note_on', channel=1, note=79, velocity=0, time=119),
#     Message('note_on', channel=1, note=84, velocity=78, time=1),
#     Message('note_on', channel=1, note=84, velocity=0, time=94),
#     Message('note_on', channel=1, note=79, velocity=75, time=146),
#     Message('note_on', channel=1, note=79, velocity=0, time=92),
#     Message('note_on', channel=1, note=84, velocity=78, time=28),
#     Message('note_on', channel=1, note=84, velocity=0, time=93),
#     Message('note_on', channel=1, note=88, velocity=76, time=27),
#     Message('note_on', channel=1, note=88, velocity=0, time=63),
#     Message('note_on', channel=1, note=84, velocity=76, time=177),
#     Message('note_on', channel=1, note=84, velocity=0, time=102),
#     Message('note_on', channel=1, note=88, velocity=76, time=18),
#     Message('note_on', channel=1, note=88, velocity=0, time=102),
#     Message('note_on', channel=1, note=91, velocity=74, time=18),
#     Message('note_on', channel=1, note=91, velocity=0, time=115),
#     Message('note_on', channel=1, note=89, velocity=69, time=5),
#     Message('note_on', channel=1, note=89, velocity=0, time=111),
#     Message('note_on', channel=1, note=88, velocity=63, time=9),
#     Message('note_on', channel=1, note=88, velocity=0, time=103),
#     Message('note_on', channel=1, note=91, velocity=75, time=17),
#     Message('note_on', channel=1, note=91, velocity=0, time=115),
#     Message('note_on', channel=1, note=89, velocity=75, time=5),
#     Message('note_on', channel=1, note=89, velocity=0, time=572),
#     Message('note_on', channel=1, note=79, velocity=72, time=1588),
#     Message('note_on', channel=1, note=83, velocity=75, time=120),
#     Message('note_on', channel=1, note=79, velocity=0, time=60),
#     Message('note_on', channel=1, note=83, velocity=0, time=36),
#     Message('note_on', channel=1, note=86, velocity=74, time=24),
#     Message('note_on', channel=1, note=86, velocity=0, time=89),
#     Message('note_on', channel=1, note=83, velocity=76, time=151),
#     Message('note_on', channel=1, note=83, velocity=0, time=113),
#     Message('note_on', channel=1, note=86, velocity=74, time=7),
#     Message('note_on', channel=1, note=86, velocity=0, time=99),
#     Message('note_on', channel=1, note=91, velocity=76, time=21),
#     Message('note_on', channel=1, note=91, velocity=0, time=59),
#     Message('note_on', channel=1, note=86, velocity=78, time=181),
#     Message('note_on', channel=1, note=86, velocity=0, time=82),
#     Message('note_on', channel=1, note=91, velocity=74, time=38),
#     Message('note_on', channel=1, note=91, velocity=0, time=93),
#     Message('note_on', channel=1, note=95, velocity=71, time=27),
#     Message('note_on', channel=1, note=95, velocity=0, time=72),
#     Message('note_on', channel=1, note=76, velocity=65, time=408),
#     Message('note_on', channel=1, note=79, velocity=65, time=0),
#     Message('note_on', channel=1, note=76, velocity=0, time=1542),
#     Message('note_on', channel=1, note=79, velocity=0, time=35),
#     Message('note_on', channel=1, note=72, velocity=59, time=343),
#     Message('note_on', channel=1, note=76, velocity=65, time=0),
#     Message('note_on', channel=1, note=72, velocity=0, time=716),
#     Message('note_on', channel=1, note=76, velocity=0, time=78),
#     Message('note_on', channel=1, note=76, velocity=67, time=166),
#     Message('note_on', channel=1, note=79, velocity=67, time=0),
#     Message('note_on', channel=1, note=76, velocity=0, time=94),
#     Message('note_on', channel=1, note=79, velocity=0, time=3),
#     Message('note_on', channel=1, note=79, velocity=78, time=143),
#     Message('note_on', channel=1, note=79, velocity=0, time=73),
#     Message('note_on', channel=1, note=84, velocity=81, time=47),
#     Message('note_on', channel=1, note=84, velocity=0, time=73),
#     Message('note_on', channel=1, note=88, velocity=78, time=47),
#     Message('note_on', channel=1, note=88, velocity=0, time=76),
#     Message('note_on', channel=1, note=86, velocity=64, time=404),
#     Message('note_on', channel=1, note=89, velocity=70, time=0),
#     Message('note_on', channel=1, note=86, velocity=0, time=935),
#     Message('note_on', channel=1, note=89, velocity=0, time=7),
#     Message('note_on', channel=1, note=84, velocity=70, time=18),
#     Message('note_on', channel=1, note=88, velocity=74, time=0),
#     Message('note_on', channel=1, note=88, velocity=0, time=320),
#     Message('note_on', channel=1, note=84, velocity=0, time=3),
#     Message('note_on', channel=1, note=83, velocity=64, time=157),
#     Message('note_on', channel=1, note=86, velocity=70, time=0),
#     Message('note_on', channel=1, note=83, velocity=0, time=326),
#     Message('note_on', channel=1, note=86, velocity=0, time=12),
#     Message('note_on', channel=1, note=84, velocity=70, time=142),
#     Message('note_on', channel=1, note=88, velocity=76, time=0),
#     Message('note_on', channel=1, note=88, velocity=0, time=209),
#     Message('note_on', channel=1, note=84, velocity=0, time=29),
#     Message('note_on', channel=1, note=84, velocity=80, time=2),
#     Message('note_on', channel=1, note=84, velocity=0, time=75),
#     Message('note_on', channel=1, note=86, velocity=63, time=45),
#     Message('note_on', channel=1, note=86, velocity=0, time=89),
#     Message('note_on', channel=1, note=88, velocity=74, time=31),
#     Message('note_on', channel=1, note=88, velocity=0, time=103),
#     Message('note_on', channel=1, note=86, velocity=67, time=17),
#     Message('note_on', channel=1, note=86, velocity=0, time=109),
#     Message('note_on', channel=1, note=84, velocity=74, time=11),
#     Message('note_on', channel=1, note=84, velocity=0, time=89),
#     Message('note_on', channel=1, note=86, velocity=69, time=31),
#     Message('note_on', channel=1, note=86, velocity=0, time=105),
#     Message('note_on', channel=1, note=84, velocity=88, time=15),
#     Message('note_on', channel=1, note=84, velocity=0, time=236),
#     Message('note_on', channel=1, note=76, velocity=80, time=484),
#     Message('note_on', channel=1, note=76, velocity=0, time=71),
#     Message('note_on', channel=1, note=77, velocity=74, time=49),
#     Message('note_on', channel=1, note=77, velocity=0, time=102),
#     Message('note_on', channel=1, note=79, velocity=81, time=18),
#     Message('note_on', channel=1, note=79, velocity=0, time=129),
#     Message('note_on', channel=1, note=88, velocity=79, time=111),
#     Message('note_on', channel=1, note=88, velocity=0, time=110),
#     Message('note_on', channel=1, note=84, velocity=83, time=130),
#     Message('note_on', channel=1, note=84, velocity=0, time=97),
#     Message('note_on', channel=1, note=79, velocity=81, time=143),
#     Message('note_on', channel=1, note=79, velocity=0, time=76),
#     Message('note_on', channel=1, note=76, velocity=85, time=169),
#     Message('note_on', channel=1, note=76, velocity=0, time=85),
#     Message('note_on', channel=1, note=77, velocity=70, time=24),
#     Message('note_on', channel=1, note=76, velocity=56, time=73),
#     Message('note_on', channel=1, note=77, velocity=0, time=47),
#     Message('note_on', channel=1, note=76, velocity=0, time=3),
#     Message('note_on', channel=1, note=77, velocity=62, time=17),
#     Message('note_on', channel=1, note=77, velocity=0, time=63),
#     Message('note_on', channel=1, note=76, velocity=78, time=11),
#     Message('note_on', channel=1, note=76, velocity=0, time=58),
#     Message('note_on', channel=1, note=77, velocity=65, time=6),
#     Message('note_on', channel=1, note=77, velocity=0, time=60),
#     Message('note_on', channel=1, note=76, velocity=75, time=5),
#     Message('note_on', channel=1, note=77, velocity=74, time=57),
#     Message('note_on', channel=1, note=76, velocity=0, time=12),
#     Message('note_on', channel=1, note=76, velocity=75, time=53),
#     Message('note_on', channel=1, note=77, velocity=0, time=20),
#     Message('note_on', channel=1, note=76, velocity=0, time=53),
#     Message('note_on', channel=1, note=74, velocity=80, time=68),
#     Message('note_on', channel=1, note=74, velocity=0, time=71),
#     Message('note_on', channel=1, note=76, velocity=76, time=49),
#     Message('note_on', channel=1, note=76, velocity=0, time=81),
#     Message('note_on', channel=1, note=77, velocity=76, time=39),
#     Message('note_on', channel=1, note=77, velocity=0, time=106),
#     Message('note_on', channel=1, note=86, velocity=85, time=134),
#     Message('note_on', channel=1, note=86, velocity=0, time=85),
#     Message('note_on', channel=1, note=83, velocity=81, time=155),
#     Message('note_on', channel=1, note=83, velocity=0, time=89),
#     Message('note_on', channel=1, note=77, velocity=75, time=151),
#     Message('note_on', channel=1, note=77, velocity=0, time=85),
#     Message('note_on', channel=1, note=74, velocity=80, time=107),
#     Message('note_on', channel=1, note=74, velocity=0, time=62),
#     Message('note_on', channel=1, note=76, velocity=72, time=1),
#     Message('note_on', channel=1, note=76, velocity=0, time=64),
#     Message('note_on', channel=1, note=74, velocity=75, time=10),
#     Message('note_on', channel=1, note=74, velocity=0, time=60),
#     Message('note_on', channel=1, note=76, velocity=74, time=7),
#     Message('note_on', channel=1, note=76, velocity=0, time=63),
#     Message('note_on', channel=1, note=74, velocity=75, time=7),
#     Message('note_on', channel=1, note=74, velocity=0, time=62),
#     Message('note_on', channel=1, note=76, velocity=71, time=6),
#     Message('note_on', channel=1, note=76, velocity=0, time=60),
#     Message('note_on', channel=1, note=74, velocity=76, time=6),
#     Message('note_on', channel=1, note=74, velocity=0, time=73),
#     Message('note_on', channel=1, note=76, velocity=72, time=0),
#     Message('note_on', channel=1, note=76, velocity=0, time=47),
#     Message('note_on', channel=1, note=74, velocity=73, time=12),
#     Message('note_on', channel=1, note=76, velocity=76, time=67),
#     Message('note_on', channel=1, note=74, velocity=0, time=2),
#     Message('note_on', channel=1, note=76, velocity=0, time=74),
#     Message('note_on', channel=1, note=74, velocity=66, time=7),
#     Message('note_on', channel=1, note=74, velocity=0, time=54),
#     Message('note_on', channel=1, note=72, velocity=85, time=24),
#     Message('note_on', channel=1, note=72, velocity=0, time=76),
#     Message('note_on', channel=1, note=74, velocity=85, time=44),
#     Message('note_on', channel=1, note=74, velocity=0, time=67),
#     Message('note_on', channel=1, note=76, velocity=85, time=53),
#     Message('note_on', channel=1, note=76, velocity=0, time=80),
#     Message('note_on', channel=1, note=74, velocity=79, time=160),
#     Message('note_on', channel=1, note=74, velocity=0, time=71),
#     Message('note_on', channel=1, note=76, velocity=74, time=49),
#     Message('note_on', channel=1, note=76, velocity=0, time=88),
#     Message('note_on', channel=1, note=77, velocity=76, time=32),
#     Message('note_on', channel=1, note=77, velocity=0, time=73),
# ...
#     Message('note_on', channel=2, note=64, velocity=78, time=0),
#     Message('note_on', channel=2, note=43, velocity=0, time=56),
#     Message('note_on', channel=2, note=48, velocity=74, time=184),
#     Message('note_on', channel=2, note=64, velocity=0, time=33),
#     Message('note_on', channel=2, note=60, velocity=0, time=17),
#     Message('note_on', channel=2, note=55, velocity=0, time=1),
#     Message('note_on', channel=2, note=55, velocity=75, time=189),
#     Message('note_on', channel=2, note=60, velocity=78, time=0),
#     Message('note_on', channel=2, note=64, velocity=80, time=0),
#     Message('note_on', channel=2, note=43, velocity=74, time=240),
#     Message('note_on', channel=2, note=48, velocity=0, time=10),
#     Message('note_on', channel=2, note=55, velocity=0, time=124),
#     Message('note_on', channel=2, note=64, velocity=0, time=15),
#     Message('note_on', channel=2, note=60, velocity=0, time=3),
#     Message('note_on', channel=2, note=55, velocity=74, time=88),
#     Message('note_on', channel=2, note=60, velocity=77, time=0),
#     Message('note_on', channel=2, note=64, velocity=77, time=0),
#     Message('note_on', channel=2, note=43, velocity=0, time=83),
#     Message('note_on', channel=2, note=48, velocity=76, time=157),
#     Message('note_on', channel=2, note=64, velocity=0, time=33),
#     Message('note_on', channel=2, note=60, velocity=0, time=31),
#     Message('note_on', channel=2, note=55, velocity=0, time=17),
#     Message('control_change', channel=2, control=64, value=127, time=93),
#     Message('note_on', channel=2, note=55, velocity=74, time=66),
#     Message('note_on', channel=2, note=60, velocity=74, time=240),
#     Message('note_on', channel=2, note=55, velocity=0, time=43),
#     Message('note_on', channel=2, note=60, velocity=0, time=66),
#     Message('note_on', channel=2, note=55, velocity=77, time=131),
#     Message('note_on', channel=2, note=60, velocity=77, time=0),
#     Message('note_on', channel=2, note=64, velocity=81, time=0),
#     Message('note_on', channel=2, note=48, velocity=0, time=57),
#     Message('note_on', channel=2, note=48, velocity=68, time=183),
#     Message('note_on', channel=2, note=55, velocity=0, time=16),
#     Message('note_on', channel=2, note=60, velocity=0, time=61),
#     Message('note_on', channel=2, note=64, velocity=0, time=1),
#     Message('note_on', channel=2, note=55, velocity=68, time=162),
#     Message('note_on', channel=2, note=55, velocity=0, time=105),
#     Message('note_on', channel=2, note=55, velocity=76, time=135),
#     Message('note_on', channel=2, note=60, velocity=76, time=0),
#     Message('note_on', channel=2, note=64, velocity=75, time=0),
#     Message('note_on', channel=2, note=55, velocity=0, time=87),
#     Message('note_on', channel=2, note=60, velocity=0, time=149),
#     Message('note_on', channel=2, note=55, velocity=61, time=4),
#     Message('note_on', channel=2, note=64, velocity=0, time=15),
#     Message('note_on', channel=2, note=48, velocity=0, time=22),
#     Message('note_on', channel=2, note=55, velocity=0, time=17),
#     Message('control_change', channel=2, control=64, value=0, time=81),
#     Message('note_on', channel=2, note=48, velocity=71, time=105),
#     Message('note_on', channel=2, note=55, velocity=68, time=0),
#     Message('note_on', channel=2, note=60, velocity=69, time=0),
#     Message('control_change', channel=2, control=64, value=127, time=14),
#     Message('note_on', channel=2, note=55, velocity=0, time=89),
#     Message('note_on', channel=2, note=55, velocity=62, time=137),
#     Message('note_on', channel=2, note=60, velocity=0, time=48),
#     Message('note_on', channel=2, note=55, velocity=0, time=85),
#     Message('note_on', channel=2, note=60, velocity=68, time=107),
#     Message('note_on', channel=2, note=60, velocity=0, time=106),
#     Message('note_on', channel=2, note=55, velocity=75, time=134),
#     Message('note_on', channel=2, note=60, velocity=75, time=0),
#     Message('note_on', channel=2, note=64, velocity=76, time=0),
#     Message('note_on', channel=2, note=55, velocity=0, time=133),
#     Message('note_on', channel=2, note=55, velocity=64, time=107),
#     Message('note_on', channel=2, note=60, velocity=0, time=26),
#     Message('note_on', channel=2, note=64, velocity=0, time=90),
#     Message('note_on', channel=2, note=60, velocity=74, time=124),
#     Message('note_on', channel=2, note=55, velocity=0, time=60),
#     Message('note_on', channel=2, note=60, velocity=0, time=19),
#     Message('note_on', channel=2, note=55, velocity=75, time=161),
#     Message('note_on', channel=2, note=64, velocity=80, time=0),
#     Message('note_on', channel=2, note=55, velocity=0, time=78),
#     Message('note_on', channel=2, note=55, velocity=75, time=162),
#     Message('note_on', channel=2, note=64, velocity=0, time=22),
#     Message('note_on', channel=2, note=48, velocity=0, time=109),
#     Message('note_on', channel=2, note=55, velocity=0, time=0),
#     Message('control_change', channel=2, control=64, value=0, time=39),
#     Message('note_on', channel=2, note=43, velocity=74, time=70),
#     Message('note_on', channel=2, note=55, velocity=72, time=0),
#     Message('note_on', channel=2, note=59, velocity=70, time=0),
#     Message('control_change', channel=2, control=64, value=127, time=87),
#     Message('note_on', channel=2, note=55, velocity=0, time=90),
#     Message('note_on', channel=2, note=50, velocity=66, time=63),
#     Message('note_on', channel=2, note=59, velocity=0, time=22),
#     Message('note_on', channel=2, note=55, velocity=75, time=218),
#     Message('note_on', channel=2, note=55, velocity=0, time=124),
#     Message('note_on', channel=2, note=55, velocity=74, time=116),
#     Message('note_on', channel=2, note=62, velocity=75, time=0),
#     Message('note_on', channel=2, note=55, velocity=0, time=283),
#     Message('note_on', channel=2, note=62, velocity=0, time=90),
#     Message('note_on', channel=2, note=55, velocity=74, time=107),
#     Message('note_on', channel=2, note=55, velocity=0, time=99),
#     Message('note_on', channel=2, note=55, velocity=76, time=141),
#     Message('note_on', channel=2, note=59, velocity=76, time=0),
#     Message('note_on', channel=2, note=55, velocity=0, time=86),
#     Message('note_on', channel=2, note=50, velocity=0, time=43),
#     Message('note_on', channel=2, note=59, velocity=0, time=30),
#     Message('note_on', channel=2, note=43, velocity=0, time=16),
#     Message('note_on', channel=2, note=55, velocity=70, time=65),
#     Message('note_on', channel=2, note=55, velocity=0, time=132),
#     Message('control_change', channel=2, control=64, value=0, time=6),
#     Message('note_on', channel=2, note=43, velocity=74, time=102),
#     Message('note_on', channel=2, note=55, velocity=70, time=0),
#     Message('note_on', channel=2, note=59, velocity=65, time=0),
#     Message('control_change', channel=2, control=64, value=127, time=35),
#     Message('note_on', channel=2, note=55, velocity=0, time=110),
#     Message('note_on', channel=2, note=59, velocity=0, time=64),
#     Message('note_on', channel=2, note=50, velocity=63, time=31),
#     Message('note_on', channel=2, note=55, velocity=74, time=240),
#     Message('note_on', channel=2, note=55, velocity=0, time=110),
#     Message('note_on', channel=2, note=55, velocity=76, time=130),
#     Message('note_on', channel=2, note=62, velocity=74, time=0),
#     Message('note_on', channel=2, note=55, velocity=0, time=238),
#     Message('note_on', channel=2, note=62, velocity=0, time=19),
#     Message('note_on', channel=2, note=55, velocity=74, time=223),
#     Message('note_on', channel=2, note=55, velocity=0, time=120),
#     Message('note_on', channel=2, note=55, velocity=76, time=120),
#     Message('note_on', channel=2, note=59, velocity=76, time=0),
#     Message('note_on', channel=2, note=55, velocity=0, time=89),
#     Message('note_on', channel=2, note=59, velocity=0, time=115),
#     Message('note_on', channel=2, note=55, velocity=70, time=36),
#     Message('control_change', channel=2, control=64, value=0, time=60),
#     Message('note_on', channel=2, note=50, velocity=0, time=0),
#     Message('note_on', channel=2, note=43, velocity=0, time=11),
#     Message('note_on', channel=2, note=55, velocity=0, time=28),
#     Message('control_change', channel=2, control=64, value=127, time=95),
#     Message('control_change', channel=2, control=64, value=127, time=10),
#     Message('note_on', channel=2, note=48, velocity=72, time=36),
#     Message('control_change', channel=2, control=64, value=0, time=214),
#     Message('note_on', channel=2, note=55, velocity=74, time=26),
#     Message('note_on', channel=2, note=60, velocity=74, time=0),
#     Message('note_on', channel=2, note=48, velocity=0, time=140),
#     Message('note_on', channel=2, note=60, velocity=0, time=49),
#     Message('note_on', channel=2, note=55, velocity=0, time=1),
#     Message('note_on', channel=2, note=43, velocity=62, time=50),
#     Message('note_on', channel=2, note=55, velocity=75, time=240),
#     Message('note_on', channel=2, note=60, velocity=76, time=0),
#     Message('note_on', channel=2, note=64, velocity=76, time=0),
#     Message('note_on', channel=2, note=43, velocity=0, time=76),
#     Message('note_on', channel=2, note=60, velocity=0, time=25),
#     Message('note_on', channel=2, note=55, velocity=0, time=5),
#     Message('note_on', channel=2, note=64, velocity=0, time=0),
#     Message('note_on', channel=2, note=48, velocity=67, time=134),
#     Message('note_on', channel=2, note=55, velocity=75, time=240),
#     Message('note_on', channel=2, note=60, velocity=75, time=0),
#     Message('note_on', channel=2, note=64, velocity=77, time=0),
#     Message('note_on', channel=2, note=48, velocity=0, time=236),
#     Message('note_on', channel=2, note=43, velocity=70, time=4),
#     Message('note_on', channel=2, note=64, velocity=0, time=91),
#     Message('note_on', channel=2, note=60, velocity=0, time=4),
#     Message('note_on', channel=2, note=55, velocity=0, time=5),
#     Message('note_on', channel=2, note=55, velocity=75, time=140),
#     Message('note_on', channel=2, note=60, velocity=77, time=0),
#     Message('note_on', channel=2, note=64, velocity=77, time=0),
#     Message('note_on', channel=2, note=64, velocity=0, time=89),
#     Message('note_on', channel=2, note=43, velocity=0, time=6),
#     Message('note_on', channel=2, note=60, velocity=0, time=8),
#     Message('note_on', channel=2, note=55, velocity=0, time=10),
#     Message('note_on', channel=2, note=48, velocity=68, time=127),
#     Message('note_on', channel=2, note=55, velocity=75, time=240),
#     Message('note_on', channel=2, note=60, velocity=76, time=0),
#     Message('note_on', channel=2, note=64, velocity=78, time=0),
#     Message('note_on', channel=2, note=48, velocity=0, time=224),
#     Message('note_on', channel=2, note=43, velocity=68, time=16),
#     Message('note_on', channel=2, note=64, velocity=0, time=48),
#     Message('note_on', channel=2, note=60, velocity=0, time=2),
#     Message('note_on', channel=2, note=55, velocity=0, time=13),
#     Message('note_on', channel=2, note=55, velocity=76, time=177),
#     Message('note_on', channel=2, note=60, velocity=77, time=0),
#     Message('note_on', channel=2, note=64, velocity=72, time=0),
#     Message('note_on', channel=2, note=43, velocity=0, time=57),
#     Message('note_on', channel=2, note=60, velocity=0, time=38),
#     Message('note_on', channel=2, note=55, velocity=0, time=14),
#     Message('note_on', channel=2, note=64, velocity=0, time=2),
#     Message('note_on', channel=2, note=48, velocity=67, time=129),
#     Message('note_on', channel=2, note=55, velocity=75, time=240),
#     Message('note_on', channel=2, note=60, velocity=76, time=0),
#     Message('note_on', channel=2, note=64, velocity=78, time=0),
#     Message('note_on', channel=2, note=43, velocity=74, time=240),
#     Message('note_on', channel=2, note=48, velocity=0, time=6),
#     Message('note_on', channel=2, note=64, velocity=0, time=112),
#     Message('note_on', channel=2, note=55, velocity=0, time=3),
#     Message('note_on', channel=2, note=60, velocity=0, time=3),
#     Message('note_on', channel=2, note=55, velocity=75, time=116),
#     Message('note_on', channel=2, note=60, velocity=74, time=0),
#     Message('note_on', channel=2, note=64, velocity=76, time=0),
#     Message('note_on', channel=2, note=43, velocity=0, time=142),
#     Message('note_on', channel=2, note=43, velocity=76, time=98),
#     Message('note_on', channel=2, note=64, velocity=0, time=59),
#     Message('note_on', channel=2, note=60, velocity=0, time=1),
#     Message('note_on', channel=2, note=55, velocity=0, time=80),
#     Message('note_on', channel=2, note=55, velocity=75, time=100),
#     Message('note_on', channel=2, note=59, velocity=79, time=0),
#     Message('note_on', channel=2, note=50, velocity=72, time=240),
#     Message('note_on', channel=2, note=59, velocity=0, time=65),
#     Message('note_on', channel=2, note=55, velocity=0, time=2),
#     Message('note_on', channel=2, note=43, velocity=0, time=14),
#     Message('note_on', channel=2, note=55, velocity=74, time=159),
#     Message('note_on', channel=2, note=59, velocity=77, time=0),
#     Message('note_on', channel=2, note=50, velocity=0, time=112),
#     Message('note_on', channel=2, note=59, velocity=0, time=43),
#     Message('note_on', channel=2, note=55, velocity=0, time=16),
#     Message('note_on', channel=2, note=43, velocity=72, time=69),
#     Message('note_on', channel=2, note=55, velocity=70, time=240),
#     Message('note_on', channel=2, note=59, velocity=74, time=0),
#     Message('note_on', channel=2, note=62, velocity=75, time=0),
#     Message('note_on', channel=2, note=43, velocity=0, time=103),
#     Message('note_on', channel=2, note=50, velocity=69, time=137),
#     Message('note_on', channel=2, note=62, velocity=0, time=104),
#     Message('note_on', channel=2, note=59, velocity=0, time=2),
#     Message('note_on', channel=2, note=55, velocity=0, time=11),
#     Message('note_on', channel=2, note=55, velocity=74, time=123),
#     Message('note_on', channel=2, note=59, velocity=74, time=0),
#     Message('note_on', channel=2, note=62, velocity=75, time=0),
#     Message('note_on', channel=2, note=50, velocity=0, time=153),
#     Message('note_on', channel=2, note=59, velocity=0, time=47),
#     Message('note_on', channel=2, note=62, velocity=0, time=14),
#     Message('note_on', channel=2, note=55, velocity=0, time=7),
#     Message('note_on', channel=2, note=48, velocity=70, time=19),
#     Message('note_on', channel=2, note=55, velocity=69, time=240),
#     Message('note_on', channel=2, note=60, velocity=71, time=0),
#     Message('note_on', channel=2, note=64, velocity=76, time=0),
#     Message('note_on', channel=2, note=48, velocity=0, time=204),
#     Message('note_on', channel=2, note=43, velocity=74, time=36),
#     Message('note_on', channel=2, note=64, velocity=0, time=13),
#     Message('note_on', channel=2, note=55, velocity=0, time=53),
#     Message('note_on', channel=2, note=60, velocity=0, time=30),
#     Message('note_on', channel=2, note=55, velocity=74, time=144),
#     Message('note_on', channel=2, note=60, velocity=75, time=0),
#     Message('note_on', channel=2, note=64, velocity=76, time=0),
#     Message('note_on', channel=2, note=43, velocity=0, time=90),
#     Message('note_on', channel=2, note=55, velocity=61, time=19),
#     Message('note_on', channel=2, note=64, velocity=0, time=47),
#     Message('note_on', channel=2, note=60, velocity=0, time=15),
#     Message('note_on', channel=2, note=55, velocity=0, time=3),
#     Message('note_on', channel=2, note=55, velocity=0, time=0),
#     Message('note_on', channel=2, note=60, velocity=69, time=5),
#     Message('note_on', channel=2, note=48, velocity=78, time=4),
#     Message('control_change', channel=2, control=64, value=127, time=52),
#     Message('note_on', channel=2, note=64, velocity=73, time=14),
#     Message('note_on', channel=2, note=48, velocity=0, time=951),
#     Message('note_on', channel=2, note=64, velocity=0, time=5),
#     Message('note_on', channel=2, note=60, velocity=0, time=16),
#     Message('control_change', channel=2, control=64, value=0, time=832),
#     MetaMessage('end_of_track', time=1)])
# ])

# %% [markdown]
#  # About output
#
# Here's what each part is telling you:
#
# MidiFile(type=1, ticks_per_beat=480, tracks=[...]): The MIDI file is of type 1, which means it has multiple tracks that are meant to be played synchronously. The ticks_per_beat value is 480, which tells us the timing resolution of the file, i.e., there are 480 ticks per quarter note beat.
#
# First MidiTrack: This track primarily consists of meta-messages related to tempo:
# <br>**set_tempo messages:** These messages define the tempo of the music in microseconds per beat. For example,
# <br>**tempo=576923** means that each beat lasts 576,923 microseconds or approximately 0.577 seconds.
# <br>**time_signature message:** This sets the time signature of the music to 1/4, meaning that there is one beat per measure, and each beat is a quarter note. The clocks_per_click value of 24 and notated_32nd_notes_per_beat of 8 provide additional details about the timing.
# <br>**end_of_track message:** This marks the end of the track.
#
#
# Second MidiTrack:This track appears to represent a melody:
# <br>**track_name meta-message:** This names the track "MELODY."
# <br>**program_change message:** This sets the instrument sound to be used on channel 0. The value program=0 typically corresponds to a grand piano in the General MIDI standard.
# <br>**note_on messages:** These messages signal the start of a note. For example, the message note_on, channel=0, note=76, velocity=85, time=10529 means that on channel 0, note number 76 (E6 in standard tuning) is played with a velocity (i.e., volume) of 85, 10,529 ticks after the previous event. The following note_on with velocity=0 is a common way to represent a note-off event, meaning the note is released.
#
# Overall, this representation gives you a detailed look into the structure of the MIDI file, with insights into the tempo, timing, instrument sounds, and notes being played.

# %% [markdown]
# ## 2. Playing the MIDI File

# %%
#starts from the beginning each time not from where you left off

# import mido
# from mido import MidiFile
# import tkinter as tk
# import threading

# class MidiPlayer:
#     def __init__(self, filename):
#         self.midi_file = MidiFile(filename)
#         self.playing = False

#     def play_midi(self):
#         with mido.open_output() as port:
#             for message in self.midi_file.play():
#                 if not self.playing:
#                     break
#                 port.send(message)

#     def play(self):
#         if not self.playing:
#             self.playing = True
#             threading.Thread(target=self.play_midi).start()

#     def stop(self):
#         self.playing = False

# def play():
#     player.play()
#     lbl_status.config(text="Playing")

# def stop():
#     player.stop()
#     lbl_status.config(text="Stopped")

# player = MidiPlayer('POP909/909/909.mid')

# root = tk.Tk()
# root.title("MIDI Player")

# frame_buttons = tk.Frame(root)
# frame_buttons.pack()

# btn_play = tk.Button(frame_buttons, text="Play", command=play)
# btn_play.pack(side=tk.LEFT)

# btn_stop = tk.Button(frame_buttons, text="Stop", command=stop)
# btn_stop.pack(side=tk.LEFT)

# lbl_status = tk.Label(root, text="Stopped")
# lbl_status.pack()

# root.mainloop()

# %% [markdown]
# ## Play One of the Songs

# %%
# just comment out while reloading code because it plays everytime

# import mido
# from mido import MidiFile

# midi_file = MidiFile('POP909/909/909.mid')

# # Open output port with default backend
# with mido.open_output() as port:
#     for message in midi_file.play():
#         port.send(message)

# %% [markdown]
# ## 3. Analyzing & Processing the MIDI Data

# %% [markdown]
# Use the first midi file as a tester to see what information is in the files

# %%
import pretty_midi

# Load MIDI file
midi_data = pretty_midi.PrettyMIDI('POP909/909/909.mid')

# Print time signature changes
print("Time Signatures:")
for ts in midi_data.time_signature_changes:
    print(ts)

# Print tempo changes
print("\nTempo Changes:")
for tempo_change in midi_data.get_tempo_changes()[1]:
    print(tempo_change)

# Print instrument information
print("\nInstruments:")
for instrument in midi_data.instruments:
    print(f'Name: {instrument.name}, Program: {instrument.program}, Is drum: {instrument.is_drum}')

# Print some notes for the first instrument, if it has any
if midi_data.instruments:
    print("\nNotes for MELODY:")
    for note in midi_data.instruments[0].notes[:5]:  # Just the first 10 notes
        print(note)
        print(f"Duration: {note.end - note.start}")  # Adding duration
        
# Print some notes for the first instrument, if it has any
if midi_data.instruments:
    print("\nNotes for BRIDGE:")
    for note in midi_data.instruments[1].notes[:5]:  # Just the first 10 notes
        print(note)
        print(f"Duration: {note.end - note.start}")  # Adding duration
        
# Print some notes for the first instrument, if it has any
if midi_data.instruments:
    print("\nNotes for PIANO:")
    for note in midi_data.instruments[2].notes[:5]:  # Just the first 10 notes
        print(note)
        print(f"Duration: {note.end - note.start}")  # Adding duration
# Out:
# Time Signatures:
# 1/4 at 0.00 seconds
#
# Tempo Changes:
# 104.00001386666852
# 103.75022479215373
# 104.00001386666852
# 103.75022479215373
# 104.00001386666852
# 103.75022479215373
# 104.00001386666852
#
# Instruments:
# Name: MELODY, Program: 0, Is drum: False
# Name: BRIDGE, Program: 0, Is drum: False
# Name: PIANO, Program: 0, Is drum: False
#
# Notes for MELODY:
# Note(start=12.655046, end=12.737979, pitch=76, velocity=85)
# Duration: 0.08293268124999997
# Note(start=12.799277, end=12.890623, pitch=77, velocity=78)
# Duration: 0.09134614166666566
# Note(start=12.943508, end=13.034854, pitch=79, velocity=74)
# Duration: 0.09134614166666566
# Note(start=13.231969, end=13.320912, pitch=77, velocity=78)
# Duration: 0.08894229583333413
# Note(start=13.520431, end=13.616585, pitch=76, velocity=81)
# Duration: 0.09615383333333405
#
# Notes for BRIDGE:
# Note(start=1.116586, end=1.201923, pitch=76, velocity=80)
# Duration: 0.0853365270833335
# Note(start=1.260817, end=1.383413, pitch=77, velocity=74)
# Duration: 0.1225961375000002
# Note(start=1.405048, end=1.560096, pitch=79, velocity=81)
# Duration: 0.15504805624999984
# Note(start=1.693509, end=1.825721, pitch=88, velocity=79)
# Duration: 0.1322115208333332
# Note(start=1.981971, end=2.098557, pitch=84, velocity=83)
# Duration: 0.11658652291666671
#
# Notes for PIANO:
# Note(start=1.405048, end=1.724759, pitch=48, velocity=85)
# Duration: 0.31971149583333314
# Note(start=1.693509, end=1.830529, pitch=64, velocity=75)
# Duration: 0.13701921250000004
# Note(start=1.693509, end=1.831731, pitch=60, velocity=70)
# Duration: 0.1382211354166667
# Note(start=1.693509, end=1.843750, pitch=55, velocity=74)
# Duration: 0.15024036458333323
# Note(start=1.981971, end=2.322115, pitch=43, velocity=69)
# Duration: 0.3401441854166669

# %% [markdown]
# Print out the unique information for all songs to see if there are major differences between each track to see if we need to preprocess that data to make it all uniform so it is easier for the transformer to read.

# %%
import pretty_midi
import os

# Base directory containing all the individual song folders
base_directory = 'POP909'

# Set to store unique instrument information
unique_instruments = set()

# Set to store unique time signature changes
unique_time_signatures = set()

# Iterate through all the subdirectories
for subdir, _, files in os.walk(base_directory):
    for file in files:
        # Check if the file has a .mid extension
        if file.endswith('.mid'):
            # Construct full path to MIDI file
            midi_path = os.path.join(subdir, file)

            # Load MIDI file into PrettyMIDI object
            midi_data = pretty_midi.PrettyMIDI(midi_path)

            # Collect unique time signatures
            for ts in midi_data.time_signature_changes:
                unique_time_signatures.add((ts.numerator, ts.denominator))

            # Collect information about piano instruments (program 0)
            for instrument in midi_data.instruments:
                if instrument.program == 0:
                    unique_instruments.add((instrument.name, instrument.program, instrument.is_drum))

# Print the unique instrument information
print("Unique Instruments:")
for info in unique_instruments:
    name, program, is_drum = info
    print(f"Instrument: {name}, Program: {program}, Is Drum: {is_drum}")

# Print the unique time signatures
print("\nUnique Time Signatures:")
for ts in unique_time_signatures:
    numerator, denominator = ts
    print(f"Time Signature: {numerator}/{denominator}")
# Out:
# Unique Instruments:
# Instrument: PIANO, Program: 0, Is Drum: False
# Instrument: Piano, Program: 0, Is Drum: False
# Instrument: MELODY, Program: 0, Is Drum: False
# Instrument: BRIDGE, Program: 0, Is Drum: False
#
# Unique Time Signatures:
# Time Signature: 4/4
# Time Signature: 2/4
# Time Signature: 3/4
# Time Signature: 6/8
# Time Signature: 1/4
# Time Signature: 2/2

# %% [markdown]
# We can see that the names that were inputted for the instrument name were spelt wrong, in a different language, the name of the musician etc. However, they all have **Program: 0** and **Is Drum: False** which indicates that they are all piano music. Therefore, we will change the naming conventions going forward to clean the data a bit and only look at music with 4/4 Time Signature for ease.

# %%
# Counter for the total number of songs modified
total_songs_modified = 0

# Iterate through all the subdirectories again to modify MIDI files
for subdir, _, files in os.walk(base_directory):
    for file in files:
        # Check if the file has a .mid extension and if the file does NOT start with "modified_"
        if file.endswith('.mid') and not file.startswith('modified_'):
            # Construct full path to MIDI file
            midi_path = os.path.join(subdir, file)

            # Load MIDI file into PrettyMIDI object
            midi_data = pretty_midi.PrettyMIDI(midi_path)

            # Check for 4/4 time signature
            is_four_by_four = any(ts.numerator == 4 and ts.denominator == 4 for ts in midi_data.time_signature_changes)

            if is_four_by_four:
                # Update instrument names and save the modified MIDI
                for instrument in midi_data.instruments:
                    if instrument.program == 0 and not instrument.is_drum:
                        instrument.name = "Piano"

                # Save the modified MIDI file; you can choose where to save it
                new_midi_path = os.path.join(subdir, "modified_" + file)
                midi_data.write(new_midi_path)
                print(new_midi_path)

                # Increment the counter for total number of songs modified
                total_songs_modified += 1

# Print the total number of songs modified
print(f"Total number of songs modified: {total_songs_modified}")
# Out:
# POP909\008\modified_008.mid
# POP909\022\modified_022.mid
# POP909\026\modified_026.mid
# POP909\027\modified_027.mid
# POP909\029\modified_029.mid
# POP909\032\modified_032.mid
# POP909\033\modified_033.mid
# POP909\035\modified_035.mid
# POP909\040\modified_040.mid
# POP909\041\modified_041.mid
# POP909\042\modified_042.mid
# POP909\043\modified_043.mid
# POP909\055\modified_055.mid
# POP909\056\modified_056.mid
# POP909\059\modified_059.mid
# POP909\062\modified_062.mid
# POP909\063\modified_063.mid
# POP909\064\modified_064.mid
# POP909\068\modified_068.mid
# POP909\069\modified_069.mid
# POP909\070\modified_070.mid
# POP909\071\modified_071.mid
# POP909\072\modified_072.mid
# POP909\080\modified_080.mid
# POP909\086\modified_086.mid
# POP909\088\modified_088.mid
# POP909\090\modified_090.mid
# POP909\099\modified_099.mid
# POP909\101\modified_101.mid
# POP909\103\modified_103.mid
# POP909\106\modified_106.mid
# POP909\108\modified_108.mid
# POP909\111\modified_111.mid
# POP909\119\modified_119.mid
# POP909\144\modified_144.mid
# POP909\148\modified_148.mid
# POP909\157\modified_157.mid
# POP909\161\modified_161.mid
# POP909\169\modified_169.mid
# POP909\174\modified_174.mid
# POP909\177\modified_177.mid
# POP909\178\modified_178.mid
# POP909\179\modified_179.mid
# POP909\180\modified_180.mid
# POP909\181\modified_181.mid
# POP909\182\modified_182.mid
# POP909\183\modified_183.mid
# POP909\184\modified_184.mid
# POP909\185\modified_185.mid
# POP909\186\modified_186.mid
# POP909\187\modified_187.mid
# POP909\188\modified_188.mid
# POP909\189\modified_189.mid
# POP909\190\modified_190.mid
# POP909\191\modified_191.mid
# POP909\192\modified_192.mid
# POP909\193\modified_193.mid
# POP909\194\modified_194.mid
# POP909\195\modified_195.mid
# POP909\196\modified_196.mid
# POP909\197\modified_197.mid
# POP909\198\modified_198.mid
# POP909\199\modified_199.mid
# POP909\200\modified_200.mid
# POP909\201\modified_201.mid
# POP909\204\modified_204.mid
# POP909\205\modified_205.mid
# POP909\206\modified_206.mid
# POP909\207\modified_207.mid
# POP909\208\modified_208.mid
# POP909\209\modified_209.mid
# POP909\210\modified_210.mid
# POP909\211\modified_211.mid
# POP909\212\modified_212.mid
# POP909\213\modified_213.mid
# POP909\214\modified_214.mid
# POP909\216\modified_216.mid
# POP909\217\modified_217.mid
# POP909\218\modified_218.mid
# POP909\219\modified_219.mid
# POP909\220\modified_220.mid
# POP909\221\modified_221.mid
# POP909\222\modified_222.mid
# POP909\223\modified_223.mid
# POP909\224\modified_224.mid
# POP909\225\modified_225.mid
# POP909\226\modified_226.mid
# POP909\227\modified_227.mid
# POP909\228\modified_228.mid
# POP909\229\modified_229.mid
# POP909\230\modified_230.mid
# POP909\232\modified_232.mid
# POP909\233\modified_233.mid
# POP909\234\modified_234.mid
# POP909\235\modified_235.mid
# POP909\236\modified_236.mid
# POP909\237\modified_237.mid
# POP909\238\modified_238.mid
# POP909\239\modified_239.mid
# POP909\240\modified_240.mid
# POP909\241\modified_241.mid
# POP909\242\modified_242.mid
# POP909\243\modified_243.mid
# POP909\244\modified_244.mid
# POP909\245\modified_245.mid
# POP909\246\modified_246.mid
# POP909\247\modified_247.mid
# POP909\248\modified_248.mid
# POP909\249\modified_249.mid
# POP909\250\modified_250.mid
# POP909\251\modified_251.mid
# POP909\252\modified_252.mid
# POP909\253\modified_253.mid
# POP909\255\modified_255.mid
# POP909\256\modified_256.mid
# POP909\257\modified_257.mid
# POP909\258\modified_258.mid
# POP909\259\modified_259.mid
# POP909\260\modified_260.mid
# POP909\261\modified_261.mid
# POP909\262\modified_262.mid
# POP909\263\modified_263.mid
# POP909\264\modified_264.mid
# POP909\265\modified_265.mid
# POP909\266\modified_266.mid
# POP909\267\modified_267.mid
# POP909\268\modified_268.mid
# POP909\269\modified_269.mid
# POP909\270\modified_270.mid
# POP909\271\modified_271.mid
# POP909\272\modified_272.mid
# POP909\273\modified_273.mid
# POP909\274\modified_274.mid
# POP909\275\modified_275.mid
# POP909\276\modified_276.mid
# POP909\277\modified_277.mid
# POP909\278\modified_278.mid
# POP909\279\modified_279.mid
# POP909\280\modified_280.mid
# POP909\281\modified_281.mid
# POP909\282\modified_282.mid
# POP909\283\modified_283.mid
# POP909\284\modified_284.mid
# POP909\285\modified_285.mid
# POP909\286\modified_286.mid
# POP909\287\modified_287.mid
# POP909\288\modified_288.mid
# POP909\290\modified_290.mid
# POP909\291\modified_291.mid
# POP909\292\modified_292.mid
# POP909\293\modified_293.mid
# POP909\294\modified_294.mid
# POP909\296\modified_296.mid
# POP909\297\modified_297.mid
# POP909\298\modified_298.mid
# POP909\299\modified_299.mid
# POP909\300\modified_300.mid
# POP909\301\modified_301.mid
# POP909\302\modified_302.mid
# POP909\303\modified_303.mid
# POP909\304\modified_304.mid
# POP909\305\modified_305.mid
# POP909\306\modified_306.mid
# POP909\308\modified_308.mid
# POP909\310\modified_310.mid
# POP909\311\modified_311.mid
# POP909\312\modified_312.mid
# POP909\313\modified_313.mid
# POP909\314\modified_314.mid
# POP909\315\modified_315.mid
# POP909\316\modified_316.mid
# POP909\317\modified_317.mid
# POP909\318\modified_318.mid
# POP909\319\modified_319.mid
# POP909\320\modified_320.mid
# POP909\321\modified_321.mid
# POP909\322\modified_322.mid
# POP909\323\modified_323.mid
# POP909\324\modified_324.mid
# POP909\325\modified_325.mid
# POP909\326\modified_326.mid
# POP909\327\modified_327.mid
# POP909\328\modified_328.mid
# POP909\329\modified_329.mid
# POP909\330\modified_330.mid
# POP909\331\modified_331.mid
# POP909\332\modified_332.mid
# POP909\334\modified_334.mid
# POP909\336\modified_336.mid
# POP909\337\modified_337.mid
# POP909\338\modified_338.mid
# POP909\339\modified_339.mid
# POP909\340\modified_340.mid
# POP909\341\modified_341.mid
# POP909\342\modified_342.mid
# POP909\343\modified_343.mid
# POP909\344\modified_344.mid
# POP909\345\modified_345.mid
# POP909\346\modified_346.mid
# POP909\347\modified_347.mid
# POP909\348\modified_348.mid
# POP909\349\modified_349.mid
# POP909\353\modified_353.mid
# POP909\369\modified_369.mid
# POP909\392\modified_392.mid
# POP909\396\modified_396.mid
# POP909\407\modified_407.mid
# POP909\411\modified_411.mid
# POP909\454\modified_454.mid
# POP909\456\modified_456.mid
# POP909\537\modified_537.mid
# POP909\538\modified_538.mid
# POP909\539\modified_539.mid
# POP909\540\modified_540.mid
# POP909\542\modified_542.mid
# POP909\543\modified_543.mid
# POP909\549\modified_549.mid
# POP909\552\modified_552.mid
# POP909\554\modified_554.mid
# POP909\555\modified_555.mid
# POP909\556\modified_556.mid
# POP909\558\modified_558.mid
# POP909\562\modified_562.mid
# POP909\564\modified_564.mid
# POP909\565\modified_565.mid
# POP909\566\modified_566.mid
# POP909\568\modified_568.mid
# POP909\569\modified_569.mid
# POP909\570\modified_570.mid
# POP909\571\modified_571.mid
# POP909\572\modified_572.mid
# POP909\576\modified_576.mid
# POP909\578\modified_578.mid
# POP909\597\modified_597.mid
# POP909\605\modified_605.mid
# POP909\613\modified_613.mid
# POP909\618\modified_618.mid
# POP909\653\modified_653.mid
# POP909\683\modified_683.mid
# POP909\684\modified_684.mid
# POP909\694\modified_694.mid
# POP909\703\modified_703.mid
# POP909\713\modified_713.mid
# POP909\717\modified_717.mid
# POP909\719\modified_719.mid
# POP909\740\modified_740.mid
# POP909\775\modified_775.mid
# POP909\781\modified_781.mid
# POP909\789\modified_789.mid
# POP909\790\modified_790.mid
# POP909\792\modified_792.mid
# POP909\795\modified_795.mid
# POP909\796\modified_796.mid
# POP909\798\modified_798.mid
# POP909\799\modified_799.mid
# POP909\806\modified_806.mid
# POP909\825\modified_825.mid
# POP909\882\modified_882.mid
# POP909\890\modified_890.mid
# POP909\896\modified_896.mid
# POP909\898\modified_898.mid
# POP909\901\modified_901.mid
# POP909\905\modified_905.mid
# POP909\906\modified_906.mid
# Total number of songs modified: 264

# %% [markdown]
# ## Read the Modified Data Back In (dont know if I need this)

# %%
# # Iterate through all the subdirectories again to read modified MIDI files
# for subdir, _, files in os.walk(base_directory):
#     for file in files:
#         # Check if the file has a .mid extension and if the file starts with "modified_"
#         if file.endswith('.mid') and file.startswith("modified_"):
#             # Construct full path to MIDI file
#             midi_44TS = os.path.join(subdir, file)  # Changed variable name here

#             # Load MIDI file into PrettyMIDI object
#             midi_data = pretty_midi.PrettyMIDI(midi_44TS)  # Changed variable name here

#             # Perform your operations here
#             print(f"Loaded modified MIDI file from {midi_44TS}")  # Changed variable name here
#             # ... (rest of your code to process these modified MIDI files)

# %% [markdown]
# ## Check to see if we need to Transpose the music to C Major

# %%
import pretty_midi
import os
from collections import Counter

# Base directory containing all the individual song folders
base_directory = 'POP909'  # Changed from 'archive' to your specific directory

# Counter to keep track of key occurrences
key_counter = Counter()

# Iterate through all the subdirectories
for subdir, _, files in os.walk(base_directory):
    for file in files:
        # Check if the file has a .mid extension and starts with "modified_"
        if file.endswith('.mid') and file.startswith("modified_"):
            # Construct full path to MIDI file
            midi_path = os.path.join(subdir, file)

            # Load MIDI file into PrettyMIDI object
            midi_data = pretty_midi.PrettyMIDI(midi_path)

            # Get key signature changes
            key_signature_changes = midi_data.key_signature_changes

            # If key signature changes exist, take the first one (assuming it's the key of the piece)
            if key_signature_changes:
                key = key_signature_changes[0].key_number
                # Increment the counter for this key
                key_counter[key] += 1

# Print the count of each key
for key, count in key_counter.items():
    # PrettyMIDI's key_number is an integer, where 0 = C Major, 1 = C# Major, etc., and negative numbers are the corresponding minor keys
    print(f"Key {pretty_midi.key_number_to_key_name(key)}: {count} occurrences")
# Out:
# Key C Major: 126 occurrences

# %% [markdown]
# ## Sequence Length:
#
# Transformers work with a fixed sequence length. So, you have to determine the maximum length of your sequences. If a song/chord progression is longer, you might have to split it or use techniques like windowing.
#
# Pad shorter sequences with a special "padding" token to ensure all sequences are of the same length.

# %% [markdown]
# ## Determine the Shortest Sequence Length
#
# **Extract note length information.** We obtain the duration T0 of the shortest note in the melody score, and use T0 as the basic unit length to extract the duration information of all notes, which solves the problem of missing duration information in the conversion process. The specific steps for extracting note duration information are as follows:
# <br>•Specify the MIDI music file and extract the melody track from Track1;
# <br>•Get the list by traversing all the notes in itand extracting the duration L1,Get the smallest duration T0;
# <br>•After obtaining the duration T0,divide the duration of all notes by T0 to obtain the note multiple Ni of all notes for the smallest note, so as to facilitate the textual representation below. (An automatic music generation and evaluation method based on transfer learning)

# %% [markdown]
# Find the shortest note duration in each song (T0) to create a unit of time and divide this by each note duration to find Ni ie the number of T0 per note. Also check that no song is empty and contains no notes

# %%
# Lists to store shortest note duration (T0) and Ni values for each song
all_shortest_note_durations = {}
all_ni_values = {}
empty_songs = []  # List to store names of songs with no notes

# Iterate through all the subdirectories again
for subdir, _, files in os.walk(base_directory):
    for file in files:
        # Check if the file has a .mid extension and starts with "modified_"
        if file.endswith('.mid') and file.startswith("modified_"):
            # Construct full path to MIDI file
            midi_path = os.path.join(subdir, file)

            # Load MIDI file into PrettyMIDI object
            midi_data = pretty_midi.PrettyMIDI(midi_path)

            # Initialize variables to store note durations for each song
            note_durations = []

            # Iterate over each instrument track
            for instrument in midi_data.instruments:
                # Iterate through all notes in the instrument track
                for note in instrument.notes:
                    # Calculate the note duration
                    note_duration = note.end - note.start
                    note_durations.append(note_duration)

            # Check if any notes were found
            if not note_durations:
                print(f"Warning: {file} contains no notes.")
                empty_songs.append(file)
                continue  # Skip to the next song

            # Find the shortest note duration for the song (T0)
            T0 = min(note_durations)
            all_shortest_note_durations[file] = T0

            # Calculate Ni for each note in the song and store in a list
            ni_values = [duration / T0 for duration in note_durations]
            all_ni_values[file] = ni_values

# Display the T0 and Ni values
for file in all_shortest_note_durations.keys():
    print(f"For {file}, the shortest note duration (T0) is: {all_shortest_note_durations[file]}")
    print(f"First 10 Ni values for {file} are: {all_ni_values[file][:10]}")

# Display the names of empty songs
if empty_songs:
    print(f"The following songs contained no notes: {', '.join(empty_songs)}")
# Out:
# For modified_008.mid, the shortest note duration (T0) is: 0.08461539166665943
# First 1 Ni values for modified_008.mid are: [2.5227272727274825]
# For modified_022.mid, the shortest note duration (T0) is: 0.008928572916666155
# First 1 Ni values for modified_022.mid are: [23.800000000001432]
# For modified_026.mid, the shortest note duration (T0) is: 0.05937500000000284
# First 1 Ni values for modified_026.mid are: [12.684210526315194]
# For modified_027.mid, the shortest note duration (T0) is: 0.0390625
# First 1 Ni values for modified_027.mid are: [5.3]
# For modified_029.mid, the shortest note duration (T0) is: 0.018181800000007797
# First 1 Ni values for modified_029.mid are: [19.249999999991598]
# For modified_032.mid, the shortest note duration (T0) is: 0.008474566666667016
# First 1 Ni values for modified_032.mid are: [76.49999999999686]
# For modified_033.mid, the shortest note duration (T0) is: 0.027573500000002582
# First 1 Ni values for modified_033.mid are: [7.533333333332638]
# For modified_035.mid, the shortest note duration (T0) is: 0.05633800000000022
# First 1 Ni values for modified_035.mid are: [4.156249999999982]
# For modified_040.mid, the shortest note duration (T0) is: 0.001895087500003001
# First 1 Ni values for modified_040.mid are: [214.9999999996588]
# For modified_041.mid, the shortest note duration (T0) is: 0.0014705874999947355
# First 1 Ni values for modified_041.mid are: [144.00000000051458]
# For modified_042.mid, the shortest note duration (T0) is: 0.03082192499999792
# First 1 Ni values for modified_042.mid are: [7.16666666666709]
# For modified_043.mid, the shortest note duration (T0) is: 0.008110112499998934
# First 1 Ni values for modified_043.mid are: [37.142857142862525]
# For modified_055.mid, the shortest note duration (T0) is: 0.05381942291666064
# First 1 Ni values for modified_055.mid are: [12.25806451613038]
# For modified_056.mid, the shortest note duration (T0) is: 0.0338235124999926
# First 1 Ni values for modified_056.mid are: [5.347826086957664]
# For modified_059.mid, the shortest note duration (T0) is: 0.011904762499995059
# First 1 Ni values for modified_059.mid are: [18.967742251620905]
# For modified_062.mid, the shortest note duration (T0) is: 0.0008445937499885758
# First 1 Ni values for modified_062.mid are: [960.0000000129852]
# For modified_063.mid, the shortest note duration (T0) is: 0.0034722208333448634
# First 1 Ni values for modified_063.mid are: [61.99999999979332]
# For modified_064.mid, the shortest note duration (T0) is: 0.00595238125001174
# First 1 Ni values for modified_064.mid are: [143.84999280721712]
# For modified_068.mid, the shortest note duration (T0) is: 0.05323682291665932
# First 1 Ni values for modified_068.mid are: [6.184744386082344]
# For modified_069.mid, the shortest note duration (T0) is: 0.009072581249995437
# First 1 Ni values for modified_069.mid are: [26.555555555568784]
# For modified_070.mid, the shortest note duration (T0) is: 0.006048387499987484
# First 1 Ni values for modified_070.mid are: [40.00000000008282]
# For modified_071.mid, the shortest note duration (T0) is: 0.0018115916666658904
# First 1 Ni values for modified_071.mid are: [223.0000000000961]
# For modified_072.mid, the shortest note duration (T0) is: 0.006329116666663026
# First 1 Ni values for modified_072.mid are: [74.00000000004266]
# For modified_080.mid, the shortest note duration (T0) is: 0.020975475000000188
# First 1 Ni values for modified_080.mid are: [8.25]
# For modified_086.mid, the shortest note duration (T0) is: 0.014232268750021149
# First 1 Ni values for modified_086.mid are: [18.999999999972044]
# For modified_088.mid, the shortest note duration (T0) is: 0.00893045833333872
# First 1 Ni values for modified_088.mid are: [47.99999999997136]
# For modified_090.mid, the shortest note duration (T0) is: 0.034722208333320737
# First 1 Ni values for modified_090.mid are: [11.000000000004093]
# For modified_099.mid, the shortest note duration (T0) is: 0.023076924999998027
# First 1 Ni values for modified_099.mid are: [9.75000000000077]
# For modified_101.mid, the shortest note duration (T0) is: 0.015612799999999538
# First 1 Ni values for modified_101.mid are: [23.375000000001023]
# For modified_103.mid, the shortest note duration (T0) is: 0.0078125
# First 1 Ni values for modified_103.mid are: [40.0]
# For modified_106.mid, the shortest note duration (T0) is: 0.005597012499976017
# First 1 Ni values for modified_106.mid are: [90.66666666705514]
# For modified_108.mid, the shortest note duration (T0) is: 0.03799017708332997
# First 1 Ni values for modified_108.mid are: [3.38709677419388]
# For modified_111.mid, the shortest note duration (T0) is: 0.014112904166665885
# First 1 Ni values for modified_111.mid are: [20.000000000001005]
# For modified_119.mid, the shortest note duration (T0) is: 0.07765152291665345
# First 1 Ni values for modified_119.mid are: [7.756097560976913]
# For modified_144.mid, the shortest note duration (T0) is: 0.0018115916666658904
# First 1 Ni values for modified_144.mid are: [64.00000000002746]
# For modified_148.mid, the shortest note duration (T0) is: 0.00390625
# First 1 Ni values for modified_148.mid are: [82.0]
# For modified_157.mid, the shortest note duration (T0) is: 0.0037499999999965894
# First 1 Ni values for modified_157.mid are: [874.6666666674622]
# For modified_161.mid, the shortest note duration (T0) is: 0.038306454166672665
# First 1 Ni values for modified_161.mid are: [3.526315789473069]
# For modified_169.mid, the shortest note duration (T0) is: 0.0485293874999968
# First 1 Ni values for modified_169.mid are: [10.515151515152212]
# For modified_174.mid, the shortest note duration (T0) is: 0.02397260833333803
# First 1 Ni values for modified_174.mid are: [7.99999999999837]
# For modified_177.mid, the shortest note duration (T0) is: 0.023897033333355466
# First 1 Ni values for modified_177.mid are: [8.923076923068631]
# For modified_178.mid, the shortest note duration (T0) is: 0.008680541666677755
# First 1 Ni values for modified_178.mid are: [48.17771740428626]
# For modified_179.mid, the shortest note duration (T0) is: 0.0010080645833170365
# First 1 Ni values for modified_179.mid are: [476.0000000076953]
# For modified_180.mid, the shortest note duration (T0) is: 0.010670712499972979
# First 1 Ni values for modified_180.mid are: [16.571428571470616]
# For modified_181.mid, the shortest note duration (T0) is: 0.00551469999999199
# First 1 Ni values for modified_181.mid are: [38.66666666672271]
# For modified_182.mid, the shortest note duration (T0) is: 0.048319262500001514
# First 1 Ni values for modified_182.mid are: [5.001456027327735]
# For modified_183.mid, the shortest note duration (T0) is: 0.0070422499999995836
# First 1 Ni values for modified_183.mid are: [59.00000000000353]
# For modified_184.mid, the shortest note duration (T0) is: 0.013157874999990327
# First 1 Ni values for modified_184.mid are: [19.333333333347372]
# For modified_185.mid, the shortest note duration (T0) is: 0.004464283333334151
# First 1 Ni values for modified_185.mid are: [63.11628032867144]
# For modified_186.mid, the shortest note duration (T0) is: 0.037499999999994316
# First 1 Ni values for modified_186.mid are: [6.444444444445434]
# For modified_187.mid, the shortest note duration (T0) is: 0.005208333333335702
# First 1 Ni values for modified_187.mid are: [47.1999999999779]
# For modified_188.mid, the shortest note duration (T0) is: 0.029545424999980696
# First 1 Ni values for modified_188.mid are: [18.307692307704304]
# For modified_189.mid, the shortest note duration (T0) is: 0.049999950000000126
# First 1 Ni values for modified_189.mid are: [8.5]
# For modified_190.mid, the shortest note duration (T0) is: 0.006666666666660603
# First 1 Ni values for modified_190.mid are: [123.75000000011191]
# For modified_191.mid, the shortest note duration (T0) is: 0.039772731249996696
# First 1 Ni values for modified_191.mid are: [8.952380952381676]
# For modified_192.mid, the shortest note duration (T0) is: 0.003846154166666338
# First 1 Ni values for modified_192.mid are: [200.50000000001847]
# For modified_193.mid, the shortest note duration (T0) is: 0.024305516666686344
# First 1 Ni values for modified_193.mid are: [9.928571428563327]
# For modified_194.mid, the shortest note duration (T0) is: 0.01136364166666226
# First 1 Ni values for modified_194.mid are: [44.91664570558286]
# For modified_195.mid, the shortest note duration (T0) is: 0.015306124999995063
# First 1 Ni values for modified_195.mid are: [48.333333333348804]
# For modified_196.mid, the shortest note duration (T0) is: 0.025000000000034106
# First 1 Ni values for modified_196.mid are: [7.749999999989342]
# For modified_197.mid, the shortest note duration (T0) is: 0.04268276250000724
# First 1 Ni values for modified_197.mid are: [7.1904761904749535]
# For modified_198.mid, the shortest note duration (T0) is: 0.004844947916666342
# First 1 Ni values for modified_198.mid are: [95.80000000000705]
# For modified_199.mid, the shortest note duration (T0) is: 0.06034478333333482
# First 1 Ni values for modified_199.mid are: [4.14285714285704]
# For modified_200.mid, the shortest note duration (T0) is: 0.0625
# First 1 Ni values for modified_200.mid are: [11.849999999999966]
# For modified_201.mid, the shortest note duration (T0) is: 0.0028089874999750464
# First 1 Ni values for modified_201.mid are: [118.00000000104849]
# For modified_204.mid, the shortest note duration (T0) is: 0.012755104166672027
# First 1 Ni values for modified_204.mid are: [47.89999999997983]
# For modified_205.mid, the shortest note duration (T0) is: 0.0340907187499937
# First 1 Ni values for modified_205.mid are: [14.72727272727547]
# For modified_206.mid, the shortest note duration (T0) is: 0.012500006249979378
# First 1 Ni values for modified_206.mid are: [27.14285759528266]
# For modified_207.mid, the shortest note duration (T0) is: 0.03181815000000654
# First 1 Ni values for modified_207.mid are: [8.428571428569738]
# For modified_208.mid, the shortest note duration (T0) is: 0.00799998333333285
# First 1 Ni values for modified_208.mid are: [59.50000000000344]
# For modified_209.mid, the shortest note duration (T0) is: 0.034671437499980584
# First 1 Ni values for modified_209.mid are: [12.076392131137771]
# For modified_210.mid, the shortest note duration (T0) is: 0.006465512500000159
# First 1 Ni values for modified_210.mid are: [39.33333333333278]
# For modified_211.mid, the shortest note duration (T0) is: 0.016128899999984014
# First 1 Ni values for modified_211.mid are: [14.937500000014648]
# For modified_212.mid, the shortest note duration (T0) is: 0.019578297916666543
# First 1 Ni values for modified_212.mid are: [15.153846153846349]
# For modified_213.mid, the shortest note duration (T0) is: 0.032894604166671115
# First 1 Ni values for modified_213.mid are: [6.898467517151426]
# For modified_214.mid, the shortest note duration (T0) is: 0.024999975000000063
# First 1 Ni values for modified_214.mid are: [8.550721217387894]
# For modified_216.mid, the shortest note duration (T0) is: 0.0021929791666650544
# First 1 Ni values for modified_216.mid are: [63.557443736211134]
# For modified_217.mid, the shortest note duration (T0) is: 0.056250000000005684
# First 1 Ni values for modified_217.mid are: [6.666666666665993]
# For modified_218.mid, the shortest note duration (T0) is: 0.0018115916666658904
# First 1 Ni values for modified_218.mid are: [132.0000000000549]
# For modified_219.mid, the shortest note duration (T0) is: 0.011363635416664408
# First 1 Ni values for modified_219.mid are: [23.990027765840125]
# For modified_220.mid, the shortest note duration (T0) is: 0.017136956249999002
# First 1 Ni values for modified_220.mid are: [13.882352941177306]
# For modified_221.mid, the shortest note duration (T0) is: 0.0011363624999773947
# First 1 Ni values for modified_221.mid are: [450.00000000895085]
# For modified_222.mid, the shortest note duration (T0) is: 0.013392843750004602
# First 1 Ni values for modified_222.mid are: [28.88291850513083]
# For modified_223.mid, the shortest note duration (T0) is: 0.03771548958333426
# First 1 Ni values for modified_223.mid are: [6.742857142856955]
# For modified_224.mid, the shortest note duration (T0) is: 0.003846154166666338
# First 1 Ni values for modified_224.mid are: [30.23253748062412]
# For modified_225.mid, the shortest note duration (T0) is: 0.06406250000000568
# First 1 Ni values for modified_225.mid are: [23.029216130079284]
# For modified_226.mid, the shortest note duration (T0) is: 0.008333333333325754
# First 1 Ni values for modified_226.mid are: [61.034438000055516]
# For modified_227.mid, the shortest note duration (T0) is: 0.003846154166666338
# First 1 Ni values for modified_227.mid are: [114.47755279354708]
# For modified_228.mid, the shortest note duration (T0) is: 0.003177968749994875
# First 1 Ni values for modified_228.mid are: [98.01079174672033]
# For modified_229.mid, the shortest note duration (T0) is: 0.02566958124999985
# First 1 Ni values for modified_229.mid are: [21.565217391304472]
# For modified_230.mid, the shortest note duration (T0) is: 0.013888889583334674
# First 1 Ni values for modified_230.mid are: [50.92107045394148]
# For modified_232.mid, the shortest note duration (T0) is: 0.002212383333329626
# First 1 Ni values for modified_232.mid are: [141.00000000023607]
# For modified_233.mid, the shortest note duration (T0) is: 0.004746837499993717
# First 1 Ni values for modified_233.mid are: [203.82654767543247]
# For modified_234.mid, the shortest note duration (T0) is: 0.0010416666666728247
# First 1 Ni values for modified_234.mid are: [229.99999999863917]
# For modified_235.mid, the shortest note duration (T0) is: 0.0967741999999987
# First 1 Ni values for modified_235.mid are: [2.416666666666728]
# For modified_236.mid, the shortest note duration (T0) is: 0.019396537500000477
# First 1 Ni values for modified_236.mid are: [27.833333333332785]
# For modified_237.mid, the shortest note duration (T0) is: 0.018092112499999757
# First 1 Ni values for modified_237.mid are: [21.454545454545812]
# For modified_238.mid, the shortest note duration (T0) is: 0.02031249999998863
# First 1 Ni values for modified_238.mid are: [9.392716307697471]
# For modified_239.mid, the shortest note duration (T0) is: 0.007575758333359772
# First 1 Ni values for modified_239.mid are: [30.380950861798937]
# For modified_240.mid, the shortest note duration (T0) is: 0.0010080624999773136
# First 1 Ni values for modified_240.mid are: [238.00000000535692]
# For modified_241.mid, the shortest note duration (T0) is: 0.014830491666667278
# First 1 Ni values for modified_241.mid are: [44.126053361906386]
# For modified_242.mid, the shortest note duration (T0) is: 0.02380952500001854
# First 1 Ni values for modified_242.mid are: [9.822580808863279]
# For modified_243.mid, the shortest note duration (T0) is: 0.03419812916666842
# First 1 Ni values for modified_243.mid are: [8.21543746727814]
# For modified_244.mid, the shortest note duration (T0) is: 0.03373016041666688
# First 1 Ni values for modified_244.mid are: [13.986717500663955]
# For modified_245.mid, the shortest note duration (T0) is: 0.009943179166661764
# First 1 Ni values for modified_245.mid are: [33.71428571430205]
# For modified_246.mid, the shortest note duration (T0) is: 0.006249993750000016
# First 1 Ni values for modified_246.mid are: [68.14285714285731]
# For modified_247.mid, the shortest note duration (T0) is: 0.0015243875000123808
# First 1 Ni values for modified_247.mid are: [120.40533219528271]
# For modified_248.mid, the shortest note duration (T0) is: 0.024456431250001742
# First 1 Ni values for modified_248.mid are: [17.703703703702455]
# For modified_249.mid, the shortest note duration (T0) is: 0.028508675000011863
# First 1 Ni values for modified_249.mid are: [18.346153846146198]
# For modified_250.mid, the shortest note duration (T0) is: 0.015872999999999138
# First 1 Ni values for modified_250.mid are: [29.812500000001567]
# For modified_251.mid, the shortest note duration (T0) is: 0.04166666666665719
# First 1 Ni values for modified_251.mid are: [5.950000000001398]
# For modified_252.mid, the shortest note duration (T0) is: 0.030766208333339762
# First 1 Ni values for modified_252.mid are: [13.54838709677136]
# For modified_253.mid, the shortest note duration (T0) is: 0.00757575000000088
# First 1 Ni values for modified_253.mid are: [59.499999999992966]
# For modified_255.mid, the shortest note duration (T0) is: 0.004360462500000217
# First 1 Ni values for modified_255.mid are: [128.3333333333266]
# For modified_256.mid, the shortest note duration (T0) is: 0.031249995833320554
# First 1 Ni values for modified_256.mid are: [9.666667955559756]
# For modified_257.mid, the shortest note duration (T0) is: 0.05813937499999966
# First 1 Ni values for modified_257.mid are: [7.753043870870705]
# For modified_258.mid, the shortest note duration (T0) is: 0.03009250833332544
# First 1 Ni values for modified_258.mid are: [9.192307692310095]
# For modified_259.mid, the shortest note duration (T0) is: 0.023958333333325754
# First 1 Ni values for modified_259.mid are: [10.347826086959873]
# For modified_260.mid, the shortest note duration (T0) is: 0.016666666666667496
# First 1 Ni values for modified_260.mid are: [14.874999999999375]
# For modified_261.mid, the shortest note duration (T0) is: 0.0065298187499820415
# First 1 Ni values for modified_261.mid are: [34.00000000009358]
# For modified_262.mid, the shortest note duration (T0) is: 0.011375249999986181
# First 1 Ni values for modified_262.mid are: [32.000000000038725]
# For modified_263.mid, the shortest note duration (T0) is: 0.03749996249999299
# First 1 Ni values for modified_263.mid are: [8.777777777779473]
# For modified_264.mid, the shortest note duration (T0) is: 0.0032051208333427894
# First 1 Ni values for modified_264.mid are: [210.8894477451081]
# For modified_265.mid, the shortest note duration (T0) is: 0.01932987499998262
# First 1 Ni values for modified_265.mid are: [15.800000000014153]
# For modified_266.mid, the shortest note duration (T0) is: 0.046052635416671706
# First 1 Ni values for modified_266.mid are: [14.726445487080316]
# For modified_267.mid, the shortest note duration (T0) is: 0.002272727083322934
# First 1 Ni values for modified_267.mid are: [420.0000000019212]
# For modified_268.mid, the shortest note duration (T0) is: 0.008333333333325754
# First 1 Ni values for modified_268.mid are: [29.750000000027285]
# For modified_269.mid, the shortest note duration (T0) is: 0.015624993749980831
# First 1 Ni values for modified_269.mid are: [26.555555555588324]
# For modified_270.mid, the shortest note duration (T0) is: 0.05633800000001088
# First 1 Ni values for modified_270.mid are: [22.499999999995648]
# For modified_271.mid, the shortest note duration (T0) is: 0.003378374999996936
# First 1 Ni values for modified_271.mid are: [180.00000000016195]
# For modified_272.mid, the shortest note duration (T0) is: 0.06335610208333264
# First 1 Ni values for modified_272.mid are: [3.8378378378379288]
# For modified_273.mid, the shortest note duration (T0) is: 0.02195943749998719
# First 1 Ni values for modified_273.mid are: [18.3846153846261]
# For modified_274.mid, the shortest note duration (T0) is: 0.04282395416666418
# First 1 Ni values for modified_274.mid are: [6.486486486486872]
# For modified_275.mid, the shortest note duration (T0) is: 0.026119391666668434
# First 1 Ni values for modified_275.mid are: [10.92857142857072]
# For modified_276.mid, the shortest note duration (T0) is: 0.09374989999997752
# First 1 Ni values for modified_276.mid are: [2.3529411764711456]
# For modified_277.mid, the shortest note duration (T0) is: 0.007267437499990592
# First 1 Ni values for modified_277.mid are: [47.448292469037035]
# For modified_278.mid, the shortest note duration (T0) is: 0.02083331250000242
# First 1 Ni values for modified_278.mid are: [17.142857142855153]
# For modified_279.mid, the shortest note duration (T0) is: 0.0053571374999989985
# First 1 Ni values for modified_279.mid are: [80.0000000000146]
# For modified_280.mid, the shortest note duration (T0) is: 0.063235262500001
# First 1 Ni values for modified_280.mid are: [11.571170436747868]
# For modified_281.mid, the shortest note duration (T0) is: 0.01811591666666601
# First 1 Ni values for modified_281.mid are: [5.6000000000002546]
# For modified_282.mid, the shortest note duration (T0) is: 0.06678075624998314
# First 1 Ni values for modified_282.mid are: [6.128205128206683]
# For modified_283.mid, the shortest note duration (T0) is: 0.07770262500000058
# First 1 Ni values for modified_283.mid are: [6.195652173913002]
# For modified_284.mid, the shortest note duration (T0) is: 0.0024509791666673664
# First 1 Ni values for modified_284.mid are: [208.99999999993912]
# For modified_285.mid, the shortest note duration (T0) is: 0.06249986250000461
# First 1 Ni values for modified_285.mid are: [7.058823529411243]
# For modified_286.mid, the shortest note duration (T0) is: 0.004310341666666773
# First 1 Ni values for modified_286.mid are: [247.4999999999934]
# For modified_287.mid, the shortest note duration (T0) is: 0.003623183333331781
# First 1 Ni values for modified_287.mid are: [59.500000000025494]
# For modified_288.mid, the shortest note duration (T0) is: 0.021634612500008643
# First 1 Ni values for modified_288.mid are: [13.53812139767029]
# For modified_290.mid, the shortest note duration (T0) is: 0.03260865000001445
# First 1 Ni values for modified_290.mid are: [13.333333333327486]
# For modified_291.mid, the shortest note duration (T0) is: 0.006720416666667006
# First 1 Ni values for modified_291.mid are: [47.99999999999736]
# For modified_292.mid, the shortest note duration (T0) is: 0.004310343750006496
# First 1 Ni values for modified_292.mid are: [16.333333333308882]
# For modified_293.mid, the shortest note duration (T0) is: 0.0529660416666502
# First 1 Ni values for modified_293.mid are: [5.720000000001763]
# For modified_294.mid, the shortest note duration (T0) is: 0.053571374999989985
# First 1 Ni values for modified_294.mid are: [8.133333333334836]
# For modified_296.mid, the shortest note duration (T0) is: 0.04090908749999933
# First 1 Ni values for modified_296.mid are: [6.888888888889005]
# For modified_297.mid, the shortest note duration (T0) is: 0.014705866666673728
# First 1 Ni values for modified_297.mid are: [59.87499999997125]
# For modified_298.mid, the shortest note duration (T0) is: 0.0038659812499872714
# First 1 Ni values for modified_298.mid are: [79.66666666692858]
# For modified_299.mid, the shortest note duration (T0) is: 0.049568929166667886
# First 1 Ni values for modified_299.mid are: [5.217391304347683]
# For modified_300.mid, the shortest note duration (T0) is: 0.0017857124999522966
# First 1 Ni values for modified_300.mid are: [219.19855520440976]
# For modified_301.mid, the shortest note duration (T0) is: 0.06837606666666574
# First 1 Ni values for modified_301.mid are: [2.750000000000026]
# For modified_302.mid, the shortest note duration (T0) is: 0.023214262500005134
# First 1 Ni values for modified_302.mid are: [9.153846153844153]
# For modified_303.mid, the shortest note duration (T0) is: 0.011513147916666355
# First 1 Ni values for modified_303.mid are: [34.28571428571526]
# For modified_304.mid, the shortest note duration (T0) is: 0.006696431249991974
# First 1 Ni values for modified_304.mid are: [11.666666666680637]
# For modified_305.mid, the shortest note duration (T0) is: 0.07565782916666564
# First 1 Ni values for modified_305.mid are: [5.000000000000047]
# For modified_306.mid, the shortest note duration (T0) is: 0.00953386874999751
# First 1 Ni values for modified_306.mid are: [26.66666666667375]
# For modified_308.mid, the shortest note duration (T0) is: 0.06854832083333395
# First 1 Ni values for modified_308.mid are: [2.117647058823508]
# For modified_310.mid, the shortest note duration (T0) is: 0.054166666666674246
# First 1 Ni values for modified_310.mid are: [4.7499999999993445]
# For modified_311.mid, the shortest note duration (T0) is: 0.03125
# First 1 Ni values for modified_311.mid are: [10.0]
# For modified_312.mid, the shortest note duration (T0) is: 0.049744743749982945
# First 1 Ni values for modified_312.mid are: [6.1282051282072265]
# For modified_313.mid, the shortest note duration (T0) is: 0.04032254166668281
# First 1 Ni values for modified_313.mid are: [5.9999999999976215]
# For modified_314.mid, the shortest note duration (T0) is: 0.02840906249998909
# First 1 Ni values for modified_314.mid are: [15.933333333339428]
# For modified_315.mid, the shortest note duration (T0) is: 0.010080635416670702
# First 1 Ni values for modified_315.mid are: [26.599999999989215]
# For modified_316.mid, the shortest note duration (T0) is: 0.06024091666667175
# First 1 Ni values for modified_316.mid are: [6.69999999999944]
# For modified_317.mid, the shortest note duration (T0) is: 0.017307656250011405
# First 1 Ni values for modified_317.mid are: [13.333333333324301]
# For modified_318.mid, the shortest note duration (T0) is: 0.007575733333325729
# First 1 Ni values for modified_318.mid are: [30.000000000030248]
# For modified_319.mid, the shortest note duration (T0) is: 0.05597012500001597
# First 1 Ni values for modified_319.mid are: [7.966666666664375]
# For modified_320.mid, the shortest note duration (T0) is: 0.054031574999996224
# First 1 Ni values for modified_320.mid are: [2.5384615384617355]
# For modified_321.mid, the shortest note duration (T0) is: 0.04545449999997686
# First 1 Ni values for modified_321.mid are: [10.00000000000508]
# For modified_322.mid, the shortest note duration (T0) is: 0.004166666666662877
# First 1 Ni values for modified_322.mid are: [119.50000000010914]
# For modified_323.mid, the shortest note duration (T0) is: 0.04791666666666572
# First 1 Ni values for modified_323.mid are: [5.173913043478403]
# For modified_324.mid, the shortest note duration (T0) is: 0.09294850416667089
# First 1 Ni values for modified_324.mid are: [4.137931034482567]
# For modified_325.mid, the shortest note duration (T0) is: 0.001893939583339943
# First 1 Ni values for modified_325.mid are: [160.99999999943725]
# For modified_326.mid, the shortest note duration (T0) is: 0.08189649166665447
# First 1 Ni values for modified_326.mid are: [6.3157894736851325]
# For modified_327.mid, the shortest note duration (T0) is: 0.05961519583331665
# First 1 Ni values for modified_327.mid are: [4.483870967743166]
# For modified_328.mid, the shortest note duration (T0) is: 0.036111075000007986
# First 1 Ni values for modified_328.mid are: [9.23076923076718]
# For modified_329.mid, the shortest note duration (T0) is: 0.011811025000000086
# First 1 Ni values for modified_329.mid are: [23.333333333333133]
# For modified_330.mid, the shortest note duration (T0) is: 0.00474683125000297
# First 1 Ni values for modified_330.mid are: [39.33333333330876]
# For modified_331.mid, the shortest note duration (T0) is: 0.005555558333327326
# First 1 Ni values for modified_331.mid are: [73.35164932425486]
# For modified_332.mid, the shortest note duration (T0) is: 0.08909562291666706
# First 1 Ni values for modified_332.mid are: [3.567164179104447]
# For modified_334.mid, the shortest note duration (T0) is: 0.008196708333315428
# First 1 Ni values for modified_334.mid are: [30.000000000065448]
# For modified_336.mid, the shortest note duration (T0) is: 0.007999983333334626
# First 1 Ni values for modified_336.mid are: [12.624999999998002]
# For modified_337.mid, the shortest note duration (T0) is: 0.0014705875000089463
# First 1 Ni values for modified_337.mid are: [238.99999999854566]
# For modified_338.mid, the shortest note duration (T0) is: 0.03324463541666489
# First 1 Ni values for modified_338.mid are: [9.56000000000047]
# For modified_339.mid, the shortest note duration (T0) is: 0.06944433333333322
# First 1 Ni values for modified_339.mid are: [1.700000000000005]
# For modified_340.mid, the shortest note duration (T0) is: 0.036885150000003364
# First 1 Ni values for modified_340.mid are: [8.88888888888814]
# For modified_341.mid, the shortest note duration (T0) is: 0.0015060208333323999
# First 1 Ni values for modified_341.mid are: [82.0000000000519]
# For modified_342.mid, the shortest note duration (T0) is: 0.07395833333333712
# First 1 Ni values for modified_342.mid are: [3.380281690140672]
# For modified_343.mid, the shortest note duration (T0) is: 0.015624977083319891
# First 1 Ni values for modified_343.mid are: [34.28571428574378]
# For modified_344.mid, the shortest note duration (T0) is: 0.0316900874999817
# First 1 Ni values for modified_344.mid are: [14.611111111119483]
# For modified_345.mid, the shortest note duration (T0) is: 0.003124999999982947
# First 1 Ni values for modified_345.mid are: [599.5000000032719]
# For modified_346.mid, the shortest note duration (T0) is: 0.016369031250007993
# First 1 Ni values for modified_346.mid are: [21.727272727262132]
# For modified_347.mid, the shortest note duration (T0) is: 0.04861109166667177
# First 1 Ni values for modified_347.mid are: [8.535714285713377]
# For modified_348.mid, the shortest note duration (T0) is: 0.0381355500000069
# First 1 Ni values for modified_348.mid are: [6.611111111109931]
# For modified_349.mid, the shortest note duration (T0) is: 0.0078125
# First 1 Ni values for modified_349.mid are: [59.75]
# For modified_353.mid, the shortest note duration (T0) is: 0.04108317500003977
# First 1 Ni values for modified_353.mid are: [7.260869565210398]
# For modified_369.mid, the shortest note duration (T0) is: 0.0010330583333200138
# First 1 Ni values for modified_369.mid are: [375.51679076367327]
# For modified_392.mid, the shortest note duration (T0) is: 0.022435845833342682
# First 1 Ni values for modified_392.mid are: [16.357142857136004]
# For modified_396.mid, the shortest note duration (T0) is: 0.04419886666664752
# First 1 Ni values for modified_396.mid are: [7.236212080478806]
# For modified_407.mid, the shortest note duration (T0) is: 0.0020833333333314386
# First 1 Ni values for modified_407.mid are: [209.0000000001893]
# For modified_411.mid, the shortest note duration (T0) is: 0.013392843749983285
# First 1 Ni values for modified_411.mid are: [9.77777777778998]
# For modified_454.mid, the shortest note duration (T0) is: 0.013392824999982622
# First 1 Ni values for modified_454.mid are: [19.416666666691825]
# For modified_456.mid, the shortest note duration (T0) is: 0.021417412499999955
# First 1 Ni values for modified_456.mid are: [7.813209034160116]
# For modified_537.mid, the shortest note duration (T0) is: 0.05666666666667197
# First 1 Ni values for modified_537.mid are: [8.764705882352175]
# For modified_538.mid, the shortest note duration (T0) is: 0.03879307499999385
# First 1 Ni values for modified_538.mid are: [3.8333333333339437]
# For modified_539.mid, the shortest note duration (T0) is: 0.03437499999999716
# First 1 Ni values for modified_539.mid are: [22.969696969698855]
# For modified_540.mid, the shortest note duration (T0) is: 0.062499816666672814
# First 1 Ni values for modified_540.mid are: [9.47826086956425]
# For modified_542.mid, the shortest note duration (T0) is: 0.004166666666662877
# First 1 Ni values for modified_542.mid are: [23.250000000021316]
# For modified_543.mid, the shortest note duration (T0) is: 0.010416666666671404
# First 1 Ni values for modified_543.mid are: [10.199999999995635]
# For modified_549.mid, the shortest note duration (T0) is: 0.005434774999997671
# First 1 Ni values for modified_549.mid are: [146.00000000006276]
# For modified_552.mid, the shortest note duration (T0) is: 0.0012755104166615183
# First 1 Ni values for modified_552.mid are: [366.000000001479]
# For modified_554.mid, the shortest note duration (T0) is: 0.008928562499988857
# First 1 Ni values for modified_554.mid are: [22.000000000027455]
# For modified_555.mid, the shortest note duration (T0) is: 0.006666666666660603
# First 1 Ni values for modified_555.mid are: [26.750000000024514]
# For modified_556.mid, the shortest note duration (T0) is: 0.04128434999999797
# First 1 Ni values for modified_556.mid are: [6.666666666667068]
# For modified_558.mid, the shortest note duration (T0) is: 0.012295075000000821
# First 1 Ni values for modified_558.mid are: [8.8333333333329]
# For modified_562.mid, the shortest note duration (T0) is: 0.05136981249999906
# First 1 Ni values for modified_562.mid are: [7.7333333333334116]
# For modified_564.mid, the shortest note duration (T0) is: 0.04078941250000412
# First 1 Ni values for modified_564.mid are: [6.354838709676827]
# For modified_565.mid, the shortest note duration (T0) is: 0.0132211520833323
# First 1 Ni values for modified_565.mid are: [18.090909090910507]
# For modified_566.mid, the shortest note duration (T0) is: 0.004518068749995052
# First 1 Ni values for modified_566.mid are: [64.66666666673744]
# For modified_568.mid, the shortest note duration (T0) is: 0.059321966666686876
# First 1 Ni values for modified_568.mid are: [14.428571428566569]
# For modified_569.mid, the shortest note duration (T0) is: 0.06849308333333681
# First 1 Ni values for modified_569.mid are: [4.274999999999829]
# For modified_570.mid, the shortest note duration (T0) is: 0.02499994791665472
# First 1 Ni values for modified_570.mid are: [1.7692307692316438]
# For modified_571.mid, the shortest note duration (T0) is: 0.06919639166665092
# First 1 Ni values for modified_571.mid are: [2.3870967741941183]
# For modified_572.mid, the shortest note duration (T0) is: 0.02205879999999638
# First 1 Ni values for modified_572.mid are: [12.08333333333532]
# For modified_576.mid, the shortest note duration (T0) is: 0.018092112499999757
# First 1 Ni values for modified_576.mid are: [8.81818181818197]
# For modified_578.mid, the shortest note duration (T0) is: 0.04999999999999716
# First 1 Ni values for modified_578.mid are: [2.6666666666668797]
# For modified_597.mid, the shortest note duration (T0) is: 0.02205879999999638
# First 1 Ni values for modified_597.mid are: [10.083333333334998]
# For modified_605.mid, the shortest note duration (T0) is: 0.03747235416666683
# First 1 Ni values for modified_605.mid are: [2.6842105263158342]
# For modified_613.mid, the shortest note duration (T0) is: 0.02092846250000946
# First 1 Ni values for modified_613.mid are: [23.057516468291947]
# For modified_618.mid, the shortest note duration (T0) is: 0.02604165625000121
# First 1 Ni values for modified_618.mid are: [10.199999999999564]
# For modified_653.mid, the shortest note duration (T0) is: 0.03781507499999748
# First 1 Ni values for modified_653.mid are: [16.86111111111227]
# For modified_683.mid, the shortest note duration (T0) is: 0.0019083979166509835
# First 1 Ni values for modified_683.mid are: [102.00000000083773]
# For modified_684.mid, the shortest note duration (T0) is: 0.01428571666666656
# First 1 Ni values for modified_684.mid are: [25.00000000000025]
# For modified_694.mid, the shortest note duration (T0) is: 0.03937944999999843
# First 1 Ni values for modified_694.mid are: [5.00000000000018]
# For modified_703.mid, the shortest note duration (T0) is: 0.04807692708331501
# First 1 Ni values for modified_703.mid are: [7.680000000002935]
# For modified_713.mid, the shortest note duration (T0) is: 0.05397725833333311
# First 1 Ni values for modified_713.mid are: [1.6315789473684037]
# For modified_717.mid, the shortest note duration (T0) is: 0.017187500000005684
# First 1 Ni values for modified_717.mid are: [18.99999999999359]
# For modified_719.mid, the shortest note duration (T0) is: 0.004385958333330109
# First 1 Ni values for modified_719.mid are: [28.00000000002106]
# For modified_740.mid, the shortest note duration (T0) is: 0.027173874999988357
# First 1 Ni values for modified_740.mid are: [28.750009583358885]
# For modified_775.mid, the shortest note duration (T0) is: 0.02016129166666758
# First 1 Ni values for modified_775.mid are: [15.1999999999994]
# For modified_781.mid, the shortest note duration (T0) is: 0.03598485208331681
# First 1 Ni values for modified_781.mid are: [10.052631578952019]
# For modified_789.mid, the shortest note duration (T0) is: 0.04356061041666237
# First 1 Ni values for modified_789.mid are: [1.8260869565219306]
# For modified_790.mid, the shortest note duration (T0) is: 0.06960225416666788
# First 1 Ni values for modified_790.mid are: [4.1428571428570695]
# For modified_792.mid, the shortest note duration (T0) is: 0.002840908333354264
# First 1 Ni values for modified_792.mid are: [338.99999999750247]
# For modified_795.mid, the shortest note duration (T0) is: 0.009868425000000514
# First 1 Ni values for modified_795.mid are: [39.66666666666445]
# For modified_796.mid, the shortest note duration (T0) is: 0.021959464583346744
# First 1 Ni values for modified_796.mid are: [7.3076923076878275]
# For modified_798.mid, the shortest note duration (T0) is: 0.03531904999999824
# First 1 Ni values for modified_798.mid are: [5.291666666666868]
# For modified_799.mid, the shortest note duration (T0) is: 0.007994354166669382
# First 1 Ni values for modified_799.mid are: [24.999999999992]
# For modified_806.mid, the shortest note duration (T0) is: 0.13097424374999989
# First 1 Ni values for modified_806.mid are: [4.526315789473679]
# For modified_825.mid, the shortest note duration (T0) is: 0.028409083333315266
# First 1 Ni values for modified_825.mid are: [9.300000000005902]
# For modified_882.mid, the shortest note duration (T0) is: 0.01770833333333144
# First 1 Ni values for modified_882.mid are: [13.529411764707463]
# For modified_890.mid, the shortest note duration (T0) is: 0.010714287499993702
# First 1 Ni values for modified_890.mid are: [23.333333333347205]
# For modified_896.mid, the shortest note duration (T0) is: 0.025390625
# First 1 Ni values for modified_896.mid are: [8.615384615384615]
# For modified_898.mid, the shortest note duration (T0) is: 0.017123291666678142
# First 1 Ni values for modified_898.mid are: [24.69999999998338]
# For modified_901.mid, the shortest note duration (T0) is: 0.013461539583333959
# First 1 Ni values for modified_901.mid are: [16.428571428570713]
# For modified_905.mid, the shortest note duration (T0) is: 0.03591502708333394
# First 1 Ni values for modified_905.mid are: [25.086956521738703]
# For modified_906.mid, the shortest note duration (T0) is: 0.006476681249999672
# First 1 Ni values for modified_906.mid are: [16.000000000001098]

# %%
import os
import matplotlib.pyplot as plt

# Assuming songs_with_4_4_timing is a list of file paths
directories = [os.path.dirname(song) for song in songs_with_4_4_timing]

# Count occurrences of each directory
dir_counts = {}
for directory in directories:
    dir_counts[directory] = dir_counts.get(directory, 0) + 1

# Plotting
dirs = list(dir_counts.keys())
counts = list(dir_counts.values())

plt.figure(figsize=(10,6))
plt.bar(dirs, counts)
plt.xlabel('Directory')
plt.ylabel('Number of songs')
plt.title('Number of songs in each directory')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import mido
from mido import MidiFile
import matplotlib.pyplot as plt
import numpy as np

def visualize_midi(midi_path):
    mid = MidiFile(midi_path)

    # Extract note events
    notes = []
    for track in mid.tracks:
        for msg in track:
            if msg.type == 'note_on':
                notes.append(msg.note)

    # Piano roll visualization
    plt.figure(figsize=(15, 6))

    plt.subplot(1, 2, 1)
    plt.hist(notes, bins=np.arange(21, 109), align='left', rwidth=0.8)
    plt.xlabel('Note')
    plt.ylabel('Frequency')
    plt.title('Note Histogram')
    plt.xticks(np.arange(21, 109, 12), ['A0', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7'])

    plt.subplot(1, 2, 2)
    plt.eventplot(notes, orientation='horizontal', linelengths=0.8, colors='b')
    plt.yticks(np.arange(21, 109, 12), ['A0', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7'])
    plt.xlabel('Time (arbitrary units)')
    plt.title('Piano Roll')

    plt.tight_layout()
    plt.show()

# Test with one of your MIDI files
midi_path = songs_with_4_4_timing[0] # Replace this if necessary
visualize_midi(midi_path)

# %%
import music21
import networkx as nx
import matplotlib.pyplot as plt

def visualize_chord_network(midi_path):
    # Load the MIDI file into music21
    s = music21.converter.parse(midi_path)

    # Extract chords from the MIDI
    chords = s.chordify().recurse().notes
    
    # Create a graph
    G = nx.DiGraph()
    
    # Populate the graph with chord transitions
    for i in range(len(chords) - 1):
        if not G.has_edge(str(chords[i]), str(chords[i+1])):
            G.add_edge(str(chords[i]), str(chords[i+1]), weight=1)
        else:
            G[str(chords[i])][str(chords[i+1])]['weight'] += 1

    # Draw the network
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos, node_color='lightblue')
    nx.draw_networkx_labels(G, pos)
    nx.draw_networkx_edges(G, pos, width=[d['weight'] for _, _, d in G.edges(data=True)], edge_color='lightblue', arrowstyle='-|>', arrowsize=20)
    
    plt.title("Chord Transition Network")
    plt.show()

# Test with one of your MIDI files
midi_path = songs_with_4_4_timing[0]  # Replace this if necessary
visualize_chord_network(midi_path)
# Out:
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=8, channel=None, data=b'Copyright 2004 by Bernd Kr\xfcger.'>; getting generic Instrument
#   warnings.warn(

# %%
import music21
import numpy as np
import matplotlib.pyplot as plt

def visualize_note_distribution(midi_path):
    # Load the MIDI file into music21
    s = music21.converter.parse(midi_path)
    
    # Extract note events
    note_events = [n for n in s.recurse() if isinstance(n, music21.note.Note)]
    
    # Extract note pitches and their start time
    pitches = [n.pitch.midi for n in note_events]
    times = [n.offset for n in note_events]
    
    # Create a histogram
    time_bins = np.arange(0, max(times), 2)  # 2-second bins, adjust if needed
    pitch_bins = np.arange(0, 128)  # MIDI notes range from 0 to 127
    
    H, xedges, yedges = np.histogram2d(times, pitches, bins=[time_bins, pitch_bins])
    
    # Plot the histogram
    plt.imshow(H.T, origin='lower', aspect='auto', extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])
    plt.colorbar(label='Note Count')
    plt.xlabel('Time (seconds)')
    plt.ylabel('MIDI Note Number')
    plt.title('Note Distribution Over Time')
    plt.show()

# Test with one of your MIDI files
midi_path = songs_with_4_4_timing[0]  # Replace this if necessary
visualize_note_distribution(midi_path)

# %%
import music21
import numpy as np
import matplotlib.pyplot as plt

def visualize_rhythmic_patterns(midi_path, resolution=0.25):
    """Visualize rhythmic patterns using a binary heatmap.
    
    Parameters:
        midi_path (str): Path to the MIDI file.
        resolution (float): Time resolution in quarter notes. E.g., 0.25 means 16th note resolution.
    """
    s = music21.converter.parse(midi_path)
    
    # Calculate the total length in quarter notes
    total_length = max([n.offset + n.duration.quarterLength for n in s.recurse().notes])
    matrix_width = int(total_length / resolution)
    
    # Initialize a zeros matrix
    rhythm_matrix = np.zeros((int(1 / resolution), matrix_width))
    
    for n in s.recurse().notes:
        y_pos = min(int(n.duration.quarterLength / resolution) - 1, rhythm_matrix.shape[0] - 1)
        x_pos = min(int(n.offset / resolution), matrix_width - 1)
        rhythm_matrix[y_pos, x_pos] = 1
    
    # Plotting
    plt.imshow(rhythm_matrix, cmap="binary", aspect="auto", origin="lower")
    plt.xlabel('Position ({} per column)'.format(resolution))
    plt.ylabel('Duration ({} per row)'.format(resolution))
    plt.title('Rhythmic Patterns')
    plt.colorbar(ticks=[0, 1], label='Note Start')
    plt.show()

# Test with your MIDI file
midi_path = songs_with_4_4_timing[0]  
visualize_rhythmic_patterns(midi_path)

# %% [markdown]
# The visualization you've generated is a binary heatmap representation of rhythmic patterns in the MIDI song. It allows you to understand the rhythmic structure and motifs by presenting note durations and their onset positions in a concise manner. Here's how you can interpret it:
#
# X-axis (Position):
#
# Represents the temporal position of the note in the song.
# Moving from left to right corresponds to moving from the beginning to the end of the song.
# The resolution of this axis (i.e., the length of time each column represents) is determined by the resolution parameter. If the resolution is set to 0.25, for instance, then each column represents a 16th note's worth of time.
# Y-axis (Duration):
#
# Represents the duration of notes.
# The bottom row might represent notes of 16th note duration, the next row might represent 8th notes, then quarter notes, and so on, depending on your resolution setting.
# So, if there's a mark on the bottom row, it means there's a 16th note played at that time. If it's on the second row, there's an 8th note played, etc.
# Marks (white spots):
#
# Each white spot in the heatmap indicates the onset of a note.
# The position on the X-axis indicates when the note starts, and the position on the Y-axis tells you the duration of that note.
# Interpreting Patterns:
#
# Horizontal Lines: Repeated rhythmic motifs of the same duration.
# Vertical Lines: Chords or simultaneous notes of different durations played together.
# Clusters: Sections of the song with a lot of rhythmic activity.
# Absence of Marks:
#
# Areas in the heatmap that are uniformly dark indicate rests or pauses in the song where no notes are played.
# As an example, if you see a cluster of marks on the bottom-most row at the start of the X-axis, it indicates that the song starts with a rapid succession of 16th notes. If you see a mark higher up in the Y-axis, it means longer notes (like half notes or whole notes) are being played at that point in time.
#
# Remember, this visualization only gives you insight into the rhythmic structure of the song, not its melody or harmony. It's a tool to quickly grasp how rhythms evolve and are structured throughout a piece. If there are particular patterns or rhythms that are common in the piece, they should be evident as repeated patterns in the visualization.

# %%
def circular_rhythm_plot(midi_path, measures_per_circle=4):
    # Load the MIDI file into music21
    s = music21.converter.parse(midi_path)
    
    # Extract note events
    note_events = [n for n in s.recurse() if isinstance(n, music21.note.Note)]
    
    # Get the time signature if it exists, default to 4/4
    time_signature = s.getTimeSignatures()[0] if len(s.getTimeSignatures()) > 0 else music21.meter.TimeSignature('4/4')
    
    # Calculate the total number of measures in the song
    total_measures = int(max([n.offset for n in note_events]) / (time_signature.numerator / time_signature.denominator))
    
    # Create a polar plot
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111, projection='polar')
    
    # Loop over the note events to plot them
    for n in note_events:
        # Calculate the radial position based on note duration
        r = n.duration.quarterLength
        # Calculate the angular position based on measure
        theta = 2 * np.pi * (n.offset / measures_per_circle)
        ax.plot([theta, theta], [0, r], color="black")  # Draw a line from the center to the outer ring based on the note duration
    
    # Configure the plot to improve appearance
    ax.set_yticklabels([])  # Hide radial ticks
    ax.set_xticks(np.linspace(0, 2*np.pi, measures_per_circle, endpoint=False))  # Set number of sectors
    ax.set_title("Circular Rhythm Plot")
    
    plt.show()

# Test with one of your MIDI files
midi_path = songs_with_4_4_timing[0]
circular_rhythm_plot(midi_path)

# %% [markdown]
# The Circular Rhythm Plot is a visual representation of the rhythmic patterns of a song or musical piece. This visualization provides insights into the structure and repetition of rhythms, potentially revealing patterns that might not be as noticeable when looking at standard sheet music or hearing the music.
#
# Here's what the visualization tells you:
#
# Circular Structure: The entire song is represented as a circle. Depending on the parameter you choose, this circle might represent the entire song, or it might represent a fixed number of measures, with multiple circles representing the song. In the code above, by default, one circle represents 4 measures.
#
# Segments in Circle: The circle is divided into segments, with each segment corresponding to a beat or measure (depending on your chosen granularity).
#
# Dots/Lines Within Segments: Inside each segment, you'll see lines that represent individual notes. The length (distance from the center of the circle) of each line indicates the note's duration or emphasis. A longer line means a note held for a longer time.
#
# Interpreting the visualization:
#
# Repeating Patterns: If you see similar patterns or clusters of lines occurring repeatedly as you move around the circle, it means there are recurring rhythmic patterns in the music.
#
# Rhythmic Complexity: Dense clusters of lines indicate measures or segments with more rhythmic activity. If there are sparse or no lines in certain segments, it means those parts of the music have rests or fewer notes.
#
# Song Structure: The start and end of circular segments (or entire circles, if multiple are used) can help you visually discern the structure of the song. For instance, you might notice that the rhythmic pattern of the first and last circles (or segments) is similar, indicating a repeated intro and outro.
#
# Note Duration Patterns: If certain segments consistently have longer lines, it indicates those segments in the music tend to have longer, sustained notes.
#
# In summary, the Circular Rhythm Plot provides a high-level visual summary of the rhythmic patterns and structures of a song, making it easier to identify repeated sections, changes in rhythm, and other structural elements of the music. It's especially useful for analyzing pieces where rhythm plays a crucial role, such as in many forms of dance music, percussive pieces, or rhythmic exercises.

# %%
import music21

# Load the first MIDI file from the list
midi_path = songs_with_4_4_timing[0]
midi_song = music21.converter.parse(midi_path)

# Print the parts (e.g., instruments or voices) in the MIDI file
for part in midi_song.parts:
    print(part.id)

# Print the first few measures of the first part
for measure in midi_song.parts[0].getElementsByClass('Measure')[:5]:
    print(measure)
# Out:
# 2004228594896
# 2004224720512
# 2004183571184
# 2004240006448
# 2004225673584
# 2004239584128
# <music21.stream.Measure 1 offset=0.0>
# <music21.stream.Measure 2 offset=4.0>
# <music21.stream.Measure 3 offset=8.0>
# <music21.stream.Measure 4 offset=12.0>
# <music21.stream.Measure 5 offset=16.0>

# %%
import music21

# Assuming songs_with_4_4_timing is a list of MIDI file paths
midi_path = songs_with_4_4_timing[0]

# Parse the MIDI file with music21
score = music21.converter.parse(midi_path)

# Extract all note events
note_events = [n for n in score.recurse() if isinstance(n, music21.note.Note)]

# Print attributes of the first few notes
for note in note_events[:10]:  # Adjust as necessary
    print("Pitch:", note.pitch.nameWithOctave)
    print("MIDI Number:", note.pitch.midi)
    print("Start Time (Offset):", note.offset)
    print("Duration:", note.duration.quarterLength)
    print("Velocity:", note.volume.velocity)
    print("---------------")
# Out:
# Pitch: G4
# MIDI Number: 67
# Start Time (Offset): 0.5
# Duration: 0.25
# Velocity: 56
# ---------------
# Pitch: C5
# MIDI Number: 72
# Start Time (Offset): 0.75
# Duration: 0.25
# Velocity: 60
# ---------------
# Pitch: E5
# MIDI Number: 76
# Start Time (Offset): 1.0
# Duration: 0.25
# Velocity: 63
# ---------------
# Pitch: G4
# MIDI Number: 67
# Start Time (Offset): 1.25
# Duration: 0.25
# Velocity: 50
# ---------------
# Pitch: C5
# MIDI Number: 72
# Start Time (Offset): 1.5
# Duration: 0.25
# Velocity: 47
# ---------------
# Pitch: E5
# MIDI Number: 76
# Start Time (Offset): 1.75
# Duration: 0.25
# Velocity: 47
# ---------------
# Pitch: G4
# MIDI Number: 67
# Start Time (Offset): 2.5
# Duration: 0.25
# Velocity: 56
# ---------------
# Pitch: C5
# MIDI Number: 72
# Start Time (Offset): 2.75
# Duration: 0.25
# Velocity: 60
# ---------------
# Pitch: E5
# MIDI Number: 76
# Start Time (Offset): 3.0
# Duration: 0.25
# Velocity: 62
# ---------------
# Pitch: G4
# MIDI Number: 67
# Start Time (Offset): 3.25
# Duration: 0.25
# Velocity: 50
# ---------------

# %%
import music21

def ensure_start_at_zero(midi_path):
    # Load the MIDI file into music21
    s = music21.converter.parse(midi_path)
    
    # Get the minimum offset where a note or chord starts
    min_offset = min([n.offset for n in s.recurse() if isinstance(n, (music21.note.Note, music21.chord.Chord))])
    
    # If the minimum offset isn't zero, adjust all offsets
    if min_offset != 0:
        for element in s.recurse():
            element.offset -= min_offset
    
    # Save the adjusted MIDI file with a new name
    adjusted_path = os.path.join(os.path.dirname(midi_path), 'adjusted_' + os.path.basename(midi_path))
    s.write('midi', fp=adjusted_path)

for midi_path in songs_with_4_4_timing:
    ensure_start_at_zero(midi_path)
# Out:
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=7, channel=None, data=b'Copyright 2004 by Bernd Kr\xfcger.'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=0, channel=None, data=b'Pr\xe4ludium und Fuge in D-Dur, BWV 850'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=8, channel=None, data=b'Copyright 1997 by Bernd Kr\xfcger.'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2008 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2009 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=0, channel=None, data=b'Mondscheinsonate; der Gr\xe4fin Giulietta Guiccardi gewidmet'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=6, channel=None, data=b'Copyright \xa9 1998 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Beethoven Sonata No. 8 C minor, Grand Sonate path\xe9tique 3. Movement'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2003 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 2000 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 2012 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2004 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 2004 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2012 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 2002 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 2003 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2010 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 1998 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=0, channel=None, data=b'Grieg: Lyrische St\xfccke Op. 43 No. 1 - Schmetterling'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2007 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=0, channel=None, data=b'W\xe4chterlied Op12, No. 3'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 1997 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 1998 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=6, channel=None, data=b'Copyright \xa9 2010 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2000 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2006 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 1997 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2006 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2002 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=0, channel=None, data=b'Tr\xe4umerei'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=0, channel=None, data=b'Schumann:   Fr\xf6hlicher Landmann, von der Arbeit zur\xfcckkehrend'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=0, channel=None, data=b'aus Album f\xfcr die Jugend Opus 68, Nr. 10'>; getting generic Instrument
#   warnings.warn(
# C:\Users\paperspace\anaconda3\lib\site-packages\music21\midi\translate.py:863: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Schumann: Fr\xf6hlicher Landmann'>; getting generic Instrument
#   warnings.warn(

# %% [markdown]
# import music21
# import os
#
# def ensure_start_at_zero(midi_path):
#     # Load the MIDI file into music21
#     s = music21.converter.parse(midi_path)
#
#     # Get the minimum offset where a note or chord starts
#     min_offset = min([n.offset for n in s.recurse() if isinstance(n, (music21.note.Note, music21.chord.Chord))])
#
#     # If the minimum offset isn't zero, adjust all offsets
#     if min_offset != 0:
#         for element in s.recurse():
#             element.offset -= min_offset
#
#     # Save the adjusted MIDI file with a new name
#     adjusted_path = os.path.join(os.path.dirname(midi_path), 'adjusted_' + os.path.basename(midi_path))
#     s.write('midi', fp=adjusted_path)
#
#     return adjusted_path
#
# adjusted_midi_paths = [ensure_start_at_zero(midi_path) for midi_path in songs_with_4_4_timing]
#
# # After adjusting, print the note information for the first adjusted MIDI
# midi_path = adjusted_midi_paths[0]
# score = music21.converter.parse(midi_path)
# note_events = [n for n in score.recurse() if isinstance(n, music21.note.Note)]
#
# for note in note_events[:10]:  # Adjust as necessary
#     print("Pitch:", note.pitch.nameWithOctave)
#     print("MIDI Number:", note.pitch.midi)
#     print("Start Time (Offset):", note.offset)
#     print("Duration:", note.duration.quarterLength)
#     print("Velocity:", note.volume.velocity)
#     print("---------------")

# %%
# After adjusting, print the note information for the first adjusted MIDI
midi_path = adjusted_midi_paths[0]
score = music21.converter.parse(midi_path)
note_events = [n for n in score.recurse() if isinstance(n, music21.note.Note)]

for note in note_events[:10]:  # Adjust as necessary
    print("Pitch:", note.pitch.nameWithOctave)
    print("MIDI Number:", note.pitch.midi)
    print("Start Time (Offset):", note.offset)
    print("Duration:", note.duration.quarterLength)
    print("Velocity:", note.volume.velocity)
    print("---------------")

# %% [markdown]
# #  Dealing with Chords

# %% [markdown]
# The code you provided seems to focus on extracting chord information from MIDI data, which is consistent with the process you described earlier. Here's a breakdown of what each part of the code does:
#
# MIDIChord class initialization: It sets up mappings for pitch classes, chord maps, insiders, outsiders, etc. This information is used to determine chord quality and provide scoring based on notes found in the MIDI.
#
# note2pianoroll function: Converts notes from a MIDI into a pianoroll representation, which is a binary matrix indicating the presence of notes at each tick.
#
# sequencing function: For each chroma (a 12-dimensional representation indicating the presence of each pitch class), this function finds possible root notes for the chord candidates.
#
# scoring function: Given chord candidates, it scores each one based on its quality and notes, considering whether the notes are insiders, outsiders, or perfectly match the chord's map.
#
# find_chord function: For a given segment of the pianoroll, this function determines the most probable chord by first finding chord candidates and then scoring each one.
#
# greedy function: It processes the entire song's chords using a greedy algorithm. This function iteratively selects the chord that extends the furthest in time for each segment of the song.
#
# extract function: This is the main function that processes the MIDI notes to extract chords. It first converts the notes into a pianoroll and then iteratively uses the find_chord function to get chord candidates. Finally, it uses the greedy function to determine the chord sequence for the entire song.
#
# From what's presented, the code seems to employ a reasonably comprehensive strategy for chord extraction, using both musical knowledge (defined chord structures) and algorithmic logic (greedy selection). The miditoolkit library is utilized extensively to parse, process, and handle MIDI data.
#
# To match this with the context provided in the original description, this code corresponds to the "way to get these chords from a MIDI score or a MIDI performance in the data preparation process." If you intend to integrate this with a transformer-based model like the one you described earlier, you would take the chord outputs from this extraction process and convert them into tokens suitable for input into your model.

# %% [markdown]
# The described preprocessing for MIDI files involves the representation of chord events as a separate sequence of tokens, but it's important to remember that the chords are distinct from note-on events. The chords serve as a type of context or conditioning for the subsequent generation of notes by the transformer model. Here's how the transformer might process and use the chords:
#
# Contextual Conditioning: The chord tokens provide the transformer with contextual information about the harmonic content for a given span of time in the MIDI sequence. The transformer uses this context when deciding which notes to generate. In music theory, certain notes tend to be emphasized or preferred over others given a specific chord. For instance, if the chord is C Major, the notes C, E, and G are more likely to be emphasized.
#
# Chord vs. Note Generation: While the chord event token specifies the harmonic context, the actual note generation still relies on the Note-on and Note-off events. The transformer would generate specific notes based on both the preceding notes and the given chord context.
#
# Which Note to Predict: The transformer doesn't inherently prioritize the top, bottom, or middle note of a chord. Instead, it learns from the training data how notes are typically structured given a chord context. If, in the training data, melodies frequently emphasize the root note of the chord, the model will likely produce similar patterns. But, if melodies often play around with chord extensions or other non-chord tones, then the transformer might produce more varied results.
#
# Training Data Dependency: The behavior of the transformer largely depends on the training data. If the training MIDI files often emphasize the bass note of the chord in their melodies, the model might learn to do the same. The same goes for any other patterns present in the training data.
#
# Chord Extensions and Non-Chord Tones: Even if a C Major chord is specified, it doesn't mean only C, E, and G will be played. Music frequently involves chord extensions (like 7ths, 9ths, etc.) and non-chord tones (like passing tones and neighbor tones). The transformer will learn these complex behaviors from the training data.
#
# In summary, by encoding the chord information as input tokens, you're giving the transformer more knowledge about the harmonic context of a given passage, which helps in generating more harmonically coherent outputs. However, exactly how the model uses this information (which notes it emphasizes or chooses) is learned from patterns present in the training data.

# %%
import miditoolkit
import numpy as np

class MIDIChord(object):
    def __init__(self):
        # define pitch classes
        self.PITCH_CLASSES = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
        # define chord maps (required)
        self.CHORD_MAPS = {'maj': [0, 4],
                           'min': [0, 3],
                           'dim': [0, 3, 6],
                           'aug': [0, 4, 8],
                           'dom': [0, 4, 7, 10]}
        # define chord insiders (+1)
        self.CHORD_INSIDERS = {'maj': [7],
                               'min': [7],
                               'dim': [9],
                               'aug': [],
                               'dom': []}
        # define chord outsiders (-1)
        self.CHORD_OUTSIDERS_1 = {'maj': [2, 5, 9],
                                  'min': [2, 5, 8],
                                  'dim': [2, 5, 10],
                                  'aug': [2, 5, 9],
                                  'dom': [2, 5, 9]}
        # define chord outsiders (-2)
        self.CHORD_OUTSIDERS_2 = {'maj': [1, 3, 6, 8, 10],
                                  'min': [1, 4, 6, 9, 11],
                                  'dim': [1, 4, 7, 8, 11],
                                  'aug': [1, 3, 6, 7, 10],
                                  'dom': [1, 3, 6, 8, 11]}

    def note2pianoroll(self, notes, max_tick, ticks_per_beat):
        return miditoolkit.pianoroll.parser.notes2pianoroll(
                note_stream_ori=notes,
                max_tick=max_tick,
                ticks_per_beat=ticks_per_beat)

    def sequencing(self, chroma):
        candidates = {}
        for index in range(len(chroma)):
            if chroma[index]:
                root_note = index
                _chroma = np.roll(chroma, -root_note)
                sequence = np.where(_chroma == 1)[0]
                candidates[root_note] = list(sequence)
        return candidates

    def scoring(self, candidates):
        scores = {}
        qualities = {}
        for root_note, sequence in candidates.items():
            if 3 not in sequence and 4 not in sequence:
                scores[root_note] = -100
                qualities[root_note] = 'None'
            elif 3 in sequence and 4 in sequence:
                scores[root_note] = -100
                qualities[root_note] = 'None'
            else:
                # decide quality
                if 3 in sequence:
                    if 6 in sequence:
                        quality = 'dim'
                    else:
                        quality = 'min'
                elif 4 in sequence:
                    if 8 in sequence:
                        quality = 'aug'
                    else:
                        if 7 in sequence and 10 in sequence:
                            quality = 'dom'
                        else:
                            quality = 'maj'
                # decide score
                maps = self.CHORD_MAPS.get(quality)
                _notes = [n for n in sequence if n not in maps]
                score = 0
                for n in _notes:
                    if n in self.CHORD_OUTSIDERS_1.get(quality):
                        score -= 1
                    elif n in self.CHORD_OUTSIDERS_2.get(quality):
                        score -= 2
                    elif n in self.CHORD_INSIDERS.get(quality):
                        score += 1
                scores[root_note] = score
                qualities[root_note] = quality
        return scores, qualities

    def find_chord(self, pianoroll):
        chroma = miditoolkit.pianoroll.utils.tochroma(pianoroll=pianoroll)
        chroma = np.sum(chroma, axis=0)
        chroma = np.array([1 if c else 0 for c in chroma])
        if np.sum(chroma) == 0:
            return 'N', 'N', 'N', 0
        else:
            candidates = self.sequencing(chroma=chroma)
            scores, qualities = self.scoring(candidates=candidates)
            # bass note
            sorted_notes = []
            for i, v in enumerate(np.sum(pianoroll, axis=0)):
                if v > 0:
                    sorted_notes.append(int(i%12))
            bass_note = sorted_notes[0]
            # root note
            __root_note = []
            _max = max(scores.values())
            for _root_note, score in scores.items():
                if score == _max:
                    __root_note.append(_root_note)
            if len(__root_note) == 1:
                root_note = __root_note[0]
            else:
                #TODO: what should i do
                for n in sorted_notes:
                    if n in __root_note:
                        root_note = n
                        break
            # quality
            quality = qualities.get(root_note)
            sequence = candidates.get(root_note)
            # score
            score = scores.get(root_note)
            return self.PITCH_CLASSES[root_note], quality, self.PITCH_CLASSES[bass_note], score

    def greedy(self, candidates, max_tick, min_length):
        chords = []
        # start from 0
        start_tick = 0
        while start_tick < max_tick:
            _candidates = candidates.get(start_tick)
            _candidates = sorted(_candidates.items(), key=lambda x: (x[1][-1], x[0]))
            # choose
            end_tick, (root_note, quality, bass_note, _) = _candidates[-1]
            if root_note == bass_note:
                chord = '{}:{}'.format(root_note, quality)
            else:
                chord = '{}:{}/{}'.format(root_note, quality, bass_note)
            chords.append([start_tick, end_tick, chord])
            start_tick = end_tick
        # remove :None
        temp = chords
        while ':None' in temp[0][-1]:
            try:
                temp[1][0] = temp[0][0]
                del temp[0]
            except:
                print('NO CHORD')
                return []
        temp2 = []
        for chord in temp:
            if ':None' not in chord[-1]:
                temp2.append(chord)
            else:
                temp2[-1][1] = chord[1]
        return temp2

    def extract(self, notes):
        # read
        max_tick = max([n.end for n in notes])
        ticks_per_beat = 480
        pianoroll = self.note2pianoroll(
            notes=notes, 
            max_tick=max_tick, 
            ticks_per_beat=ticks_per_beat)
        # get lots of candidates
        candidates = {}
        # the shortest: 2 beat, longest: 4 beat
        for interval in [4, 2]:
            for start_tick in range(0, max_tick, ticks_per_beat):
                # set target pianoroll
                end_tick = int(ticks_per_beat * interval + start_tick)
                if end_tick > max_tick:
                    end_tick = max_tick
                _pianoroll = pianoroll[start_tick:end_tick, :]
                # find chord
                root_note, quality, bass_note, score = self.find_chord(pianoroll=_pianoroll)
                # save
                if start_tick not in candidates:
                    candidates[start_tick] = {}
                    candidates[start_tick][end_tick] = (root_note, quality, bass_note, score)
                else:
                    if end_tick not in candidates[start_tick]:
                        candidates[start_tick][end_tick] = (root_note, quality, bass_note, score)
        # greedy
        chords = self.greedy(candidates=candidates, 
                             max_tick=max_tick, 
                             min_length=ticks_per_beat)
        return chords
