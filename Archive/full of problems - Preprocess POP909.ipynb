# %% [markdown]
# ### What is happening in the preprocessing

# %% [markdown]
# # preprocess_midi Function:
#
# - Takes a file path as input.
# - Loads the MIDI file using `pyd.PrettyMIDI`.
# - Extracts notes from all instruments in the MIDI file.
# - Rounds the start and end times of each note to two decimal places.
# - Sorts the notes based on their start times.
# - Uses `MidiEventProcessor` to encode the notes into a representation sequence.
# - Updates a global variable `total` by adding the length of the representation sequence.
# - Returns the representation sequence.
#
# # preprocess_pop909 Function:
#
# - Takes the root folder of the POP909 dataset (`midi_root`) and a directory to save processed data (`save_dir`) as inputs.
# - Iterates through MIDI files in the `midi_root` directory.
# - Calls `preprocess_midi` for each MIDI file to obtain the representation sequence.
# - Collects the representation sequences into a NumPy array (`save_py`).
# - Saves the NumPy array as a file named "pop909-event-token.npy" using `np.save`.
#
# # Data Processing:
#
# - The representation sequence appears to be a sequence of events or tokens derived from the notes in the MIDI files. The exact nature of these events depends on the implementation of `MidiEventProcessor`.
# - The total length of the representation sequences is accumulated in the global variable `total`.
#
# # Execution:
#
# - The code is executed with the POP909 dataset located in the "../pop909" folder, and the processed data is saved in the "midi_data/" directory.

# %% [markdown]
# ref: https://github.com/music-x-lab/POP909-Dataset/blob/master/data_process/data_process.ipynb

# %%
#  '''
# This is the data processing script for POP909:A Pop song Dataset for Music Arrangement Generation
# ============
# It will allow you to quickly process the POP909 Files (Midi) into the Google Magenta's music representation 
#     as like [Music Transformer](https://magenta.tensorflow.org/music-transformer) 
#             [Performance RNN](https://magenta.tensorflow.org/performance-rnn).

# '''

# %%
import os
import pickle
import numpy as np
import pretty_midi as pyd
from music21 import converter, metadata, environment

total = 0

def preprocess_midi(path):
    global total
    data = pyd.PrettyMIDI(path)
    main_notes = []
    acc_notes = []
    for ins in data.instruments:
        acc_notes.extend(ins.notes)
    for i in range(len(main_notes)):
        main_notes[i].start = round(main_notes[i].start, 2)
        main_notes[i].end = round(main_notes[i].end, 2)
    for i in range(len(acc_notes)):
        acc_notes[i].start = round(acc_notes[i].start, 2)
        acc_notes[i].end = round(acc_notes[i].end, 2)
    main_notes.sort(key=lambda x: x.start)
    acc_notes.sort(key=lambda x: x.start)
    
    # Replace the following lines with your own processing logic
    main_events = [(note.start, note.end, note.pitch) for note in main_notes]
    acc_events = [(note.start, note.end, note.pitch) for note in acc_notes]
    
    total += len(main_events) + len(acc_events)
    return main_events, acc_events

def is_midi_file(filename):
    return filename.lower().endswith(".mid")

def preprocess_pop909(midi_root, save_dir):
    save_py = []

    try:
        # Create the "midi_data/" directory if it doesn't exist
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)

        # Traverse subdirectories in "POP909_v3"
        for subdir, dirs, files in os.walk(midi_root):
            for filename in files:
                file_path = os.path.join(subdir, filename)
                if is_midi_file(file_path):
                    try:
                        main_events, acc_events = preprocess_midi(file_path)
                        save_py.append((main_events, acc_events))
                    except KeyboardInterrupt:
                        print(' Abort')
                        return
                    except Exception as e:
                        print(f'Error processing file {file_path}: {e}')

        save_py = np.array(save_py)
        print(save_py.size)
        np.save(os.path.join(save_dir, "pop909-event-token.npy"), save_py)

    except Exception as e:
        print(f'An error occurred: {e}')

# Specify the paths
midi_root = "POP909_v3"
save_dir = "midi_data/"

# Call the preprocessing function
preprocess_pop909(midi_root, save_dir)
# Out:
# C:\Users\naomi\AppData\Local\Temp\ipykernel_18176\1167763997.py:57: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   save_py = np.array(save_py)
# 1756

# %%
import os
import pickle
import numpy as np
import pretty_midi as pyd

total = 0

def preprocess_midi(path):
    global total
    data = pyd.PrettyMIDI(path)
    main_notes = []
    acc_notes = []
    
    # Extract all notes from all instruments
    for ins in data.instruments:
        acc_notes.extend(ins.notes)
    
    # Quantize notes in each bar
    for i in range(len(acc_notes)):
        acc_notes[i].start = round(acc_notes[i].start, 2)
        acc_notes[i].end = round(acc_notes[i].end, 2)
        # Quantize to the nearest 16th note
        acc_notes[i].start = round(acc_notes[i].start * 4) / 4
        acc_notes[i].end = round(acc_notes[i].end * 4) / 4
    
    acc_notes.sort(key=lambda x: x.start)
    
    # Replace the following lines with your own processing logic
    main_events = [(note.start, note.end, note.pitch, note.duration, note.velocity) for note in main_notes]
    acc_events = [(note.start, note.end, note.pitch, note.duration, note.velocity) for note in acc_notes]
    
    total += len(main_events) + len(acc_events)
    return main_events, acc_events

def is_midi_file(filename):
    return filename.lower().endswith(".mid")

def preprocess_pop909(midi_root, save_dir):
    save_py = []

    try:
        # Create the "midi_data/" directory if it doesn't exist
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)

        # Traverse subdirectories in "POP909_v3"
        for subdir, dirs, files in os.walk(midi_root):
            for filename in files:
                file_path = os.path.join(subdir, filename)
                if is_midi_file(file_path):
                    try:
                        main_events, acc_events = preprocess_midi(file_path)
                        save_py.append((main_events, acc_events))
                    except KeyboardInterrupt:
                        print(' Abort')
                        return
                    except Exception as e:
                        print(f'Error processing file {file_path}: {e}')

        save_py = np.array(save_py)
        print(save_py.size)
        np.save(os.path.join(save_dir, "pop909-event-token.npy"), save_py)

    except Exception as e:
        print(f'An error occurred: {e}')

# Specify the paths
midi_root = "POP909_v3"
save_dir = "midi_data/"

# Call the preprocessing function
preprocess_pop909(midi_root, save_dir)
# Out:
# C:\Users\naomi\AppData\Local\Temp\ipykernel_2872\504675572.py:60: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   save_py = np.array(save_py)
# 1756

# %%
import os
import numpy as np
import pretty_midi as pyd

total = 0

def preprocess_midi(path):
    global total
    data = pyd.PrettyMIDI(path)
    main_notes = []
    acc_notes = []
    
    # Extract all notes from all instruments
    for ins in data.instruments:
        acc_notes.extend(ins.notes)
    
    # Quantize notes in each bar
    for i in range(len(acc_notes)):
        acc_notes[i].start = round(acc_notes[i].start, 2)
        acc_notes[i].end = round(acc_notes[i].end, 2)
        # Quantize to the nearest 16th note
        acc_notes[i].start = round(acc_notes[i].start * 4) / 4
        acc_notes[i].end = round(acc_notes[i].end * 4) / 4
    
    acc_notes.sort(key=lambda x: x.start)
    
    # Replace the following lines with your own processing logic
    main_events = [(note.start, note.end, note.pitch, note.end - note.start, note.velocity) for note in main_notes]
    acc_events = [(note.start, note.end, note.pitch, note.end - note.start, note.velocity) for note in acc_notes]
    
    total += len(main_events) + len(acc_events)
    return main_events, acc_events


def is_midi_file(filename):
    return filename.lower().endswith(".mid")

def preprocess_pop909(midi_root, save_dir):
    save_py = []

    try:
        # Create the "midi_data_v2/" directory if it doesn't exist
        save_dir_v2 = save_dir + "_v2"
        if not os.path.exists(save_dir_v2):
            os.makedirs(save_dir_v2)

        # Traverse subdirectories in "POP909_v3"
        for subdir, dirs, files in os.walk(midi_root):
            for filename in files:
                file_path = os.path.join(subdir, filename)
                if is_midi_file(file_path):
                    try:
                        main_events, acc_events = preprocess_midi(file_path)
                        save_py.append((main_events, acc_events))
                    except KeyboardInterrupt:
                        print(' Abort')
                        return
                    except Exception as e:
                        print(f'Error processing file {file_path}: {e}')

        save_py = np.array(save_py)
        print(save_py.size)
        np.save(os.path.join(save_dir_v2, "pop909-event-token.npy"), save_py)

    except Exception as e:
        print(f'An error occurred: {e}')

# Specify the paths
midi_root = "POP909_v3"
save_dir = "midi_data"

# Call the preprocessing function
preprocess_pop909(midi_root, save_dir)
# Out:
# C:\Users\naomi\AppData\Local\Temp\ipykernel_19648\762384783.py:61: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   save_py = np.array(save_py)
# 1756

# %%
miditok.MIDITokenizer

import os
import numpy as np
import pretty_midi as pyd
from miditok import REMI, TokenizerConfig
from pathlib import Path

def is_midi_file(filename):
    return filename.lower().endswith(".mid")

def tokenize_midi(midi_path, tokenizer):
    data = pyd.PrettyMIDI(midi_path)

    # Extract tempo information
    tempo_changes = data.get_tempo_changes()
    tempo_tokens = tokenizer.tokenize_tempo(tempo_changes[0], tempo_changes[1])

    # Extract note information
    notes = []
    for instrument in data.instruments:
        notes.extend(instrument.notes)

    note_tokens = tokenizer.tokenize_notes(notes)

    # Extract chord, pitch, duration, and velocity information
    chord_tokens = tokenizer.tokenize_chords(data)
    pitch_tokens, duration_tokens, velocity_tokens = tokenizer.tokenize_notes_details(notes)

    return tempo_tokens, note_tokens, chord_tokens, pitch_tokens, duration_tokens, velocity_tokens

def preprocess_pop909(midi_root, save_dir):
    save_tokens = []

    try:
        # Create the "midi_data_v2/" directory if it doesn't exist
        save_dir_v2 = save_dir + "_v2"
        if not os.path.exists(save_dir_v2):
            os.makedirs(save_dir_v2)

        # Creating a multitrack tokenizer configuration
        config = TokenizerConfig(num_velocities=16, use_chords=True, use_programs=True)
        tokenizer = REMI(config)

        # Traverse subdirectories in "POP909_v3"
        for subdir, dirs, files in os.walk(midi_root):
            for filename in files:
                file_path = os.path.join(subdir, filename)
                if is_midi_file(file_path):
                    try:
                        tempo_tokens, note_tokens, chord_tokens, pitch_tokens, duration_tokens, velocity_tokens = tokenize_midi(file_path, tokenizer)
                        save_tokens.append((tempo_tokens, note_tokens, chord_tokens, pitch_tokens, duration_tokens, velocity_tokens))
                    except KeyboardInterrupt:
                        print(' Abort')
                        return
                    except Exception as e:
                        print(f'Error processing file {file_path}: {e}')

        save_tokens = np.array(save_tokens)
        np.save(os.path.join(save_dir_v2, "pop909-tokenized.npy"), save_tokens)

        # Tokenize a whole dataset and save it at JSON files
        midi_paths = list(Path(midi_root).rglob("*.mid"))
        data_augmentation_offsets = [2, 1, 1]
        tokenizer.tokenize_midi_dataset(midi_paths, Path(save_dir_v2, "tokens_noBPE"), data_augment_offsets=data_augmentation_offsets)

        # Constructs the vocabulary with BPE, from the token files
        tokenizer.learn_bpe(
            vocab_size=10000,
            tokens_paths=list(Path(save_dir_v2, "tokens_noBPE").rglob("**/*.json")),
            start_from_empty_voc=False,
        )

        # Saving the tokenizer configuration
        tokenizer.save_params(Path(save_dir_v2, "tokenizer.json"))

    except Exception as e:
        print(f'An error occurred: {e}')

# Specify the paths
midi_root = "POP909_v3"
save_dir = "midi_data"

# Call the preprocessing function
preprocess_pop909(midi_root, save_dir)
# Out:
# Error processing file POP909_v3\001\001.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\002\002.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\003\003.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\004\004.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\005\005.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\006\006.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\007\007.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\008\008.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\009\009.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\010\010.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\011\011.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\012\012.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\013\013.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\014\014.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\015\015.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\016\016.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\017\017.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\018\018.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\019\019.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\020\020.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\021\021.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\022\022.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\023\023.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\024\024.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\025\025.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\026\026.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\027\027.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\028\028.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\029\029.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\030\030.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\031\031.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\032\032.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\033\033.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\034\034.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\035\035.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\036\036.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\037\037.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\038\038.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\039\039.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\040\040.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\041\041.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\042\042.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\043\043.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\044\044.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\045\045.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\046\046.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\047\047.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\049\049.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\050\050.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\051\051.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\052\052.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\053\053.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\054\054.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\055\055.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\056\056.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\057\057.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\058\058.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\059\059.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\060\060.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\061\061.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\062\062.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\063\063.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\064\064.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\065\065.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\066\066.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\067\067.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\068\068.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\069\069.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\070\070.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\073\073.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\074\074.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\075\075.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\076\076.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\078\078.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\079\079.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\080\080.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\081\081.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\082\082.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\083\083.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\084\084.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\085\085.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\086\086.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\087\087.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\088\088.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\089\089.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\090\090.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\091\091.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\092\092.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\093\093.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\094\094.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\095\095.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\096\096.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\097\097.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\098\098.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\099\099.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\100\100.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\101\101.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\103\103.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\104\104.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\105\105.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\106\106.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\107\107.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\108\108.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\109\109.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\110\110.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\111\111.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\112\112.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\113\113.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\114\114.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\115\115.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\116\116.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\117\117.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\118\118.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\119\119.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\120\120.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\121\121.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\122\122.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\123\123.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\124\124.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\125\125.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\126\126.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\127\127.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\128\128.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\129\129.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\130\130.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\131\131.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\132\132.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\133\133.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\134\134.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\135\135.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\136\136.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\137\137.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\138\138.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\139\139.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\140\140.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\141\141.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\142\142.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\143\143.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\144\144.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\145\145.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\146\146.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\147\147.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\148\148.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\149\149.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\150\150.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\151\151.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\152\152.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\153\153.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\154\154.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\155\155.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\156\156.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\157\157.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\158\158.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\159\159.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\160\160.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\161\161.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\162\162.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\163\163.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\164\164.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\165\165.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\166\166.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\167\167.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\168\168.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\169\169.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\170\170.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\171\171.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\172\172.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\173\173.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\174\174.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\175\175.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\176\176.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\177\177.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\178\178.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\179\179.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\180\180.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\181\181.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\182\182.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\183\183.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\184\184.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\185\185.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\186\186.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\187\187.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\188\188.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\189\189.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\190\190.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\191\191.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\192\192.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\193\193.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\194\194.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\195\195.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\196\196.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\197\197.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\198\198.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\199\199.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\200\200.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\201\201.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\202\202.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\203\203.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\204\204.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\205\205.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\206\206.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\207\207.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\208\208.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3
mid: 'REMI' object has no attribute 'tokenize_tempo'
# Error processing file POP909_v3\909\909.mid: 'REMI' object has no attribute 'tokenize_tempo'
# Tokenizing MIDIs (midi_data_v2/tokens_noBPE): 100%|██████████████████████████████████| 878/878 [01:24<00:00, 10.38it/s]
# Performing data augmentation: 100%|██████████████████████████████████████████████████| 878/878 [00:39<00:00, 22.21it/s]
# Loading token files: 100%|████████████████████████████████████████████████████████| 6129/6129 [00:40<00:00, 153.04it/s]

# %% [markdown]
# mmm-lmd
# https://colab.research.google.com/drive/1KLbe-ZnIyvpPypVqYapBRs-o5Q1E7a9R?usp=sharing#scrollTo=ex9Lt0yWw5Ud

# %%
import os
from copy import deepcopy
from math import ceil

from miditoolkit import MidiFile
from tqdm import tqdm

MAX_NB_BAR = 8
MIN_NB_NOTES = 20
dataset = "POP909"  # Change to your dataset name

merged_out_dir = os.path.join("C:/Users/naomi/Thesis/Thesis/Thesis-main/output", f"{dataset}-chunked")
os.makedirs(merged_out_dir, exist_ok=True)

# Adjust the base path to your dataset
base_path = os.path.join("C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909", dataset)
midi_paths = [os.path.join(root, file) for root, dirs, files in os.walk(base_path) for file in files if file.endswith(('.mid', '.midi'))]

print(f"Found {len(midi_paths)} MIDI files.")

for i, midi_path in enumerate(tqdm(midi_paths, desc="CHUNKING MIDIS")):
    try:
        # Determine the output directory for this file
        relative_path = os.path.relpath(midi_path, base_path)
        output_dir = os.path.join(merged_out_dir, os.path.dirname(relative_path))
        os.makedirs(output_dir, exist_ok=True)

        # Check if chunks already exist
        midi_filename = os.path.splitext(os.path.basename(midi_path))[0]
        chunk_paths = [f for f in os.listdir(output_dir) if f.startswith(f"{midi_filename}_") and f.endswith('.mid')]
        if len(chunk_paths) > 0:
            print(f"Chunks for {midi_path} already exist, skipping...")
            continue

        # Loads MIDI, merges, and saves it
        midi = MidiFile(midi_path)
        ticks_per_cut = MAX_NB_BAR * midi.ticks_per_beat * 4
        nb_cuts = ceil(midi.max_tick / ticks_per_cut)
        if nb_cuts < 2:
            continue

        print(f"Processing {midi_path}")
        midis = [deepcopy(midi) for _ in range(nb_cuts)]

        for j, track in enumerate(midi.instruments):  # sort notes as they are not always sorted right
            track.notes.sort(key=lambda x: x.start)
            for midi_short in midis:  # clears notes from shorten MIDIs
                midi_short.instruments[j].notes = []
            for note in track.notes:
                cut_id = note.start // ticks_per_cut
                note_copy = deepcopy(note)
                note_copy.start -= cut_id * ticks_per_cut
                note_copy.end -= cut_id * ticks_per_cut
                midis[cut_id].instruments[j].notes.append(note_copy)

        # Saving MIDIs
        for j, midi_short in enumerate(midis):
            if sum(len(track.notes) for track in midi_short.instruments) < MIN_NB_NOTES:
                continue
            output_filename = f"{midi_filename}_{j}.mid"
            output_path = os.path.join(output_dir, output_filename)
            midi_short.dump(output_path)

    except Exception as e:
        print(f"An error occurred while processing {midi_path}: {e}")
# Out:
# Found 0 MIDI files.
# CHUNKING MIDIS: 0it [00:00, ?it/s]

# %%
import os
from copy import deepcopy
from math import ceil
from miditoolkit import MidiFile
from tqdm import tqdm

MAX_NB_BAR = 8
MIN_NB_NOTES = 20
dataset = "POP909"  # Change to your dataset name

merged_out_dir = os.path.join("C:/Users/naomi/Thesis/Thesis/Thesis-main/output", f"{dataset}-chunked")
os.makedirs(merged_out_dir, exist_ok=True)

# Adjust the root folder to your dataset
root_folder = 'C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909'

# Iterate over folders and MIDI files
for folder_name in os.listdir(root_folder):
    folder_path = os.path.join(root_folder, folder_name)

    # Check if the item in the directory is a folder
    if os.path.isdir(folder_path):
        print(f"Processing folder: {folder_name}")

        # Iterate over MIDI files in the folder
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.mid'):
                midi_file_path = os.path.join(folder_path, file_name)

                try:
                    # Determine the output directory for this file
                    relative_path = os.path.relpath(midi_file_path, root_folder)
                    output_dir = os.path.join(merged_out_dir, os.path.dirname(relative_path))
                    os.makedirs(output_dir, exist_ok=True)

                    # Check if chunks already exist
                    midi_filename = os.path.splitext(os.path.basename(midi_file_path))[0]
                    chunk_paths = [f for f in os.listdir(output_dir) if f.startswith(f"{midi_filename}_") and f.endswith('.mid')]
                    if len(chunk_paths) > 0:
                        print(f"Chunks for {midi_file_path} already exist, skipping...")
                        continue

                    # Loads MIDI, merges, and saves it
                    midi = MidiFile(midi_file_path)
                    ticks_per_cut = MAX_NB_BAR * midi.ticks_per_beat * 4
                    nb_cuts = ceil(midi.max_tick / ticks_per_cut)
                    if nb_cuts < 2:
                        continue

                    print(f"Processing {midi_file_path}")
                    midis = [deepcopy(midi) for _ in range(nb_cuts)]

                    for j, track in enumerate(midi.instruments):  # sort notes as they are not always sorted right
                        track.notes.sort(key=lambda x: x.start)
                        for midi_short in midis:  # clears notes from shorten MIDIs
                            midi_short.instruments[j].notes = []
                        for note in track.notes:
                            cut_id = note.start // ticks_per_cut
                            note_copy = deepcopy(note)
                            note_copy.start -= cut_id * ticks_per_cut
                            note_copy.end -= cut_id * ticks_per_cut
                            midis[cut_id].instruments[j].notes.append(note_copy)

                    # Saving MIDIs
                    for j, midi_short in enumerate(midis):
                        if sum(len(track.notes) for track in midi_short.instruments) < MIN_NB_NOTES:
                            continue
                        output_filename = f"{midi_filename}_{j}.mid"
                        output_path = os.path.join(output_dir, output_filename)
                        midi_short.dump(output_path)

                except Exception as e:
                    print(f"An error occurred while processing {midi_file_path}: {e}")
# Out:
# Processing folder: 001
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\001\001.mid
# Processing folder: 002
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\002\002.mid
# Processing folder: 003
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\003\003.mid
# Processing folder: 004
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\004\004.mid
# Processing folder: 005
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\005\005.mid
# Processing folder: 006
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\006\006.mid
# Processing folder: 007
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\007\007.mid
# Processing folder: 008
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\008\008.mid
# Processing folder: 009
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\009\009.mid
# Processing folder: 010
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\010\010.mid
# Processing folder: 011
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\011\011.mid
# Processing folder: 012
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\012\012.mid
# Processing folder: 013
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\013\013.mid
# Processing folder: 014
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\014\014.mid
# Processing folder: 015
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\015\015.mid
# Processing folder: 016
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\016\016.mid
# Processing folder: 017
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\017\017.mid
# Processing folder: 018
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\018\018.mid
# Processing folder: 019
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\019\019.mid
# Processing folder: 020
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\020\020.mid
# Processing folder: 021
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\021\021.mid
# Processing folder: 022
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\022\022.mid
# Processing folder: 023
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\023\023.mid
# Processing folder: 024
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\024\024.mid
# Processing folder: 025
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\025\025.mid
# Processing folder: 026
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\026\026.mid
# Processing folder: 027
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\027\027.mid
# Processing folder: 028
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\028\028.mid
# Processing folder: 029
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\029\029.mid
# Processing folder: 030
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\030\030.mid
# Processing folder: 031
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\031\031.mid
# Processing folder: 032
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\032\032.mid
# Processing folder: 033
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\033\033.mid
# Processing folder: 034
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\034\034.mid
# Processing folder: 035
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\035\035.mid
# Processing folder: 036
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\036\036.mid
# Processing folder: 037
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\037\037.mid
# Processing folder: 038
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\038\038.mid
# Processing folder: 039
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\039\039.mid
# Processing folder: 040
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\040\040.mid
# Processing folder: 041
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\041\041.mid
# Processing folder: 042
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\042\042.mid
# Processing folder: 043
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\043\043.mid
# Processing folder: 044
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\044\044.mid
# Processing folder: 045
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\045\045.mid
# Processing folder: 046
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\046\046.mid
# Processing folder: 047
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\047\047.mid
# Processing folder: 048
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\048\048.mid
# Processing folder: 049
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\049\049.mid
# Processing folder: 050
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\050\050.mid
# Processing folder: 051
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\051\051.mid
# Processing folder: 052
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\052\052.mid
# Processing folder: 053
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\053\053.mid
# Processing folder: 054
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\054\054.mid
# Processing folder: 055
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\055\055.mid
# Processing folder: 056
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\056\056.mid
# Processing folder: 057
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\057\057.mid
# Processing folder: 058
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\058\058.mid
# Processing folder: 059
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\059\059.mid
# Processing folder: 060
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\060\060.mid
# Processing folder: 061
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\061\061.mid
# Processing folder: 062
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\062\062.mid
# Processing folder: 063
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\063\063.mid
# Processing folder: 064
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\064\064.mid
# Processing folder: 065
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\065\065.mid
# Processing folder: 066
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\066\066.mid
# Processing folder: 067
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\067\067.mid
# Processing folder: 068
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\068\068.mid
# Processing folder: 069
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\069\069.mid
# Processing folder: 070
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\070\070.mid
# Processing folder: 071
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\071\071.mid
# Processing folder: 072
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\072\072.mid
# Processing folder: 073
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\073\073.mid
# Processing folder: 074
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\074\074.mid
# Processing folder: 075
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\075\075.mid
# Processing folder: 076
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\076\076.mid
# Processing folder: 077
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\077\077.mid
# Processing folder: 078
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\078\078.mid
# Processing folder: 079
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\079\079.mid
# Processing folder: 080
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\080\080.mid
# Processing folder: 081
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\081\081.mid
# Processing folder: 082
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\082\082.mid
# Processing folder: 083
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\083\083.mid
# Processing folder: 084
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\084\084.mid
# Processing folder: 085
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\085\085.mid
# Processing folder: 086
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\086\086.mid
# Processing folder: 087
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\087\087.mid
# Processing folder: 088
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\088\088.mid
# Processing folder: 089
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\089\089.mid
# Processing folder: 090
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\090\090.mid
# Processing folder: 091
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\091\091.mid
# Processing folder: 092
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\092\092.mid
# Processing folder: 093
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\093\093.mid
# Processing folder: 094
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\094\094.mid
# Processing folder: 095
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\095\095.mid
# Processing folder: 096
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\096\096.mid
# Processing folder: 097
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\097\097.mid
# Processing folder: 098
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\098\098.mid
# Processing folder: 099
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\099\099.mid
# Processing folder: 100
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\100\100.mid
# Processing folder: 101
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\101\101.mid
# Processing folder: 102
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\102\102.mid
# Processing folder: 103
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\103\103.mid
# Processing folder: 104
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\104\104.mid
# Processing folder: 105
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\105\105.mid
# Processing folder: 106
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\106\106.mid
# Processing folder: 107
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\107\107.mid
# Processing folder: 108
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\108\108.mid
# Processing folder: 109
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\109\109.mid
# Processing folder: 110
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\110\110.mid
# Processing folder: 111
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\111\111.mid
# Processing folder: 112
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\112\112.mid
# Processing folder: 113
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\113\113.mid
# Processing folder: 114
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\114\114.mid
# Processing folder: 115
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\115\115.mid
# Processing folder: 116
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\116\116.mid
# Processing folder: 117
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\117\117.mid
# Processing folder: 118
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\118\118.mid
# Processing folder: 119
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\119\119.mid
# Processing folder: 120
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\120\120.mid
# Processing folder: 121
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\121\121.mid
# Processing folder: 122
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\122\122.mid
# Processing folder: 123
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\123\123.mid
# Processing folder: 124
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\124\124.mid
# Processing folder: 125
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\125\125.mid
# Processing folder: 126
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\126\126.mid
# Processing folder: 127
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\127\127.mid
# Processing folder: 128
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\128\128.mid
# Processing folder: 129
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\129\129.mid
# Processing folder: 130
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\130\130.mid
# Processing folder: 131
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\131\131.mid
# Processing folder: 132
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\132\132.mid
# Processing folder: 133
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\133\133.mid
# Processing folder: 134
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\134\134.mid
# Processing folder: 135
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\135\135.mid
# Processing folder: 136
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\136\136.mid
# Processing folder: 137
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\137\137.mid
# Processing folder: 138
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\138\138.mid
# Processing folder: 139
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\139\139.mid
# Processing folder: 140
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\140\140.mid
# Processing folder: 141
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\141\141.mid
# Processing folder: 142
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\142\142.mid
# Processing folder: 143
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\143\143.mid
# Processing folder: 144
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\144\144.mid
# Processing folder: 145
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\145\145.mid
# Processing folder: 146
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\146\146.mid
# Processing folder: 147
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\147\147.mid
# Processing folder: 148
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\148\148.mid
# Processing folder: 149
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\149\149.mid
# Processing folder: 150
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\150\150.mid
# Processing folder: 151
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\151\151.mid
# Processing folder: 152
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\152\152.mid
# Processing folder: 153
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\153\153.mid
# Processing folder: 154
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\154\154.mid
# Processing folder: 155
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\155\155.mid
# Processing folder: 156
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\156\156.mid
# Processing folder: 157
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\157\157.mid
# Processing folder: 158
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\158\158.mid
# Processing folder: 159
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\159\159.mid
# Processing folder: 160
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\160\160.mid
# Processing folder: 161
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\161\161.mid
# Processing folder: 162
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\162\162.mid
# Processing folder: 163
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\163\163.mid
# Processing folder: 164
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\164\164.mid
# Processing folder: 165
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\165\165.mid
# Processing folder: 166
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\166\166.mid
# Processing folder: 167
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\167\167.mid
# Processing folder: 168
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\168\168.mid
# Processing folder: 169
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\169\169.mid
# Processing folder: 170
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\170\170.mid
# Processing folder: 171
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\171\171.mid
# Processing folder: 172
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\172\172.mid
# Processing folder: 173
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\173\173.mid
# Processing folder: 174
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\174\174.mid
# Processing folder: 175
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\175\175.mid
# Processing folder: 176
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\176\176.mid
# Processing folder: 177
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\177\177.mid
# Processing folder: 178
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\178\178.mid
# Processing folder: 179
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\179\179.mid
# Processing folder: 180
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\180\180.mid
# Processing folder: 181
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\181\181.mid
# Processing folder: 182
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\182\182.mid
# Processing folder: 183
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\183\183.mid
# Processing folder: 184
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\184\184.mid
# Processing folder: 185
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\185\185.mid
# Processing folder: 186
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\186\186.mid
# Processing folder: 187
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\187\187.mid
# Processing folder: 188
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\188\188.mid
# Processing folder: 189
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\189\189.mid
# Processing folder: 190
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\190\190.mid
# Processing folder: 191
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\191\191.mid
# Processing folder: 192
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\192\192.mid
# Processing folder: 193
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\193\193.mid
# Processing folder: 194
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\357\357.mid
# Processing folder: 358
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\358\358.mid
# Processing folder: 359
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\359\359.mid
# Processing folder: 360
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\360\360.mid
# Processing folder: 361
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\361\361.mid
# Processing folder: 362
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\362\362.mid
# Processing folder: 363
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\363\363.mid
# Processing folder: 364
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\364\364.mid
# Processing folder: 365
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\365\365.mid
# Processing folder: 366
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\366\366.mid
# Processing folder: 367
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\367\367.mid
# Processing folder: 368
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\368\368.mid
# Processing folder: 369
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\369\369.mid
# Processing folder: 370
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\370\370.mid
# Processing folder: 371
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\371\371.mid
# Processing folder: 372
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\372\372.mid
# Processing folder: 373
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\373\373.mid
# Processing folder: 374
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\374\374.mid
# Processing folder: 375
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\375\375.mid
# Processing folder: 376
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\376\376.mid
# Processing folder: 377
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\377\377.mid
# Processing folder: 378
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\378\378.mid
# Processing folder: 379
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\379\379.mid
# Processing folder: 380
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\380\380.mid
# Processing folder: 381
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\381\381.mid
# Processing folder: 382
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\382\382.mid
# Processing folder: 383
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\383\383.mid
# Processing folder: 384
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\384\384.mid
# Processing folder: 385
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\385\385.mid
# Processing folder: 386
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\386\386.mid
# Processing folder: 387
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\387\387.mid
# Processing folder: 388
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\388\388.mid
# Processing folder: 389
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\389\389.mid
# Processing folder: 390
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\390\390.mid
# Processing folder: 391
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\391\391.mid
# Processing folder: 392
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\392\392.mid
# Processing folder: 393
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\393\393.mid
# Processing folder: 394
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\394\394.mid
# Processing folder: 395
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\395\395.mid
# Processing folder: 396
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\396\396.mid
# Processing folder: 397
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\397\397.mid
# Processing folder: 398
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\398\398.mid
# Processing folder: 399
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\399\399.mid
# Processing folder: 400
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\400\400.mid
# Processing folder: 401
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\401\401.mid
# Processing folder: 402
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\402\402.mid
# Processing folder: 403
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\403\403.mid
# Processing folder: 404
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\404\404.mid
# Processing folder: 405
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\405\405.mid
# Processing folder: 406
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\406\406.mid
# Processing folder: 407
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\407\407.mid
# Processing folder: 408
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\408\408.mid
# Processing folder: 409
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\409\409.mid
# Processing folder: 410
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\410\410.mid
# Processing folder: 411
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\411\411.mid
# Processing folder: 412
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\412\412.mid
# Processing folder: 413
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\413\413.mid
# Processing folder: 414
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\414\414.mid
# Processing folder: 415
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\415\415.mid
# Processing folder: 416
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\416\416.mid
# Processing folder: 417
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\417\417.mid
# Processing folder: 418
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\418\418.mid
# Processing folder: 419
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\419\419.mid
# Processing folder: 420
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\420\420.mid
# Processing folder: 421
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\421\421.mid
# Processing folder: 422
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\422\422.mid
# Processing folder: 423
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\423\423.mid
# Processing folder: 424
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\424\424.mid
# Processing folder: 425
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\425\425.mid
# Processing folder: 426
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\426\426.mid
# Processing folder: 427
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\427\427.mid
# Processing folder: 428
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\428\428.mid
# Processing folder: 429
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\429\429.mid
# Processing folder: 430
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\430\430.mid
# Processing folder: 431
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\431\431.mid
# Processing folder: 432
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\432\432.mid
# Processing folder: 433
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\433\433.mid
# Processing folder: 434
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\434\434.mid
# Processing folder: 435
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\435\435.mid
# Processing folder: 436
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\436\436.mid
# Processing folder: 437
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\437\437.mid
# Processing folder: 438
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\438\438.mid
# Processing folder: 439
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\439\439.mid
# Processing folder: 440
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\440\440.mid
# Processing folder: 441
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\441\441.mid
# Processing folder: 442
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\442\442.mid
# Processing folder: 443
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\443\443.mid
# Processing folder: 444
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\444\444.mid
# Processing folder: 445
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\445\445.mid
# Processing folder: 446
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\446\446.mid
# Processing folder: 447
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\447\447.mid
# Processing folder: 448
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\448\448.mid
# Processing folder: 449
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\449\449.mid
# Processing folder: 450
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\450\450.mid
# Processing folder: 451
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\451\451.mid
# Processing folder: 452
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\452\452.mid
# Processing folder: 453
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\453\453.mid
# Processing folder: 454
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\454\454.mid
# Processing folder: 455
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\455\455.mid
# Processing folder: 456
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\456\456.mid
# Processing folder: 457
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\457\457.mid
# Processing folder: 458
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\458\458.mid
# Processing folder: 459
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\459\459.mid
# Processing folder: 460
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\460\460.mid
# Processing folder: 461
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\461\461.mid
# Processing folder: 462
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\462\462.mid
# Processing folder: 463
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\463\463.mid
# Processing folder: 464
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\464\464.mid
# Processing folder: 465
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\465\465.mid
# Processing folder: 466
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\466\466.mid
# Processing folder: 467
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\467\467.mid
# Processing folder: 468
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\468\468.mid
# Processing folder: 469
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\469\469.mid
# Processing folder: 470
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\470\470.mid
# Processing folder: 471
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\471\471.mid
# Processing folder: 472
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\472\472.mid
# Processing folder: 473
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\473\473.mid
# Processing folder: 474
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\474\474.mid
# Processing folder: 475
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\475\475.mid
# Processing folder: 476
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\476\476.mid
# Processing folder: 477
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\477\477.mid
# Processing folder: 478
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\478\478.mid
# Processing folder: 479
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\479\479.mid
# Processing folder: 480
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\480\480.mid
# Processing folder: 481
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\481\481.mid
# Processing folder: 482
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\482\482.mid
# Processing folder: 483
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\483\483.mid
# Processing folder: 484
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\484\484.mid
# Processing folder: 485
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\485\485.mid
# Processing folder: 486
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\486\486.mid
# Processing folder: 487
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\487\487.mid
# Processing folder: 488
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\488\488.mid
# Processing folder: 489
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\489\489.mid
# Processing folder: 490
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\490\490.mid
# Processing folder: 491
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\491\491.mid
# Processing folder: 492
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\492\492.mid
# Processing folder: 493
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\493\493.mid
# Processing folder: 494
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\494\494.mid
# Processing folder: 495
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\495\495.mid
# Processing folder: 496
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\496\496.mid
# Processing folder: 497
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\497\497.mid
# Processing folder: 498
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\498\498.mid
# Processing folder: 499
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\499\499.mid
# Processing folder: 500
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\500\500.mid
# Processing folder: 501
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\501\501.mid
# Processing folder: 502
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\502\502.mid
# Processing folder: 503
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\503\503.mid
# Processing folder: 504
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\504\504.mid
# Processing folder: 505
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\505\505.mid
# Processing folder: 506
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\506\506.mid
# Processing folder: 507
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\507\507.mid
# Processing folder: 508
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\508\508.mid
# Processing folder: 509
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\509\509.mid
# Processing folder: 510
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\510\510.mid
# Processing folder: 511
# ...
# Processing folder: 740
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\740\740.mid
# Processing folder: 741
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\741\741.mid
# Processing folder: 742
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\742\742.mid
# Processing folder: 743
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\743\743.mid
# Processing folder: 744
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\744\744.mid
# Processing folder: 745
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\745\745.mid
# Processing folder: 746
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\746\746.mid
# Processing folder: 747
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\747\747.mid
# Processing folder: 748
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\748\748.mid
# Processing folder: 749
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\749\749.mid
# Processing folder: 750
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\750\750.mid
# Processing folder: 751
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\751\751.mid
# Processing folder: 752
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\752\752.mid
# Processing folder: 753
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\753\753.mid
# Processing folder: 754
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\754\754.mid
# Processing folder: 755
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\755\755.mid
# Processing folder: 756
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\756\756.mid
# Processing folder: 757
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\757\757.mid
# Processing folder: 758
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\758\758.mid
# Processing folder: 759
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\759\759.mid
# Processing folder: 760
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\760\760.mid
# Processing folder: 761
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\761\761.mid
# Processing folder: 762
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\762\762.mid
# Processing folder: 763
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\763\763.mid
# Processing folder: 764
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\764\764.mid
# Processing folder: 765
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\765\765.mid
# Processing folder: 766
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\766\766.mid
# Processing folder: 767
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\767\767.mid
# Processing folder: 768
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\768\768.mid
# Processing folder: 769
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\769\769.mid
# Processing folder: 770
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\770\770.mid
# Processing folder: 771
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\771\771.mid
# Processing folder: 772
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\772\772.mid
# Processing folder: 773
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\773\773.mid
# Processing folder: 774
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\774\774.mid
# Processing folder: 775
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\775\775.mid
# Processing folder: 776
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\776\776.mid
# Processing folder: 777
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\777\777.mid
# Processing folder: 778
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\778\778.mid
# Processing folder: 779
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\779\779.mid
# Processing folder: 780
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\780\780.mid
# Processing folder: 781
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\781\781.mid
# Processing folder: 782
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\782\782.mid
# Processing folder: 783
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\783\783.mid
# Processing folder: 784
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\784\784.mid
# Processing folder: 785
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\785\785.mid
# Processing folder: 786
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\786\786.mid
# Processing folder: 787
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\787\787.mid
# Processing folder: 788
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\788\788.mid
# Processing folder: 789
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\789\789.mid
# Processing folder: 790
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\790\790.mid
# Processing folder: 791
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\791\791.mid
# Processing folder: 792
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\792\792.mid
# Processing folder: 793
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\793\793.mid
# Processing folder: 794
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\794\794.mid
# Processing folder: 795
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\795\795.mid
# Processing folder: 796
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\796\796.mid
# Processing folder: 797
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\797\797.mid
# Processing folder: 798
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\798\798.mid
# Processing folder: 799
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\799\799.mid
# Processing folder: 800
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\800\800.mid
# Processing folder: 801
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\801\801.mid
# Processing folder: 802
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\802\802.mid
# Processing folder: 803
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\803\803.mid
# Processing folder: 804
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\804\804.mid
# Processing folder: 805
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\805\805.mid
# Processing folder: 806
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\806\806.mid
# Processing folder: 807
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\807\807.mid
# Processing folder: 808
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\808\808.mid
# Processing folder: 809
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\809\809.mid
# Processing folder: 810
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\810\810.mid
# Processing folder: 811
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\811\811.mid
# Processing folder: 812
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\812\812.mid
# Processing folder: 813
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\813\813.mid
# Processing folder: 814
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\814\814.mid
# Processing folder: 815
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\815\815.mid
# Processing folder: 816
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\816\816.mid
# Processing folder: 817
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\817\817.mid
# Processing folder: 818
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\818\818.mid
# Processing folder: 819
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\819\819.mid
# Processing folder: 820
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\820\820.mid
# Processing folder: 821
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\821\821.mid
# Processing folder: 822
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\822\822.mid
# Processing folder: 823
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\823\823.mid
# Processing folder: 824
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\824\824.mid
# Processing folder: 825
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\825\825.mid
# Processing folder: 826
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\826\826.mid
# Processing folder: 827
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\827\827.mid
# Processing folder: 828
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\828\828.mid
# Processing folder: 829
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\829\829.mid
# Processing folder: 830
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\830\830.mid
# Processing folder: 831
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\831\831.mid
# Processing folder: 832
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\832\832.mid
# Processing folder: 833
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\833\833.mid
# Processing folder: 834
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\834\834.mid
# Processing folder: 835
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\835\835.mid
# Processing folder: 836
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\836\836.mid
# Processing folder: 837
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\837\837.mid
# Processing folder: 838
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\838\838.mid
# Processing folder: 839
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\839\839.mid
# Processing folder: 840
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\840\840.mid
# Processing folder: 841
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\841\841.mid
# Processing folder: 842
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\842\842.mid
# Processing folder: 843
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\843\843.mid
# Processing folder: 844
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\844\844.mid
# Processing folder: 845
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\845\845.mid
# Processing folder: 846
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\846\846.mid
# Processing folder: 847
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\847\847.mid
# Processing folder: 848
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\848\848.mid
# Processing folder: 849
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\849\849.mid
# Processing folder: 850
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\850\850.mid
# Processing folder: 851
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\851\851.mid
# Processing folder: 852
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\852\852.mid
# Processing folder: 853
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\853\853.mid
# Processing folder: 854
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\854\854.mid
# Processing folder: 855
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\855\855.mid
# Processing folder: 856
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\856\856.mid
# Processing folder: 857
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\857\857.mid
# Processing folder: 858
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\858\858.mid
# Processing folder: 859
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\859\859.mid
# Processing folder: 860
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\860\860.mid
# Processing folder: 861
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\861\861.mid
# Processing folder: 862
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\862\862.mid
# Processing folder: 863
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\863\863.mid
# Processing folder: 864
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\864\864.mid
# Processing folder: 865
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\865\865.mid
# Processing folder: 866
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\866\866.mid
# Processing folder: 867
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\867\867.mid
# Processing folder: 868
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\868\868.mid
# Processing folder: 869
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\869\869.mid
# Processing folder: 870
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\870\870.mid
# Processing folder: 871
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\871\871.mid
# Processing folder: 872
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\872\872.mid
# Processing folder: 873
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\873\873.mid
# Processing folder: 874
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\874\874.mid
# Processing folder: 875
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\875\875.mid
# Processing folder: 876
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\876\876.mid
# Processing folder: 877
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\877\877.mid
# Processing folder: 878
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\878\878.mid
# Processing folder: 879
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\879\879.mid
# Processing folder: 880
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\880\880.mid
# Processing folder: 881
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\881\881.mid
# Processing folder: 882
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\882\882.mid
# Processing folder: 883
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\883\883.mid
# Processing folder: 884
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\884\884.mid
# Processing folder: 885
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\885\885.mid
# Processing folder: 886
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\886\886.mid
# Processing folder: 887
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\887\887.mid
# Processing folder: 888
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\888\888.mid
# Processing folder: 889
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\889\889.mid
# Processing folder: 890
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\890\890.mid
# Processing folder: 891
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\891\891.mid
# Processing folder: 892
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\892\892.mid
# Processing folder: 893
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\893\893.mid
# Processing folder: 894
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\894\894.mid
# Processing folder: 895
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\895\895.mid
# Processing folder: 896
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\896\896.mid
# Processing folder: 897
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\897\897.mid
# Processing folder: 898
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\898\898.mid
# Processing folder: 899
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\899\899.mid
# Processing folder: 900
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\900\900.mid
# Processing folder: 901
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\901\901.mid
# Processing folder: 902
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\902\902.mid
# Processing folder: 903
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\903\903.mid
# Processing folder: 904
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\904\904.mid
# Processing folder: 905
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\905\905.mid
# Processing folder: 906
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\906\906.mid
# Processing folder: 907
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\907\907.mid
# Processing folder: 908
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\908\908.mid
# Processing folder: 909
# Processing C:/Users/naomi/Thesis/Thesis/Thesis-main/POP909\909\909.mid
